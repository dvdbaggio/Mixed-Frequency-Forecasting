# %% [markdown]
# # Shallow LSTM Benchmark with Optuna & Symlog

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.9.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.50)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.12)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler, RobustScaler
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pack_padded_sequence
from torch.optim.lr_scheduler import ReduceLROnPlateau
import optuna

SEED = 42
DATA_PATH = Path("Merged_Dataset_yoy.csv")
PREDICTION_TARGETS = ["EBITDA", "Net_Income", "ROA"]
DEFAULT_LOOKBACK_DAYS = 365

MAX_EPOCHS = 100
PATIENCE = 10
TRAIN_YEAR_CUTOFF = 2019
VALID_YEAR_CUTOFF = 2021
OPTUNA_TRIALS = 100

np.random.seed(SEED)
torch.manual_seed(SEED)
torch.set_num_threads(max(1, torch.get_num_threads() // 2))
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data Processing (Baseline)

# %%
def load_and_prepare_yoy_data(data_path: Path, lookback_days: int = 365):
    try:
        df = pd.read_csv(data_path)
    except FileNotFoundError:
        df = pd.read_csv("Merged_Dataset_yoy.csv")

    df["Date"] = pd.to_datetime(df["Date"])
    df = df.sort_values(["Company", "Date"]).reset_index(drop=True)
    df["year"] = df["Date"].dt.year

    df["has_targets"] = df[PREDICTION_TARGETS].notna().any(axis=1)
    year_end_records = df[df["has_targets"]].copy()
    exclude_cols = {"Date", "Company", "year", "has_targets"} | set(PREDICTION_TARGETS)
    feature_cols = [col for col in df.columns if col not in exclude_cols and pd.api.types.is_numeric_dtype(df[col])]

    sequences = []
    for company in df["Company"].unique():
        company_records = year_end_records[year_end_records["Company"] == company].copy()
        company_data = df[df["Company"] == company].copy()

        for _, year_end_row in company_records.iterrows():
            year = int(year_end_row["year"])
            year_end_date = year_end_row["Date"]

            prior_year_records = year_end_records[
                (year_end_records["Company"] == company) & (year_end_records["year"] == year - 1)
            ]
            if prior_year_records.empty:
                continue

            prior_row = prior_year_records.iloc[0]
            window_start = year_end_date - pd.Timedelta(days=lookback_days)
            window = company_data[(company_data["Date"] > window_start) & (company_data["Date"] <= year_end_date)].copy()

            if len(window) < 200:
                continue

            window[feature_cols] = window[feature_cols].ffill().bfill()
            if window[feature_cols].isna().any().any():
                continue

            sequences.append({
                "company": company, "year": year, "year_end_date": year_end_date,
                "window_data": window[feature_cols].to_numpy(dtype=np.float32),
                **{f"current_{t.lower()}": year_end_row[t] for t in PREDICTION_TARGETS},
                **{f"prior_{t.lower()}": prior_row[t] for t in PREDICTION_TARGETS},
            })

    data_records = []
    for seq in sequences:
        for target_name in PREDICTION_TARGETS:
            current_val = seq[f"current_{target_name.lower()}"]
            prior_val = seq[f"prior_{target_name.lower()}"]
            if pd.isna(current_val) or pd.isna(prior_val):
                continue

            label_value = (current_val - prior_val) / (np.abs(prior_val) + 1e-8)

            data_records.append({
                "company": seq["company"], "year": seq["year"], "year_end_date": seq["year_end_date"],
                "target": target_name, "label_value": label_value,
                "window_data": seq["window_data"]
            })

    return pd.DataFrame(data_records), feature_cols

data_df, feature_cols = load_and_prepare_yoy_data(DATA_PATH, lookback_days=DEFAULT_LOOKBACK_DAYS)

def split_by_year(data_df: pd.DataFrame, train_cutoff: int, valid_cutoff: int):
    train_data = data_df[data_df["year"] <= train_cutoff].copy()
    val_data = data_df[(data_df["year"] > train_cutoff) & (data_df["year"] <= valid_cutoff)].copy()
    test_data = data_df[data_df["year"] > valid_cutoff].copy()
    return train_data, val_data, test_data

train_data, val_data, test_data = split_by_year(data_df, TRAIN_YEAR_CUTOFF, VALID_YEAR_CUTOFF)

scaler = StandardScaler()
train_windows = np.vstack([row for row in train_data["window_data"]])
scaler.fit(train_windows)

max_seq_length = max(len(row) for row in data_df["window_data"])

# %% [markdown]
# ## Enhanced Pipeline Setup (Symlog, RobustScaler, Packing)

# %%
SELECTED_FEATURES = feature_cols.copy() # Can apply feature selection here
selected_indices = [feature_cols.index(f) for f in SELECTED_FEATURES]

improved_data_df = data_df.copy()

# SYMLOG TRANSFORMATION instead of Winsorization
idx_value = improved_data_df["target"].isin(PREDICTION_TARGETS)
y_val = improved_data_df.loc[idx_value, "label_value"]
improved_data_df.loc[idx_value, "label_value"] = np.sign(y_val) * np.log1p(np.abs(y_val))

train_data_imp, val_data_imp, test_data_imp = split_by_year(improved_data_df, TRAIN_YEAR_CUTOFF, VALID_YEAR_CUTOFF)

robust_scaler = RobustScaler()
train_windows_imp = np.vstack([row[:, selected_indices] for row in train_data_imp["window_data"]])
robust_scaler.fit(train_windows_imp)

def collate_fn_improved(batch):
    batch.sort(key=lambda x: x[2], reverse=True)
    sequences = [x[0] for x in batch]
    targets = torch.stack([x[1] for x in batch])
    lengths = torch.tensor([x[2] for x in batch])
    padded_seqs = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    return padded_seqs, targets, lengths

# %% [markdown]
# ## Model Definitions

# %%
class ShallowLSTMClassifier(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_targets: int = 1, dropout: float = 0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=1, batch_first=True)
        self.dropout = nn.Dropout(p=dropout)
        self.head = nn.Linear(hidden_size, num_targets)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        lstm_out, _ = self.lstm(x)
        hidden = self.dropout(lstm_out[:, -1, :])
        logits = self.head(hidden)
        if logits.size(-1) == 1: logits = logits.squeeze(-1)
        return logits

class ImprovedShallowLSTM(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_targets: int = 1, dropout: float = 0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=1, batch_first=True)
        self.dropout = nn.Dropout(p=dropout)
        self.head = nn.Linear(hidden_size, num_targets)

    def forward(self, x, lengths):
        packed_x = pack_padded_sequence(x, lengths.cpu(), batch_first=True, enforce_sorted=True)
        _, (hn, _) = self.lstm(packed_x)
        hidden = self.dropout(hn[-1])
        logits = self.head(hidden)
        if logits.size(-1) == 1: logits = logits.squeeze(-1)
        return logits

class TwoLayersLSTM(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_targets: int = 1, dropout: float = 0.2):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=2,
            dropout=dropout,
            batch_first=True
        )
        self.dropout = nn.Dropout(p=dropout)
        self.head = nn.Linear(hidden_size, num_targets)

    def forward(self, x, lengths):
        packed_x = pack_padded_sequence(x, lengths.cpu(), batch_first=True, enforce_sorted=True)
        _, (hn, _) = self.lstm(packed_x)
        hidden = self.dropout(hn[-1])
        logits = self.head(hidden)
        if logits.size(-1) == 1: logits = logits.squeeze(-1)
        return logits

# %%
class UpgradedTwoLayersLSTM(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_targets: int = 1, dropout: float = 0.2):
        super().__init__()

        # 1. Bidirectional LSTM
        # Automatically doubles the output feature size
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=2,
            dropout=dropout,
            batch_first=True,
            bidirectional=True
        )

        # 2. Layer Normalization for stability
        # The dimension is hidden_size * 2 because of the bidirectional flag
        self.layer_norm = nn.LayerNorm(hidden_size * 2)
        self.dropout = nn.Dropout(p=dropout)

        # 3. MLP Head with non-linearity instead of a single Linear layer
        self.head = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.GELU(),
            nn.Dropout(p=dropout),
            nn.Linear(hidden_size, num_targets)
        )

    def forward(self, x, lengths):
        packed_x = pack_padded_sequence(x, lengths.cpu(), batch_first=True, enforce_sorted=True)
        _, (hn, _) = self.lstm(packed_x)

        # Extract the last hidden state from both forward and backward directions of the top layer
        # hn shape: (num_layers * num_directions, batch, hidden_size)
        # Top layer forward is at index -2, Top layer backward is at index -1
        hidden_forward = hn[-2]
        hidden_backward = hn[-1]

        # Concatenate forward and backward states
        hidden = torch.cat((hidden_forward, hidden_backward), dim=1)

        # Apply normalization and dropout
        hidden = self.layer_norm(hidden)
        hidden = self.dropout(hidden)

        # Pass through the MLP prediction head
        logits = self.head(hidden)

        if logits.size(-1) == 1:
            logits = logits.squeeze(-1)

        return logits

# %% [markdown]
# ## Helpers for Optuna and Evaluation

# %%
def extract_mtl_df(df: pd.DataFrame) -> pd.DataFrame:
    mtl_records = []
    for (company, year), group in df.groupby(["company", "year"]):
        window_data = group.iloc[0]["window_data"]
        year_end_date = group.iloc[0]["year_end_date"]
        label_value = np.full(len(PREDICTION_TARGETS), np.nan, dtype=np.float32)
        for i, t in enumerate(PREDICTION_TARGETS):
            t_row = group[group["target"] == t]
            if not t_row.empty:
                label_value[i] = t_row.iloc[0]["label_value"]
        mtl_records.append({
            "company": company, "year": year, "year_end_date": year_end_date,
            "window_data": window_data, "label_value": label_value
        })
    return pd.DataFrame(mtl_records)

# Baseline MTL dfs
mtl_train_data = extract_mtl_df(train_data)
mtl_val_data = extract_mtl_df(val_data)
mtl_test_data = extract_mtl_df(test_data)

# Improved MTL dfs
mtl_train_data_imp = extract_mtl_df(train_data_imp)
mtl_val_data_imp = extract_mtl_df(val_data_imp)
mtl_test_data_imp = extract_mtl_df(test_data_imp)

class YoYSequenceDatasetMTL(Dataset):
    def __init__(self, data_df: pd.DataFrame, max_seq_length: int, scaler: StandardScaler = None):
        self.data_df = data_df.reset_index(drop=True)
        self.max_seq_length = max_seq_length
        self.scaler = scaler

    def __len__(self) -> int: return len(self.data_df)

    def __getitem__(self, idx: int):
        row = self.data_df.iloc[idx]
        window = row["window_data"].copy()
        if self.scaler is not None: window = self.scaler.transform(window)
        seq_len = len(window)
        if seq_len < self.max_seq_length:
            padding = np.zeros((self.max_seq_length - seq_len, window.shape[1]), dtype=np.float32)
            window = np.vstack([padding, window])
        target = row["label_value"]
        mask = ~np.isnan(target)
        target_clean = np.nan_to_num(target, nan=0.0)
        return torch.from_numpy(window), torch.tensor(target_clean, dtype=torch.float32), torch.tensor(mask, dtype=torch.bool)


class ImprovedYoYDatasetMTL(Dataset):
    def __init__(self, data_df, scaler, feature_indices, window_size=None):
        self.data_df = data_df.reset_index(drop=True)
        self.scaler = scaler
        self.feature_indices = feature_indices
        self.window_size = window_size  # Store the desired sequence length

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        row = self.data_df.iloc[idx]

        # 1. Extract the pre-computed window from the dataframe
        window = row["window_data"][:, self.feature_indices].copy()

        # 2. Truncate the window to test different sizes
        # We take the last 'window_size' steps to keep the most recent data
        if self.window_size is not None:
            window = window[-self.window_size:]

        # 3. Apply scaling if provided
        if self.scaler:
            window = self.scaler.transform(window)

        # 4. Extract and clean targets
        target = row["label_value"]
        mask = ~np.isnan(target)
        target_clean = np.nan_to_num(target, nan=0.0)

        return (
            torch.from_numpy(window),
            torch.tensor(target_clean, dtype=torch.float32),
            torch.tensor(mask, dtype=torch.bool),
            len(window)
        )

def collate_fn_improved_mtl(batch):
    batch.sort(key=lambda x: x[3], reverse=True)
    sequences = [x[0] for x in batch]
    targets = torch.stack([x[1] for x in batch])
    masks = torch.stack([x[2] for x in batch])
    lengths = torch.tensor([x[3] for x in batch])
    padded_seqs = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    return padded_seqs, targets, masks, lengths

# %%
def build_loaders_and_model(is_improved, params):
    dropout_val = params.get("dropout", 0.2)
    if is_improved:
        train_ds = ImprovedYoYDatasetMTL(mtl_train_data_imp, robust_scaler, selected_indices)
        val_ds = ImprovedYoYDatasetMTL(mtl_val_data_imp, robust_scaler, selected_indices)
        test_ds = ImprovedYoYDatasetMTL(mtl_test_data_imp, robust_scaler, selected_indices)
        collate = collate_fn_improved_mtl
        model = ImprovedShallowLSTM(len(selected_indices), params["hidden_size"], len(PREDICTION_TARGETS), dropout_val).to(DEVICE)
    else:
        train_ds = YoYSequenceDatasetMTL(mtl_train_data, max_seq_length, scaler)
        val_ds = YoYSequenceDatasetMTL(mtl_val_data, max_seq_length, scaler)
        test_ds = YoYSequenceDatasetMTL(mtl_test_data, max_seq_length, scaler)
        collate = None
        model = ShallowLSTMClassifier(len(feature_cols), params["hidden_size"], len(PREDICTION_TARGETS), dropout_val).to(DEVICE)

    if collate:
        train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True, collate_fn=collate)
        val_loader = DataLoader(val_ds, batch_size=params["batch_size"], shuffle=False, collate_fn=collate)
        test_loader = DataLoader(test_ds, batch_size=params["batch_size"], shuffle=False, collate_fn=collate)
    else:
        train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True)
        val_loader = DataLoader(val_ds, batch_size=params["batch_size"], shuffle=False)
        test_loader = DataLoader(test_ds, batch_size=params["batch_size"], shuffle=False)

    return model, train_loader, val_loader, test_loader


def evaluate_loader(model, loader, is_improved):
    model.eval()
    all_preds, all_targets, all_masks = [], [], []
    with torch.no_grad():
        for batch in loader:
            if is_improved:
                bx, by, bmask, lengths = batch
                logits = model(bx.to(DEVICE), lengths)
                all_masks.append(bmask.numpy())
            else:
                bx, by, bmask = batch
                logits = model(bx.to(DEVICE))
                all_masks.append(bmask.numpy())

            all_preds.append(logits.cpu().numpy())
            all_targets.append(by.numpy())

    if not all_preds:
        return None

    y_pred = np.vstack(all_preds)
    y_true = np.vstack(all_targets)

    if is_improved:
      print("MAX y_pred:", np.max(np.abs(y_pred)))
      print("MAX y_true:", np.max(np.abs(y_true)))
      y_pred = np.sign(y_pred) * np.expm1(np.abs(y_pred))
      y_true = np.sign(y_true) * np.expm1(np.abs(y_true))

    mask = np.vstack(all_masks)
    res = {}
    for i, t in enumerate(PREDICTION_TARGETS):
        m = mask[:, i]
        if m.sum() == 0:
            continue
        res[t] = np.mean(np.abs(y_pred[m, i] - y_true[m, i]))
    return res


def final_train_and_test(is_improved, params):
    model, train_loader, val_loader, test_loader = build_loaders_and_model(
        is_improved, params
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=params["lr"], weight_decay=params["weight_decay"])
    huber_delta = params.get("huber_delta", 1.0)

    model, _ = train_and_eval(
        model, train_loader, val_loader, optimizer,
        is_improved=is_improved, huber_delta=huber_delta
    )

    return evaluate_loader(model, test_loader, is_improved=is_improved)

def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)

N_RUNS = 20
print(f"Computing Final Test Metrics using Test Sets across {N_RUNS} runs...")
final_results = []

def run_multiple_times(pipeline_name, is_improved, best_params_dict):
    if "value" not in best_params_dict:
        return
    params = best_params_dict["value"]

    target_results = {t: [] for t in PREDICTION_TARGETS}
    for run_idx in range(N_RUNS):
        set_seed(SEED + run_idx)
        res = final_train_and_test(is_improved, params)
        for target, val in res.items():
            target_results[target].append(val)

    for target in PREDICTION_TARGETS:
        avg_mae = np.mean(target_results[target])
        std_mae = np.std(target_results[target])
        final_results.append({
            "Pipeline": pipeline_name,
            "Target": target,
            "Test MAE (Mean)": avg_mae,
            "Deviation": std_mae
        })
# Out:
# Computing Final Test Metrics using Test Sets across 20 runs...

# %%
mib_tickers = [
    "A2A", "AMPLIFON", "AZIMUT", "BANCA MEDIOLANUM", "BANCA MONTE DEI PASCHI",
    "BANCA PPO.DI SONDRIO", "BANCO BPM", "BPER BANCA", "BRUNELLO CUCINELLI",
    "BUZZI", "DAVIDE CAMPARI MILANO", "DIASORIN", "ENEL", "ENI",
    "FERRARI (MIL)", "FINCANTIERI", "FINECOBANK", "GENERALI", "HERA",
    "INFRASTRUTTURE WIRELESS ITALIANE NPV", "INTESANPAOLO", "ITALGAS",
    "IVECO", "LEONARDO", "LOTTOMATICA", "MEDIOBANCA BC.FIN", "MONCLER",
    "NEXI", "POSTE ITALIANE", "PRYSMIAN", "RECORDATI INDUA.CHIMICA",
    "SAIPEM", "SNAM", "STELLANTIS", "STMICROELECTRONICS (MIL)",
    "TELECOM ITALIA", "TENARIS", "TERNA RETE ELETTRICA NAZ", "UNICREDIT",
    "UNIPOL ASSICURAZIONI"
]

mid_tickers = [
    "ACEA", "ALERION CLEAN POWER", "ANIMA", "ARISTON",
    "ARNOLDO MONDADORI EDI.", "ASCOPIAVE", "AVIO", "BANCA GENERALI",
    "BANCA IFIS", "BFF BANK", "BNC.DI DESIO E DELB.", "CALTAGIRONE",
    "CAREL", "CEMBRE", "CEMENTIR", "COMPAGNIE INDUSTRIALI RIUNITE SHS",
    "CREDITO EMILIANO", "D'AMICO INTL.SHIP.", "DANIELI", "DATALOGIC",
    "DE LONGHI", "EL EN", "ENAV", "ERG", "FERRETTI (MIL)",
    "FIERA MILANO", "FRENI BREMBO", "GVS", "INTERCOS", "INTERPUMP",
    "IREN", "ITALMOBILIARE", "JUVENTUS FOOTBALL CLUB", "LUVE", "MARIE",
    "MARR", "MFE B", "MFE-MEDIAFOREUROPE", "MOLTIPLY", "NEWPRINCES",
    "OVS", "PHARMANUTRA", "PHILOGEN", "PIRELLI & C", "RAI WAY",
    "REPLY", "RIZZOLI CRER.DLSM.GP.", "SAFILO", "SALVATORE FERRAGAMO",
    "SANLORENZO", "SESA", "SOL", "TECHNOGYM", "TECHNOPROBE", "TINEXTA",
    "WEBUILD", "WIIT", "ZIGNAGO VETRO"
]

small_tickers = [
    "ABITARE IN", "AEDES", "AEFFE", "AEROP GUGL MARCO",
    "ALTEA GREEN POWER", "ANTARES VISION", "AQUAFIL", "B&C SPEAKERS",
    "BANCA PROFILO", "BANCA SISTEMA", "BASICNET", "BASTOGI", "BEEWIZE",
    "BIESSE", "BORGOSESIA", "BRIOSCHI SVILUPPO IMMBL", "CAIRO COMMUNICATION",
    "CALEFFI", "CALTAGIRONE EDITORE", "CELLULARLINE",
    "CENTRALE DEL LATTE D'ITALIA", "CLASS EDITORI", "CSP INTERNATIONAL",
    "CY4GATE", "DIGITAL BROS", "DIGITAL VALUE", "DOVALUE", "ELICA", "EMAK",
    "ENERVIT", "EPRICE", "EQUITA", "ESPRINET", "EUROGROUP LAMINATIONS A",
    "EUROTECH", "FIDIA", "FILA", "FNM", "GABETTI PROPERTY SLTN.",
    "GAROFALO HEALTH CARE", "GAS PLUS", "GEFRAN", "GENERALFINANCE",
    "GEOX", "GPI", "GRANDI VIAGGI", "IMMOBILIARE GRDE. DTBZ. SO.DI INVM.IMMB.",
    "IMMSI", "INDEL B", "INDUSTRIE DE NORA", "IRCE", "IT WAY",
    "ITALIAN DESIGN BRAND", "ITALIAN EXHIBITION", "ITALIAN SEA",
    "LANDI RENZO", "MET EXTRA", "MONDO TV", "NEODECORTECH", "OLIDATA",
    "OPS ITALIA", "OPS RETAIL", "ORSERO", "PININFARINA", "PIQUADRO",
    "PLC", "RATTI", "REVO INSURANCE", "RISANAMENTO", "SABAF", "SECO",
    "SERI INDUSTRIAL", "SIT", "SOFTLAB", "SOGEFI", "SOMEC", "SS LAZIO",
    "SYS-DAT", "TESMEC", "TESSELLIS", "TREVI FIN INDUSTRIALE", "TRIBOO",
    "TXT E-SOLUTION", "UNIDATA", "VALSOIA", "VINCENZO ZUCCHI", "ZEST"
]

ticker_groups = {"MIB": mib_tickers, "Mid-cap": mid_tickers, "Small-cap": small_tickers}

# %% [markdown]
# ## Core Training Logic & Optuna Integration

# %%
def train_and_eval(model, train_loader, val_loader, optimizer, is_improved, trial=None, loss_type='l1', huber_delta=1.0):
    if loss_type == 'l1':
        criterion = nn.L1Loss(reduction='none')
    elif loss_type == 'mse':
        criterion = nn.MSELoss(reduction='none')
    elif loss_type == 'huber':
        criterion = nn.HuberLoss(delta=huber_delta, reduction='none')
    else:
        raise ValueError(f"Unknown loss_type: {loss_type}")

    scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

    best_state = None
    best_metric = float("inf")
    epochs_without_improvement = 0

    for epoch in range(1, MAX_EPOCHS + 1):
        model.train()
        for batch in train_loader:
            optimizer.zero_grad(set_to_none=True)
            if is_improved:
                bx, by, bmask, lengths = batch
                bx, by, bmask = bx.to(DEVICE), by.to(DEVICE), bmask.to(DEVICE)
                logits = model(bx, lengths)
                loss_m = criterion(logits, by)
                loss = loss_m[bmask].mean() if loss_m[bmask].numel() > 0 else 0*loss_m.sum()
            else:
                bx, by, bmask = batch
                bx, by, bmask = bx.to(DEVICE), by.to(DEVICE), bmask.to(DEVICE)
                logits = model(bx)
                loss_m = criterion(logits, by)
                loss = loss_m[bmask].mean() if loss_m[bmask].numel() > 0 else 0*loss_m.sum()

            if isinstance(loss, torch.Tensor) and loss.requires_grad:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

        # Eval
        model.eval()
        all_preds = []
        all_targets = []
        all_masks = []
        with torch.no_grad():
            for batch in val_loader:
                if is_improved:
                    bx, by, bmask, lengths = batch
                    bx = bx.to(DEVICE)
                    logits = model(bx, lengths)
                    all_masks.append(bmask.numpy())
                else:
                    bx, by, bmask = batch
                    bx = bx.to(DEVICE)
                    logits = model(bx)
                    all_masks.append(bmask.numpy())

                all_preds.append(logits.cpu().numpy())
                all_targets.append(by.numpy())

        if len(all_preds) == 0:
            break

        y_pred = np.vstack(all_preds)
        y_true = np.vstack(all_targets)

        if is_improved:
            y_pred = np.sign(y_pred) * np.expm1(np.abs(y_pred))
            y_true = np.sign(y_true) * np.expm1(np.abs(y_true))

        mask = np.vstack(all_masks)
        valid_sum, count = 0, 0
        for i in range(len(PREDICTION_TARGETS)):
            m = mask[:, i]
            if m.sum() == 0: continue
            valid_sum += np.mean(np.abs(y_pred[m, i] - y_true[m, i]))
            count += 1
        current_metric = valid_sum / max(1, count)

        scheduler.step(current_metric)

        improved = current_metric < best_metric
        if improved:
            best_metric = current_metric
            best_state = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        if trial is not None:
            trial.report(current_metric, epoch)
            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

        if epochs_without_improvement >= PATIENCE:
            break

    if best_state is not None:
        model.load_state_dict(best_state)
    return model, best_metric

def get_hpo_objective(is_improved, loss_type='l1'):
    def objective(trial):
        hidden_size = trial.suggest_categorical("hidden_size", [32, 64, 128])
        lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
        batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
        weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
        dropout = trial.suggest_float("dropout", 0.2, 0.5)
        huber_delta = trial.suggest_float("huber_delta", 0.8, 2.0) if loss_type == 'huber' else 1.0


        if is_improved:
            train_ds = ImprovedYoYDatasetMTL(mtl_train_data_imp, robust_scaler, selected_indices)
            val_ds = ImprovedYoYDatasetMTL(mtl_val_data_imp, robust_scaler, selected_indices)
            collate = collate_fn_improved_mtl
            model = ImprovedShallowLSTM(len(selected_indices), hidden_size, len(PREDICTION_TARGETS), dropout).to(DEVICE)
        else:
            train_ds = YoYSequenceDatasetMTL(mtl_train_data, max_seq_length, scaler)
            val_ds = YoYSequenceDatasetMTL(mtl_val_data, max_seq_length, scaler)
            collate = None
            model = ShallowLSTMClassifier(len(feature_cols), hidden_size, len(PREDICTION_TARGETS), dropout).to(DEVICE)

        if collate:
            train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate)
            val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, collate_fn=collate)
        else:
            train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

        _, best_metric = train_and_eval(
            model, train_loader, val_loader, optimizer,
            is_improved=is_improved, trial=trial, loss_type=loss_type, huber_delta=huber_delta
        )
        return best_metric
    return objective

def evaluate_real_metrics(model, loader, device):
    model.eval()

    all_preds = []
    all_targets = []
    all_masks = []

    with torch.no_grad():

        for batch in loader:

            bx, by, bmask, lengths = batch

            preds = model(
                bx.to(device),
                lengths
            )

            all_preds.append(preds.cpu().numpy())
            all_targets.append(by.numpy())
            all_masks.append(bmask.numpy())

    y_pred = np.vstack(all_preds)
    y_true = np.vstack(all_targets)
    mask = np.vstack(all_masks).astype(bool)

    # back to real scale
    y_pred = np.sign(y_pred) * np.expm1(np.abs(y_pred))
    y_true = np.sign(y_true) * np.expm1(np.abs(y_true))

    errors = np.abs(y_pred - y_true)
    squared_errors = (y_pred - y_true) ** 2

    mae = errors[mask].mean()
    rmse = np.sqrt(squared_errors[mask].mean())

    print(f"Test MAE  (Real Scale): {mae:.4f}")
    print(f"Test RMSE (Real Scale): {rmse:.4f}")

    return float(mae), float(rmse)

# %% [markdown]
# # Training

# %% [markdown]
# ## Baseline MTL

# %%
print("Baseline MTL (Comparing Losses)")
best_mtl_baselines = {}
for l_type in ['l1', 'mse', 'huber']:
    print(f"\nEvaluating Baseline with '{l_type}' Loss...")
    pruner = optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=15)
    study = optuna.create_study(direction="minimize", study_name=f"mtl_base_{l_type}", pruner=pruner)
    study.optimize(get_hpo_objective(False, loss_type=l_type), n_trials=OPTUNA_TRIALS)
    best_mtl_baselines[l_type] = study.best_trial.params
    print(f"[{l_type.upper()} - MTL Base] Best Avg Val Metric (minimize): {study.best_value:.4f}")
    print(f" Best Params: {study.best_trial.params}")
# Out:
# [I 2026-06-11 15:30:26,553] A new study created in memory with name: mtl_base_l1
# Baseline MTL (Comparing Losses)
#
# Evaluating Baseline with 'l1' Loss...
# [I 2026-06-11 15:31:06,182] Trial 0 finished with value: 7.734981536865234 and parameters: {'hidden_size': 32, 'lr': 0.00027021834454844833, 'batch_size': 32, 'weight_decay': 1.3677599584464013e-05, 'dropout': 0.4246114507933375}. Best is trial 0 with value: 7.734981536865234.
# [I 2026-06-11 15:31:48,325] Trial 1 finished with value: 7.727621078491211 and parameters: {'hidden_size': 128, 'lr': 0.00039634279231945895, 'batch_size': 32, 'weight_decay': 1.2526423395815606e-06, 'dropout': 0.41565271051206143}. Best is trial 1 with value: 7.727621078491211.
# [I 2026-06-11 15:32:10,729] Trial 2 finished with value: 7.7255730628967285 and parameters: {'hidden_size': 32, 'lr': 0.0012034923138592923, 'batch_size': 64, 'weight_decay': 6.0834799575737164e-05, 'dropout': 0.30644071436319953}. Best is trial 2 with value: 7.7255730628967285.
# [I 2026-06-11 15:32:24,990] Trial 3 finished with value: 7.7104172706604 and parameters: {'hidden_size': 128, 'lr': 0.0010558210035945422, 'batch_size': 64, 'weight_decay': 0.0006194841377249081, 'dropout': 0.3432648432987221}. Best is trial 3 with value: 7.7104172706604.
# [I 2026-06-11 15:33:13,483] Trial 4 finished with value: 7.72498083114624 and parameters: {'hidden_size': 32, 'lr': 0.0001736538793035244, 'batch_size': 16, 'weight_decay': 9.870905240740717e-05, 'dropout': 0.26407622476616127}. Best is trial 3 with value: 7.7104172706604.
# [I 2026-06-11 15:33:34,730] Trial 5 finished with value: 7.70827054977417 and parameters: {'hidden_size': 32, 'lr': 0.0033298824226502387, 'batch_size': 16, 'weight_decay': 0.0002583035195278999, 'dropout': 0.4436715197144857}. Best is trial 5 with value: 7.70827054977417.
# [I 2026-06-11 15:33:51,087] Trial 6 finished with value: 7.7041096687316895 and parameters: {'hidden_size': 64, 'lr': 0.0026521870952558916, 'batch_size': 64, 'weight_decay': 0.000667318070082182, 'dropout': 0.33478748523476975}. Best is trial 6 with value: 7.7041096687316895.
# [I 2026-06-11 15:34:32,039] Trial 7 finished with value: 7.723221302032471 and parameters: {'hidden_size': 64, 'lr': 0.0001065707914098706, 'batch_size': 16, 'weight_decay': 3.360412690500287e-05, 'dropout': 0.4200218221133518}. Best is trial 6 with value: 7.7041096687316895.
# [I 2026-06-11 15:35:07,428] Trial 8 finished with value: 7.693379878997803 and parameters: {'hidden_size': 64, 'lr': 0.000177617109179785, 'batch_size': 16, 'weight_decay': 0.0008701026014502767, 'dropout': 0.49052075826305697}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:36:28,546] Trial 9 finished with value: 7.726699352264404 and parameters: {'hidden_size': 32, 'lr': 0.0002675448447361985, 'batch_size': 64, 'weight_decay': 7.073821476111232e-05, 'dropout': 0.32145812905647875}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:36:52,433] Trial 10 finished with value: 7.709419250488281 and parameters: {'hidden_size': 64, 'lr': 0.00870581265855902, 'batch_size': 16, 'weight_decay': 3.349908415468675e-06, 'dropout': 0.49414924227649826}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:37:17,453] Trial 11 finished with value: 7.717385768890381 and parameters: {'hidden_size': 64, 'lr': 0.0008356614340236801, 'batch_size': 64, 'weight_decay': 0.0009475987112308068, 'dropout': 0.21420815040115782}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:37:43,234] Trial 12 finished with value: 7.702723026275635 and parameters: {'hidden_size': 64, 'lr': 0.0032661298916545982, 'batch_size': 64, 'weight_decay': 0.0003013653356649718, 'dropout': 0.3721272853240933}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:37:56,335] Trial 13 finished with value: 7.70481538772583 and parameters: {'hidden_size': 64, 'lr': 0.00657677819358987, 'batch_size': 16, 'weight_decay': 0.00022628378897461896, 'dropout': 0.4984570507755955}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:38:15,246] Trial 14 finished with value: 7.707691192626953 and parameters: {'hidden_size': 64, 'lr': 0.0006125421282580249, 'batch_size': 32, 'weight_decay': 0.0002603422469441784, 'dropout': 0.38183279540828713}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:38:39,249] Trial 15 finished with value: 7.7081122398376465 and parameters: {'hidden_size': 64, 'lr': 0.001945012745627892, 'batch_size': 64, 'weight_decay': 0.00035723774609888525, 'dropout': 0.4627109855241055}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:39:00,328] Trial 16 finished with value: 7.697563648223877 and parameters: {'hidden_size': 64, 'lr': 0.003868172602102629, 'batch_size': 16, 'weight_decay': 0.0009529381239833849, 'dropout': 0.3830551241810888}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:39:15,249] Trial 17 finished with value: 7.696392059326172 and parameters: {'hidden_size': 128, 'lr': 0.005388629346146473, 'batch_size': 16, 'weight_decay': 0.0009856584545008778, 'dropout': 0.27598769250949395}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:39:32,502] Trial 18 pruned.
# [I 2026-06-11 15:39:51,422] Trial 19 finished with value: 7.69867467880249 and parameters: {'hidden_size': 128, 'lr': 0.0015456489243030674, 'batch_size': 16, 'weight_decay': 0.0004874937385700872, 'dropout': 0.20901583514957303}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:40:13,928] Trial 20 finished with value: 7.696929931640625 and parameters: {'hidden_size': 128, 'lr': 0.0005788268121679678, 'batch_size': 16, 'weight_decay': 2.863466061436509e-05, 'dropout': 0.27295631936946185}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:40:28,394] Trial 21 finished with value: 7.716818332672119 and parameters: {'hidden_size': 128, 'lr': 0.0005016255869188226, 'batch_size': 16, 'weight_decay': 1.1997897279431295e-05, 'dropout': 0.2737199666134702}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:40:47,073] Trial 22 pruned.
# [I 2026-06-11 15:41:03,763] Trial 23 pruned.
# [I 2026-06-11 15:41:20,941] Trial 24 pruned.
# [I 2026-06-11 15:41:41,778] Trial 25 finished with value: 7.708881378173828 and parameters: {'hidden_size': 128, 'lr': 0.0007320878197326419, 'batch_size': 16, 'weight_decay': 4.429136207033634e-06, 'dropout': 0.35973515701365455}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:42:05,842] Trial 26 finished with value: 7.701882839202881 and parameters: {'hidden_size': 128, 'lr': 0.0001559684255847785, 'batch_size': 32, 'weight_decay': 1.0000262237573081e-06, 'dropout': 0.305828386282438}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:42:27,279] Trial 27 finished with value: 7.707067966461182 and parameters: {'hidden_size': 128, 'lr': 0.002136676447636379, 'batch_size': 16, 'weight_decay': 3.433189523862046e-05, 'dropout': 0.23752037553027605}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:42:39,753] Trial 28 finished with value: 7.715043544769287 and parameters: {'hidden_size': 128, 'lr': 0.009297985191047868, 'batch_size': 16, 'weight_decay': 1.1151862131000264e-05, 'dropout': 0.4615113046786826}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:42:53,954] Trial 29 pruned.
# [I 2026-06-11 15:43:08,592] Trial 30 pruned.
# [I 2026-06-11 15:43:28,949] Trial 31 finished with value: 7.7028727531433105 and parameters: {'hidden_size': 64, 'lr': 0.005005814063464894, 'batch_size': 16, 'weight_decay': 0.00098888373058213, 'dropout': 0.3944908924416386}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:43:45,170] Trial 32 finished with value: 7.707101821899414 and parameters: {'hidden_size': 64, 'lr': 0.004506545993133173, 'batch_size': 16, 'weight_decay': 0.0007410254119032839, 'dropout': 0.44000231056965444}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:44:21,290] Trial 33 finished with value: 7.70225715637207 and parameters: {'hidden_size': 64, 'lr': 0.0013222033005150721, 'batch_size': 16, 'weight_decay': 1.992945157617604e-06, 'dropout': 0.34936162436555585}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:44:36,383] Trial 34 finished with value: 7.7062087059021 and parameters: {'hidden_size': 64, 'lr': 0.006592330482108397, 'batch_size': 32, 'weight_decay': 0.000540476647240083, 'dropout': 0.47702911605688814}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:45:03,886] Trial 35 finished with value: 7.697176456451416 and parameters: {'hidden_size': 128, 'lr': 0.0009689614449722305, 'batch_size': 16, 'weight_decay': 0.0009853079981611832, 'dropout': 0.3130780243120048}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:45:23,416] Trial 36 finished with value: 7.698286056518555 and parameters: {'hidden_size': 128, 'lr': 0.0009320890568550146, 'batch_size': 16, 'weight_decay': 0.00041966483115302443, 'dropout': 0.30827606860588913}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:45:49,882] Trial 37 finished with value: 7.708066463470459 and parameters: {'hidden_size': 128, 'lr': 0.0005434035464844247, 'batch_size': 16, 'weight_decay': 6.513381603097919e-05, 'dropout': 0.24949387707182946}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:46:18,648] Trial 38 finished with value: 7.708555221557617 and parameters: {'hidden_size': 128, 'lr': 0.00015687146065941038, 'batch_size': 16, 'weight_decay': 0.000648954131793482, 'dropout': 0.32719406820334995}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:46:36,434] Trial 39 pruned.
# [I 2026-06-11 15:46:56,979] Trial 40 finished with value: 7.6986403465271 and parameters: {'hidden_size': 128, 'lr': 0.001547947644550453, 'batch_size': 16, 'weight_decay': 4.2020260551186225e-05, 'dropout': 0.2184981059498455}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:47:07,923] Trial 41 finished with value: 7.698483943939209 and parameters: {'hidden_size': 64, 'lr': 0.0035576959464136606, 'batch_size': 16, 'weight_decay': 0.000996978842873715, 'dropout': 0.2582886576138532}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:47:35,537] Trial 42 finished with value: 7.710122585296631 and parameters: {'hidden_size': 32, 'lr': 0.0024131244806107096, 'batch_size': 16, 'weight_decay': 0.0006891530669149487, 'dropout': 0.27667832400419845}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:47:59,934] Trial 43 finished with value: 7.699314117431641 and parameters: {'hidden_size': 128, 'lr': 0.003742337068069782, 'batch_size': 16, 'weight_decay': 0.000369744167012993, 'dropout': 0.3079855988842618}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:48:29,666] Trial 44 finished with value: 7.699769496917725 and parameters: {'hidden_size': 64, 'lr': 0.007074588510945223, 'batch_size': 16, 'weight_decay': 0.0007594305953761921, 'dropout': 0.34209845235964287}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:48:42,134] Trial 45 pruned.
# [I 2026-06-11 15:48:56,692] Trial 46 finished with value: 7.7029194831848145 and parameters: {'hidden_size': 128, 'lr': 0.00281149030585022, 'batch_size': 16, 'weight_decay': 1.8882414877032315e-05, 'dropout': 0.4105748927734378}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:49:11,972] Trial 47 pruned.
# [I 2026-06-11 15:49:27,486] Trial 48 pruned.
# [I 2026-06-11 15:50:08,538] Trial 49 finished with value: 7.704579830169678 and parameters: {'hidden_size': 64, 'lr': 0.00045381421084513646, 'batch_size': 64, 'weight_decay': 0.000501506098855633, 'dropout': 0.22599030534794556}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:50:30,292] Trial 50 finished with value: 7.702064037322998 and parameters: {'hidden_size': 128, 'lr': 0.00023517462536717262, 'batch_size': 16, 'weight_decay': 0.0008316554473764497, 'dropout': 0.35631042957046744}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:50:49,319] Trial 51 finished with value: 7.696944713592529 and parameters: {'hidden_size': 128, 'lr': 0.0008089914463111383, 'batch_size': 16, 'weight_decay': 0.0003836642503360395, 'dropout': 0.3048584661171782}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:51:09,720] Trial 52 finished with value: 7.710653781890869 and parameters: {'hidden_size': 128, 'lr': 0.001004153420952161, 'batch_size': 16, 'weight_decay': 0.0006027361128014365, 'dropout': 0.29902216438464807}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:51:26,447] Trial 53 pruned.
# [I 2026-06-11 15:51:47,949] Trial 54 finished with value: 7.707098007202148 and parameters: {'hidden_size': 128, 'lr': 0.001843833023757215, 'batch_size': 16, 'weight_decay': 0.0002247759294749868, 'dropout': 0.2574978511762849}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:52:04,670] Trial 55 pruned.
# [I 2026-06-11 15:52:18,454] Trial 56 pruned.
# [I 2026-06-11 15:52:34,407] Trial 57 pruned.
# [I 2026-06-11 15:53:03,510] Trial 58 finished with value: 7.698439121246338 and parameters: {'hidden_size': 128, 'lr': 0.0008328855256325401, 'batch_size': 32, 'weight_decay': 0.0007699426793943406, 'dropout': 0.47724073260289385}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:53:27,235] Trial 59 finished with value: 7.7083516120910645 and parameters: {'hidden_size': 128, 'lr': 0.007775877331342711, 'batch_size': 16, 'weight_decay': 6.302355117645289e-06, 'dropout': 0.38809382058239295}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:53:41,358] Trial 60 finished with value: 7.712884426116943 and parameters: {'hidden_size': 64, 'lr': 0.004132475279920515, 'batch_size': 16, 'weight_decay': 0.00010949578754324246, 'dropout': 0.4559903259147273}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:53:58,039] Trial 61 finished with value: 7.694970607757568 and parameters: {'hidden_size': 128, 'lr': 0.0010513915623865948, 'batch_size': 16, 'weight_decay': 0.00039585275594164373, 'dropout': 0.30951091940676556}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:54:29,187] Trial 62 finished with value: 7.707450866699219 and parameters: {'hidden_size': 128, 'lr': 0.0008355576508044692, 'batch_size': 16, 'weight_decay': 0.0006183442183994295, 'dropout': 0.2917474457701691}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:54:52,079] Trial 63 finished with value: 7.704659938812256 and parameters: {'hidden_size': 128, 'lr': 0.0011490372389468997, 'batch_size': 16, 'weight_decay': 0.0003704868653579092, 'dropout': 0.301374395042097}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:55:16,913] Trial 64 finished with value: 7.700706958770752 and parameters: {'hidden_size': 128, 'lr': 0.0014600584555408904, 'batch_size': 16, 'weight_decay': 0.0008348911791939126, 'dropout': 0.31297519756629516}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:55:31,284] Trial 65 finished with value: 7.697134494781494 and parameters: {'hidden_size': 128, 'lr': 0.005648654349200322, 'batch_size': 16, 'weight_decay': 1.6508843087549314e-06, 'dropout': 0.36515584669342294}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:55:49,014] Trial 66 finished with value: 7.70521354675293 and parameters: {'hidden_size': 128, 'lr': 0.004950063816925921, 'batch_size': 16, 'weight_decay': 2.872434296823552e-06, 'dropout': 0.3681736474795704}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:56:10,531] Trial 67 finished with value: 7.699260234832764 and parameters: {'hidden_size': 128, 'lr': 0.0009341256241675408, 'batch_size': 16, 'weight_decay': 1.7281551354009058e-06, 'dropout': 0.2816153470834261}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:56:38,381] Trial 68 finished with value: 7.705116271972656 and parameters: {'hidden_size': 128, 'lr': 0.00020600052562079417, 'batch_size': 16, 'weight_decay': 4.7958215625889164e-05, 'dropout': 0.34320943403927745}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:57:00,145] Trial 69 finished with value: 7.709142208099365 and parameters: {'hidden_size': 128, 'lr': 0.0031484165422197424, 'batch_size': 64, 'weight_decay': 0.0002379902109388319, 'dropout': 0.20287696561733398}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:57:16,025] Trial 70 finished with value: 7.710328578948975 and parameters: {'hidden_size': 128, 'lr': 0.005764610145779863, 'batch_size': 32, 'weight_decay': 2.2889500144625446e-05, 'dropout': 0.327789869704335}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:57:31,899] Trial 71 finished with value: 7.694921493530273 and parameters: {'hidden_size': 128, 'lr': 0.001662760363245543, 'batch_size': 16, 'weight_decay': 0.0005093673445116835, 'dropout': 0.27049650608014947}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:57:46,383] Trial 72 finished with value: 7.700527667999268 and parameters: {'hidden_size': 128, 'lr': 0.00170202041967748, 'batch_size': 16, 'weight_decay': 0.0004519932575834732, 'dropout': 0.2684406105370398}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:58:01,722] Trial 73 finished with value: 7.7061944007873535 and parameters: {'hidden_size': 128, 'lr': 0.0006331589709963748, 'batch_size': 16, 'weight_decay': 8.403425750593197e-05, 'dropout': 0.2479387068872023}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:58:18,186] Trial 74 pruned.
# [I 2026-06-11 15:58:35,182] Trial 75 finished with value: 7.697563171386719 and parameters: {'hidden_size': 128, 'lr': 0.009956272322912518, 'batch_size': 16, 'weight_decay': 0.0005690162090285864, 'dropout': 0.2856071539945495}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:58:49,711] Trial 76 pruned.
# [I 2026-06-11 15:59:15,354] Trial 77 finished with value: 7.708425045013428 and parameters: {'hidden_size': 128, 'lr': 0.0023206858130584724, 'batch_size': 16, 'weight_decay': 0.00020166265591110169, 'dropout': 0.22836078438633228}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 15:59:43,808] Trial 78 finished with value: 7.710604190826416 and parameters: {'hidden_size': 128, 'lr': 0.0008161307571467217, 'batch_size': 16, 'weight_decay': 0.0008233399740461472, 'dropout': 0.273029355171653}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:00:01,994] Trial 79 finished with value: 7.7064385414123535 and parameters: {'hidden_size': 128, 'lr': 0.008197899943709728, 'batch_size': 16, 'weight_decay': 0.00038260562526176814, 'dropout': 0.31677168909944003}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:00:18,716] Trial 80 pruned.
# [I 2026-06-11 16:00:38,132] Trial 81 finished with value: 7.705094814300537 and parameters: {'hidden_size': 128, 'lr': 0.0068194929588986045, 'batch_size': 16, 'weight_decay': 0.0005590028435958246, 'dropout': 0.28488863090923805}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:01:04,385] Trial 82 finished with value: 7.700993061065674 and parameters: {'hidden_size': 128, 'lr': 0.005752072013572276, 'batch_size': 16, 'weight_decay': 0.0006812053817742259, 'dropout': 0.28934260066515616}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:01:21,198] Trial 83 pruned.
# [I 2026-06-11 16:01:38,213] Trial 84 pruned.
# [I 2026-06-11 16:01:52,076] Trial 85 finished with value: 7.708917140960693 and parameters: {'hidden_size': 128, 'lr': 0.0012776704380763428, 'batch_size': 16, 'weight_decay': 0.0003333335665876347, 'dropout': 0.24110163401019172}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:02:11,355] Trial 86 pruned.
# [I 2026-06-11 16:02:31,868] Trial 87 finished with value: 7.697988986968994 and parameters: {'hidden_size': 128, 'lr': 0.004471009333898394, 'batch_size': 32, 'weight_decay': 0.0008913590872017709, 'dropout': 0.2965128970531291}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:02:48,737] Trial 88 pruned.
# [I 2026-06-11 16:03:02,182] Trial 89 pruned.
# [I 2026-06-11 16:03:29,654] Trial 90 finished with value: 7.698554515838623 and parameters: {'hidden_size': 128, 'lr': 0.001955501073113515, 'batch_size': 16, 'weight_decay': 0.0004228101331052172, 'dropout': 0.32249359065559496}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:03:49,306] Trial 91 finished with value: 7.704547882080078 and parameters: {'hidden_size': 64, 'lr': 0.004016366861889135, 'batch_size': 16, 'weight_decay': 0.0009476104677052258, 'dropout': 0.33664989623600305}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:04:02,717] Trial 92 finished with value: 7.707253932952881 and parameters: {'hidden_size': 64, 'lr': 0.006136321105888485, 'batch_size': 16, 'weight_decay': 0.0005896686970670544, 'dropout': 0.4830751729574861}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:04:16,231] Trial 93 finished with value: 7.702756404876709 and parameters: {'hidden_size': 64, 'lr': 0.00880198893012676, 'batch_size': 16, 'weight_decay': 0.0007914084019146264, 'dropout': 0.4019852191602068}. Best is trial 8 with value: 7.693379878997803.
# [I 2026-06-11 16:04:29,538] Trial 94 finished with value: 7.693369388580322 and parameters: {'hidden_size': 64, 'lr': 0.007232524590277065, 'batch_size': 16, 'weight_decay': 0.0005087759150780066, 'dropout': 0.35589358244791597}. Best is trial 94 with value: 7.693369388580322.
# [I 2026-06-11 16:04:40,885] Trial 95 finished with value: 7.718494892120361 and parameters: {'hidden_size': 64, 'lr': 0.008564623006838124, 'batch_size': 16, 'weight_decay': 0.00028364343497297033, 'dropout': 0.3640675237089486}. Best is trial 94 with value: 7.693369388580322.
# [I 2026-06-11 16:04:56,169] Trial 96 finished with value: 7.693441867828369 and parameters: {'hidden_size': 64, 'lr': 0.00763790980265702, 'batch_size': 16, 'weight_decay': 0.0005056700729700437, 'dropout': 0.3487489027589542}. Best is trial 94 with value: 7.693369388580322.
# [I 2026-06-11 16:05:11,694] Trial 97 pruned.
# [I 2026-06-11 16:05:25,341] Trial 98 finished with value: 7.707608699798584 and parameters: {'hidden_size': 64, 'lr': 0.004892841813209894, 'batch_size': 16, 'weight_decay': 3.2349993916243224e-05, 'dropout': 0.3494654378750714}. Best is trial 94 with value: 7.693369388580322.
# [I 2026-06-11 16:05:56,215] Trial 99 finished with value: 7.708155155181885 and parameters: {'hidden_size': 64, 'lr': 0.0005993061179308855, 'batch_size': 16, 'weight_decay': 0.00038017426195793483, 'dropout': 0.332641722200115}. Best is trial 94 with value: 7.693369388580322.
# [I 2026-06-11 16:05:56,217] A new study created in memory with name: mtl_base_mse
# [L1 - MTL Base] Best Avg Val Metric (minimize): 7.6934
#  Best Params: {'hidden_size': 64, 'lr': 0.007232524590277065, 'batch_size': 16, 'weight_decay': 0.0005087759150780066, 'dropout': 0.35589358244791597}
#
# Evaluating Baseline with 'mse' Loss...
# [I 2026-06-11 16:06:08,343] Trial 0 finished with value: 7.731516361236572 and parameters: {'hidden_size': 128, 'lr': 0.0016671962506878606, 'batch_size': 64, 'weight_decay': 0.0007531177813081549, 'dropout': 0.47101734997273415}. Best is trial 0 with value: 7.731516361236572.
# [I 2026-06-11 16:06:20,391] Trial 1 finished with value: 7.774034023284912 and parameters: {'hidden_size': 64, 'lr': 0.00019673809324166486, 'batch_size': 64, 'weight_decay': 0.00033444281806840144, 'dropout': 0.4997670873946422}. Best is trial 0 with value: 7.731516361236572.
# [I 2026-06-11 16:06:37,621] Trial 2 finished with value: 7.721024036407471 and parameters: {'hidden_size': 64, 'lr': 0.0025468879533494387, 'batch_size': 32, 'weight_decay': 1.9455530835664114e-05, 'dropout': 0.4542862242923973}. Best is trial 2 with value: 7.721024036407471.
# [I 2026-06-11 16:06:51,647] Trial 3 finished with value: 7.717710971832275 and parameters: {'hidden_size': 128, 'lr': 0.005571127597457127, 'batch_size': 32, 'weight_decay': 5.539415297102192e-06, 'dropout': 0.4072937262142805}. Best is trial 3 with value: 7.717710971832275.
# [I 2026-06-11 16:07:17,141] Trial 4 finished with value: 7.738523006439209 and parameters: {'hidden_size': 32, 'lr': 0.0006349699611352354, 'batch_size': 32, 'weight_decay': 0.0004560478006140707, 'dropout': 0.44264478166801674}. Best is trial 3 with value: 7.717710971832275.
# [I 2026-06-11 16:07:28,827] Trial 5 finished with value: 7.73721170425415 and parameters: {'hidden_size': 64, 'lr': 0.00241472213577113, 'batch_size': 32, 'weight_decay': 0.00022715827626885844, 'dropout': 0.4941916848966311}. Best is trial 3 with value: 7.717710971832275.
# [I 2026-06-11 16:07:41,300] Trial 6 finished with value: 7.71679162979126 and parameters: {'hidden_size': 32, 'lr': 0.004882669880970777, 'batch_size': 32, 'weight_decay': 0.0002664270286645747, 'dropout': 0.3121318059830959}. Best is trial 6 with value: 7.71679162979126.
# [I 2026-06-11 16:07:58,138] Trial 7 finished with value: 7.728322505950928 and parameters: {'hidden_size': 128, 'lr': 0.00037787573717034176, 'batch_size': 16, 'weight_decay': 1.892154611025605e-06, 'dropout': 0.34123589780613195}. Best is trial 6 with value: 7.71679162979126.
# [I 2026-06-11 16:08:29,586] Trial 8 finished with value: 7.726507663726807 and parameters: {'hidden_size': 64, 'lr': 0.0001678993418151132, 'batch_size': 32, 'weight_decay': 2.6751150906860794e-05, 'dropout': 0.4499285453497416}. Best is trial 6 with value: 7.71679162979126.
# [I 2026-06-11 16:08:46,494] Trial 9 finished with value: 7.787288665771484 and parameters: {'hidden_size': 64, 'lr': 0.00032093578632885354, 'batch_size': 64, 'weight_decay': 2.778168529385919e-05, 'dropout': 0.3677200394445393}. Best is trial 6 with value: 7.71679162979126.
# [I 2026-06-11 16:08:59,346] Trial 10 finished with value: 7.703269958496094 and parameters: {'hidden_size': 32, 'lr': 0.009617258885110795, 'batch_size': 16, 'weight_decay': 7.665223281581029e-05, 'dropout': 0.22709669183478373}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:09:12,121] Trial 11 finished with value: 7.717113494873047 and parameters: {'hidden_size': 32, 'lr': 0.009595785225962017, 'batch_size': 16, 'weight_decay': 9.164841825996632e-05, 'dropout': 0.23374115502042375}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:09:40,671] Trial 12 finished with value: 7.712856292724609 and parameters: {'hidden_size': 32, 'lr': 0.009981114070644923, 'batch_size': 16, 'weight_decay': 0.0001026412399191645, 'dropout': 0.2315434155467788}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:09:59,657] Trial 13 finished with value: 7.716200351715088 and parameters: {'hidden_size': 32, 'lr': 0.008845454671111154, 'batch_size': 16, 'weight_decay': 7.726778946098566e-05, 'dropout': 0.2148452961215293}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:10:10,499] Trial 14 finished with value: 7.704899311065674 and parameters: {'hidden_size': 32, 'lr': 0.004645830568753374, 'batch_size': 16, 'weight_decay': 8.427435000746762e-05, 'dropout': 0.2675772869083798}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:10:26,503] Trial 15 pruned.
# [I 2026-06-11 16:10:56,001] Trial 16 finished with value: 7.707956790924072 and parameters: {'hidden_size': 32, 'lr': 0.004317704635525674, 'batch_size': 16, 'weight_decay': 6.112208970797083e-05, 'dropout': 0.2710891953914374}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:11:11,475] Trial 17 pruned.
# [I 2026-06-11 16:11:32,781] Trial 18 finished with value: 7.7256646156311035 and parameters: {'hidden_size': 32, 'lr': 0.000984063527608276, 'batch_size': 16, 'weight_decay': 4.4504125786438184e-05, 'dropout': 0.20221993152041948}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:11:54,795] Trial 19 finished with value: 7.7152228355407715 and parameters: {'hidden_size': 32, 'lr': 0.006432537876081705, 'batch_size': 16, 'weight_decay': 6.905112528580516e-06, 'dropout': 0.3083776975825974}. Best is trial 10 with value: 7.703269958496094.
# [I 2026-06-11 16:12:14,432] Trial 20 finished with value: 7.700791835784912 and parameters: {'hidden_size': 128, 'lr': 0.0027373765090469623, 'batch_size': 16, 'weight_decay': 0.00013680382451093643, 'dropout': 0.2464255007240333}. Best is trial 20 with value: 7.700791835784912.
# [I 2026-06-11 16:12:29,460] Trial 21 finished with value: 7.707810878753662 and parameters: {'hidden_size': 128, 'lr': 0.003031539234026581, 'batch_size': 16, 'weight_decay': 0.0001396202655697775, 'dropout': 0.2419773572125851}. Best is trial 20 with value: 7.700791835784912.
# [I 2026-06-11 16:12:50,809] Trial 22 finished with value: 7.71821403503418 and parameters: {'hidden_size': 128, 'lr': 0.0018873338249694495, 'batch_size': 16, 'weight_decay': 4.316814372481099e-05, 'dropout': 0.2570824297467884}. Best is trial 20 with value: 7.700791835784912.
# [I 2026-06-11 16:13:20,076] Trial 23 finished with value: 7.702280521392822 and parameters: {'hidden_size': 128, 'lr': 0.006558849376000975, 'batch_size': 16, 'weight_decay': 0.0009289078578176645, 'dropout': 0.3056587443281644}. Best is trial 20 with value: 7.700791835784912.
# [I 2026-06-11 16:13:40,228] Trial 24 finished with value: 7.698358058929443 and parameters: {'hidden_size': 128, 'lr': 0.006747809713564877, 'batch_size': 16, 'weight_decay': 0.0006683370292963869, 'dropout': 0.29977472432378044}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:14:01,340] Trial 25 finished with value: 7.720076084136963 and parameters: {'hidden_size': 128, 'lr': 0.006484642935911872, 'batch_size': 64, 'weight_decay': 0.0008514674851786853, 'dropout': 0.3240567796628676}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:14:31,006] Trial 26 finished with value: 7.724514007568359 and parameters: {'hidden_size': 128, 'lr': 0.00010079481280780472, 'batch_size': 16, 'weight_decay': 0.0006238008730261776, 'dropout': 0.35782134024772233}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:14:43,571] Trial 27 finished with value: 7.704372882843018 and parameters: {'hidden_size': 128, 'lr': 0.003410116145323439, 'batch_size': 16, 'weight_decay': 0.0009945157810622915, 'dropout': 0.29629305475907763}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:15:03,108] Trial 28 finished with value: 7.698655605316162 and parameters: {'hidden_size': 128, 'lr': 0.006859661489473491, 'batch_size': 16, 'weight_decay': 0.00045178845563876885, 'dropout': 0.39000642931792273}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:15:17,036] Trial 29 pruned.
# [I 2026-06-11 16:15:52,994] Trial 30 finished with value: 7.70833158493042 and parameters: {'hidden_size': 128, 'lr': 0.0020774298899435156, 'batch_size': 16, 'weight_decay': 0.000496080598653039, 'dropout': 0.41977730774520255}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:16:11,677] Trial 31 finished with value: 7.700135707855225 and parameters: {'hidden_size': 128, 'lr': 0.006882723573925349, 'batch_size': 16, 'weight_decay': 0.00030973226866493406, 'dropout': 0.33140414893036513}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:16:31,685] Trial 32 finished with value: 7.704405307769775 and parameters: {'hidden_size': 128, 'lr': 0.00685503344312612, 'batch_size': 16, 'weight_decay': 0.000373714567354867, 'dropout': 0.3347042039260056}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:16:43,738] Trial 33 finished with value: 7.72509241104126 and parameters: {'hidden_size': 128, 'lr': 0.0029956273435085166, 'batch_size': 64, 'weight_decay': 0.0002182495930251168, 'dropout': 0.37587190006870524}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:17:00,490] Trial 34 finished with value: 7.710340976715088 and parameters: {'hidden_size': 128, 'lr': 0.003975847705502389, 'batch_size': 16, 'weight_decay': 0.00014787390612668662, 'dropout': 0.3499609287063318}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:17:21,006] Trial 35 finished with value: 7.708296298980713 and parameters: {'hidden_size': 128, 'lr': 0.0074530493352341865, 'batch_size': 16, 'weight_decay': 0.00031203756847392254, 'dropout': 0.40674551802272235}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:17:38,598] Trial 36 finished with value: 7.712645053863525 and parameters: {'hidden_size': 128, 'lr': 0.0010805744497466923, 'batch_size': 16, 'weight_decay': 0.0005903320161947763, 'dropout': 0.2869900862513415}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:17:59,039] Trial 37 finished with value: 7.703515529632568 and parameters: {'hidden_size': 128, 'lr': 0.0025278153716993402, 'batch_size': 32, 'weight_decay': 0.00029169503888695476, 'dropout': 0.32530551089484167}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:18:09,126] Trial 38 finished with value: 7.736772060394287 and parameters: {'hidden_size': 128, 'lr': 0.00494534176875848, 'batch_size': 64, 'weight_decay': 0.00018238380593734075, 'dropout': 0.2512085124869228}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:18:20,497] Trial 39 finished with value: 7.727834224700928 and parameters: {'hidden_size': 64, 'lr': 0.005583658089348446, 'batch_size': 32, 'weight_decay': 0.0006615786237652485, 'dropout': 0.4711177120399611}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:18:32,831] Trial 40 finished with value: 7.703663349151611 and parameters: {'hidden_size': 128, 'lr': 0.005426460519873068, 'batch_size': 16, 'weight_decay': 0.00037337445788294195, 'dropout': 0.39240199032509676}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:18:48,911] Trial 41 finished with value: 7.704030513763428 and parameters: {'hidden_size': 128, 'lr': 0.007591527148058069, 'batch_size': 16, 'weight_decay': 0.0009629112197368228, 'dropout': 0.30485610043963596}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:19:12,724] Trial 42 finished with value: 7.720785617828369 and parameters: {'hidden_size': 128, 'lr': 0.007514393363001941, 'batch_size': 16, 'weight_decay': 1.3897203620806735e-06, 'dropout': 0.29471736400645193}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:19:35,140] Trial 43 finished with value: 7.714046478271484 and parameters: {'hidden_size': 128, 'lr': 0.0007228762872972656, 'batch_size': 16, 'weight_decay': 0.00026618505629905076, 'dropout': 0.3186458305109697}. Best is trial 24 with value: 7.698358058929443.
# [I 2026-06-11 16:19:49,997] Trial 44 finished with value: 7.6978759765625 and parameters: {'hidden_size': 64, 'lr': 0.0057524472764221195, 'batch_size': 16, 'weight_decay': 0.0005125507943385454, 'dropout': 0.4251182597214571}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:19:59,408] Trial 45 finished with value: 7.730095386505127 and parameters: {'hidden_size': 64, 'lr': 0.002854934769486142, 'batch_size': 32, 'weight_decay': 0.0001217580754467087, 'dropout': 0.4342943760733648}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:20:13,021] Trial 46 finished with value: 7.721208095550537 and parameters: {'hidden_size': 64, 'lr': 0.004135470233839112, 'batch_size': 16, 'weight_decay': 0.0004861548876279267, 'dropout': 0.45931927454984867}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:20:28,770] Trial 47 finished with value: 7.7052178382873535 and parameters: {'hidden_size': 64, 'lr': 0.0055120166713882495, 'batch_size': 16, 'weight_decay': 0.00024984287559218384, 'dropout': 0.42291792488856533}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:20:41,060] Trial 48 finished with value: 7.711140155792236 and parameters: {'hidden_size': 64, 'lr': 0.008600167293858412, 'batch_size': 16, 'weight_decay': 0.000686638454967673, 'dropout': 0.37421265859365027}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:20:59,842] Trial 49 finished with value: 7.719315052032471 and parameters: {'hidden_size': 64, 'lr': 0.002270132192048653, 'batch_size': 16, 'weight_decay': 0.0003898037133906353, 'dropout': 0.48483434291955874}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:21:22,429] Trial 50 finished with value: 7.721104145050049 and parameters: {'hidden_size': 64, 'lr': 0.004617421358068711, 'batch_size': 32, 'weight_decay': 0.00019675485777498455, 'dropout': 0.3971792137228094}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:21:49,514] Trial 51 finished with value: 7.702749729156494 and parameters: {'hidden_size': 128, 'lr': 0.006098681938762035, 'batch_size': 16, 'weight_decay': 0.0007699052262717883, 'dropout': 0.34061661288752765}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:22:03,105] Trial 52 finished with value: 7.7026801109313965 and parameters: {'hidden_size': 128, 'lr': 0.008484009274197266, 'batch_size': 16, 'weight_decay': 0.0005493022653990328, 'dropout': 0.3575971031207414}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:22:32,095] Trial 53 finished with value: 7.713138580322266 and parameters: {'hidden_size': 128, 'lr': 0.003495093485468158, 'batch_size': 16, 'weight_decay': 0.0003119873952383843, 'dropout': 0.26224695683814886}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:22:52,296] Trial 54 finished with value: 7.721799373626709 and parameters: {'hidden_size': 128, 'lr': 0.009647056878886867, 'batch_size': 16, 'weight_decay': 0.0004695580948071965, 'dropout': 0.28539441277539057}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:23:33,582] Trial 55 finished with value: 7.706201076507568 and parameters: {'hidden_size': 128, 'lr': 0.004888144465906098, 'batch_size': 16, 'weight_decay': 0.0007372017841871034, 'dropout': 0.4434090041655716}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:23:52,956] Trial 56 finished with value: 7.706676006317139 and parameters: {'hidden_size': 128, 'lr': 0.006495546388955782, 'batch_size': 16, 'weight_decay': 0.00011857954621945174, 'dropout': 0.42441651746260295}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:24:12,991] Trial 57 finished with value: 7.708049774169922 and parameters: {'hidden_size': 64, 'lr': 0.007688513161403705, 'batch_size': 16, 'weight_decay': 6.05809315735094e-05, 'dropout': 0.24599702272543544}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:24:24,152] Trial 58 finished with value: 7.751913547515869 and parameters: {'hidden_size': 128, 'lr': 0.003776395633042906, 'batch_size': 64, 'weight_decay': 0.00022144425483508793, 'dropout': 0.21891081747541513}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:24:36,754] Trial 59 finished with value: 7.73441743850708 and parameters: {'hidden_size': 128, 'lr': 0.000320470453543823, 'batch_size': 16, 'weight_decay': 0.000998810369620337, 'dropout': 0.30175682107811647}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:24:56,022] Trial 60 finished with value: 7.708185195922852 and parameters: {'hidden_size': 128, 'lr': 0.005842162858781216, 'batch_size': 16, 'weight_decay': 3.2504465108722057e-06, 'dropout': 0.38183315988188243}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:25:21,043] Trial 61 finished with value: 7.705819606781006 and parameters: {'hidden_size': 128, 'lr': 0.008372362699413794, 'batch_size': 16, 'weight_decay': 0.0005648020647799869, 'dropout': 0.3598676780664099}. Best is trial 44 with value: 7.6978759765625.
# [I 2026-06-11 16:25:34,742] Trial 62 finished with value: 7.695923328399658 and parameters: {'hidden_size': 128, 'lr': 0.008574128930311503, 'batch_size': 16, 'weight_decay': 0.0005486117924594846, 'dropout': 0.3343509687238012}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:25:51,079] Trial 63 finished with value: 7.699483871459961 and parameters: {'hidden_size': 128, 'lr': 0.006778078920705592, 'batch_size': 16, 'weight_decay': 0.0003905798226322537, 'dropout': 0.3297668842979756}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:26:23,133] Trial 64 finished with value: 7.71368408203125 and parameters: {'hidden_size': 128, 'lr': 0.004610449563746279, 'batch_size': 16, 'weight_decay': 0.0003957741135666308, 'dropout': 0.334519310823553}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:26:54,030] Trial 65 finished with value: 7.705329895019531 and parameters: {'hidden_size': 128, 'lr': 0.00966704363681293, 'batch_size': 16, 'weight_decay': 0.0001594128931966969, 'dropout': 0.3191311006508241}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:27:16,326] Trial 66 finished with value: 7.715128421783447 and parameters: {'hidden_size': 128, 'lr': 0.007208165434469831, 'batch_size': 16, 'weight_decay': 0.00033594833106065776, 'dropout': 0.3461425870930554}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:27:30,799] Trial 67 finished with value: 7.708845615386963 and parameters: {'hidden_size': 128, 'lr': 0.001625022197055491, 'batch_size': 16, 'weight_decay': 0.0002563004618810974, 'dropout': 0.40788623295737336}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:27:39,920] Trial 68 finished with value: 7.767240524291992 and parameters: {'hidden_size': 32, 'lr': 0.005304228963706067, 'batch_size': 64, 'weight_decay': 0.0004170925120458415, 'dropout': 0.3337527067137712}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:28:02,589] Trial 69 finished with value: 7.710447788238525 and parameters: {'hidden_size': 128, 'lr': 0.0030647994820075233, 'batch_size': 16, 'weight_decay': 0.0007108832826449332, 'dropout': 0.31469089628685304}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:28:17,301] Trial 70 finished with value: 7.70086669921875 and parameters: {'hidden_size': 64, 'lr': 0.006100814281651338, 'batch_size': 16, 'weight_decay': 1.3298452617720568e-05, 'dropout': 0.36508405591356885}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:28:29,944] Trial 71 finished with value: 7.711541652679443 and parameters: {'hidden_size': 64, 'lr': 0.008145221839245747, 'batch_size': 16, 'weight_decay': 1.3656148940536683e-05, 'dropout': 0.3681872363235751}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:28:46,056] Trial 72 finished with value: 7.7166876792907715 and parameters: {'hidden_size': 64, 'lr': 0.00618629215798206, 'batch_size': 16, 'weight_decay': 2.6271077237067707e-05, 'dropout': 0.36328862785490446}. Best is trial 62 with value: 7.695923328399658.
# [I 2026-06-11 16:29:04,399] Trial 73 finished with value: 7.695489406585693 and parameters: {'hidden_size': 64, 'lr': 0.006983818714746657, 'batch_size': 16, 'weight_decay': 5.675822110414546e-06, 'dropout': 0.3475448443627979}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:29:20,440] Trial 74 finished with value: 7.708168029785156 and parameters: {'hidden_size': 64, 'lr': 0.004314475134103838, 'batch_size': 16, 'weight_decay': 3.107006509810952e-06, 'dropout': 0.32745182446703797}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:29:40,683] Trial 75 finished with value: 7.714491367340088 and parameters: {'hidden_size': 64, 'lr': 0.006925524283069107, 'batch_size': 16, 'weight_decay': 7.534938512001078e-06, 'dropout': 0.3432776758468448}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:29:51,846] Trial 76 finished with value: 7.7102227210998535 and parameters: {'hidden_size': 128, 'lr': 0.009386865886474981, 'batch_size': 32, 'weight_decay': 0.0005408486840154801, 'dropout': 0.3524047088144849}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:30:06,876] Trial 77 finished with value: 7.704166889190674 and parameters: {'hidden_size': 128, 'lr': 0.006959205762779643, 'batch_size': 16, 'weight_decay': 0.0007949607115848699, 'dropout': 0.38177718150742407}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:30:23,215] Trial 78 finished with value: 7.713081359863281 and parameters: {'hidden_size': 128, 'lr': 0.008539243746862924, 'batch_size': 16, 'weight_decay': 0.0003342813422147338, 'dropout': 0.2826259147150443}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:30:35,814] Trial 79 finished with value: 7.712932109832764 and parameters: {'hidden_size': 32, 'lr': 0.005377054966805321, 'batch_size': 16, 'weight_decay': 0.0004341434807460308, 'dropout': 0.2955465523346021}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:30:47,087] Trial 80 finished with value: 7.7222981452941895 and parameters: {'hidden_size': 64, 'lr': 0.0038882468172873647, 'batch_size': 64, 'weight_decay': 4.064207149716467e-06, 'dropout': 0.4117225808264993}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:31:06,673] Trial 81 finished with value: 7.711964130401611 and parameters: {'hidden_size': 64, 'lr': 0.005740159049388741, 'batch_size': 16, 'weight_decay': 1.4561599697989593e-05, 'dropout': 0.3308177930603806}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:31:31,178] Trial 82 finished with value: 7.699791431427002 and parameters: {'hidden_size': 64, 'lr': 0.0066604349685926295, 'batch_size': 16, 'weight_decay': 9.66966836508976e-06, 'dropout': 0.3513762513532325}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:31:49,885] Trial 83 finished with value: 7.711416244506836 and parameters: {'hidden_size': 64, 'lr': 0.007661870122914292, 'batch_size': 16, 'weight_decay': 6.429945447205948e-06, 'dropout': 0.35445008143091866}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:32:13,284] Trial 84 finished with value: 7.721612453460693 and parameters: {'hidden_size': 64, 'lr': 0.005023498286861404, 'batch_size': 16, 'weight_decay': 4.872337540893389e-06, 'dropout': 0.3397195222707276}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:32:35,039] Trial 85 finished with value: 7.715184688568115 and parameters: {'hidden_size': 64, 'lr': 0.009953773086377984, 'batch_size': 16, 'weight_decay': 9.002811027539836e-06, 'dropout': 0.3084692140172914}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:33:09,975] Trial 86 finished with value: 7.71264123916626 and parameters: {'hidden_size': 128, 'lr': 0.004617856078129425, 'batch_size': 16, 'weight_decay': 2.3395850723293472e-06, 'dropout': 0.20296703023014603}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:33:27,532] Trial 87 finished with value: 7.699552059173584 and parameters: {'hidden_size': 128, 'lr': 0.0066417827791337624, 'batch_size': 16, 'weight_decay': 0.0006207842041814792, 'dropout': 0.32417091733794134}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:33:42,779] Trial 88 finished with value: 7.715318202972412 and parameters: {'hidden_size': 64, 'lr': 0.006497865656983833, 'batch_size': 32, 'weight_decay': 0.0005984746584883278, 'dropout': 0.3197319185664496}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:33:59,174] Trial 89 finished with value: 7.715013027191162 and parameters: {'hidden_size': 128, 'lr': 0.007242809419519219, 'batch_size': 16, 'weight_decay': 0.0008070628874840805, 'dropout': 0.3468594222133818}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:34:42,350] Trial 90 finished with value: 7.703189849853516 and parameters: {'hidden_size': 128, 'lr': 0.008708937348971903, 'batch_size': 16, 'weight_decay': 1.0638168784786438e-06, 'dropout': 0.31290285327975265}. Best is trial 73 with value: 7.695489406585693.
# [I 2026-06-11 16:35:00,640] Trial 91 finished with value: 7.7136616706848145 and parameters: {'hidden_size': 128, 'lr': 0.0033037210740185386, 'batch_size': 16, 'weight_decay': 0.0006490134454568615, 'dropout': 0.32349066612771943}. Best is trial 73 with value: 7.695489406585693.
# ...
# [I 2026-06-11 16:52:41,709] Trial 49 finished with value: 7.7009429931640625 and parameters: {'hidden_size': 128, 'lr': 0.007641626248760193, 'batch_size': 64, 'weight_decay': 1.8643822046198525e-05, 'dropout': 0.3069233111935837, 'huber_delta': 1.864997328568597}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:53:00,993] Trial 50 finished with value: 7.700479507446289 and parameters: {'hidden_size': 128, 'lr': 0.0046347049264667895, 'batch_size': 64, 'weight_decay': 6.802541091155724e-06, 'dropout': 0.3590536192887041, 'huber_delta': 1.7478612574291446}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:53:16,366] Trial 51 finished with value: 7.704408168792725 and parameters: {'hidden_size': 128, 'lr': 0.005929933640068945, 'batch_size': 64, 'weight_decay': 9.948808043541296e-06, 'dropout': 0.3257794725467008, 'huber_delta': 1.9648292947559234}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:53:42,672] Trial 52 finished with value: 7.705545902252197 and parameters: {'hidden_size': 128, 'lr': 0.007818517954622399, 'batch_size': 64, 'weight_decay': 1.50426642898666e-05, 'dropout': 0.26843786158204347, 'huber_delta': 1.9219947277780045}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:53:56,450] Trial 53 finished with value: 7.708927154541016 and parameters: {'hidden_size': 128, 'lr': 0.0037714386145646086, 'batch_size': 64, 'weight_decay': 4.250074172204831e-05, 'dropout': 0.38151515269673514, 'huber_delta': 1.792349730795073}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:54:08,606] Trial 54 finished with value: 7.697239398956299 and parameters: {'hidden_size': 128, 'lr': 0.006081621043301758, 'batch_size': 64, 'weight_decay': 3.145187445791268e-05, 'dropout': 0.25859237655218, 'huber_delta': 1.8905163658082278}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:54:20,670] Trial 55 finished with value: 7.701725006103516 and parameters: {'hidden_size': 128, 'lr': 0.0048812509210453625, 'batch_size': 64, 'weight_decay': 1.5085004911868916e-05, 'dropout': 0.30008915490905136, 'huber_delta': 1.8902230890581286}. Best is trial 48 with value: 7.6962432861328125.
# [I 2026-06-11 16:54:36,361] Trial 56 finished with value: 7.695962905883789 and parameters: {'hidden_size': 128, 'lr': 0.006368003091682352, 'batch_size': 64, 'weight_decay': 6.95352598804736e-05, 'dropout': 0.27689277302498083, 'huber_delta': 1.829269506231741}. Best is trial 56 with value: 7.695962905883789.
# [I 2026-06-11 16:54:49,531] Trial 57 finished with value: 7.698781490325928 and parameters: {'hidden_size': 128, 'lr': 0.006574782694013968, 'batch_size': 64, 'weight_decay': 6.861155524940449e-05, 'dropout': 0.2811154316453919, 'huber_delta': 1.8271797208138514}. Best is trial 56 with value: 7.695962905883789.
# [I 2026-06-11 16:55:01,863] Trial 58 finished with value: 7.694249629974365 and parameters: {'hidden_size': 128, 'lr': 0.008258414393755893, 'batch_size': 64, 'weight_decay': 0.0005003370851215999, 'dropout': 0.25881984639588684, 'huber_delta': 1.6341846432332245}. Best is trial 58 with value: 7.694249629974365.
# [I 2026-06-11 16:55:27,855] Trial 59 finished with value: 7.691688537597656 and parameters: {'hidden_size': 128, 'lr': 0.008413145419011104, 'batch_size': 64, 'weight_decay': 0.0006289798091665713, 'dropout': 0.25746791334752883, 'huber_delta': 1.6282774654565855}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:55:52,211] Trial 60 finished with value: 7.6933913230896 and parameters: {'hidden_size': 128, 'lr': 0.008578752205511663, 'batch_size': 64, 'weight_decay': 0.0005905870307711927, 'dropout': 0.27268905612968075, 'huber_delta': 1.6123351842283653}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:56:17,539] Trial 61 finished with value: 7.697107791900635 and parameters: {'hidden_size': 128, 'lr': 0.008801152726281108, 'batch_size': 64, 'weight_decay': 0.0006845977919455963, 'dropout': 0.25684604157533175, 'huber_delta': 1.6309978840066284}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:56:32,464] Trial 62 finished with value: 7.696469783782959 and parameters: {'hidden_size': 128, 'lr': 0.008893403397659256, 'batch_size': 64, 'weight_decay': 0.0006676733712424504, 'dropout': 0.29223764484860015, 'huber_delta': 1.6141210042319811}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:57:02,704] Trial 63 finished with value: 7.702049732208252 and parameters: {'hidden_size': 128, 'lr': 0.008467081708945516, 'batch_size': 64, 'weight_decay': 0.0004947702646249435, 'dropout': 0.2705819371629659, 'huber_delta': 1.5310457802271724}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:57:25,438] Trial 64 finished with value: 7.697320938110352 and parameters: {'hidden_size': 128, 'lr': 0.005635046575669027, 'batch_size': 64, 'weight_decay': 0.0009446699007921414, 'dropout': 0.3124901325474798, 'huber_delta': 1.6092670588937392}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:57:48,821] Trial 65 finished with value: 7.693154811859131 and parameters: {'hidden_size': 128, 'lr': 0.007130618629425062, 'batch_size': 64, 'weight_decay': 0.0003457362768798411, 'dropout': 0.2938396569297814, 'huber_delta': 1.7124580421724045}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:58:13,091] Trial 66 finished with value: 7.705026149749756 and parameters: {'hidden_size': 128, 'lr': 0.007198620339474116, 'batch_size': 64, 'weight_decay': 0.0002542265595575662, 'dropout': 0.27629951275064835, 'huber_delta': 1.7224912725975967}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:58:26,185] Trial 67 finished with value: 7.701765537261963 and parameters: {'hidden_size': 128, 'lr': 0.0098991570387452, 'batch_size': 64, 'weight_decay': 0.0003723112944452996, 'dropout': 0.3017697218842781, 'huber_delta': 1.685324715367265}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:58:41,981] Trial 68 finished with value: 7.6943230628967285 and parameters: {'hidden_size': 128, 'lr': 0.006585707915472929, 'batch_size': 64, 'weight_decay': 0.0005087173708777592, 'dropout': 0.29091720149715644, 'huber_delta': 1.5647204602314766}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:59:19,225] Trial 69 finished with value: 7.696002960205078 and parameters: {'hidden_size': 128, 'lr': 0.006841576613938588, 'batch_size': 64, 'weight_decay': 0.0004938060676729507, 'dropout': 0.2886321482586454, 'huber_delta': 1.5406296081737676}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:59:36,261] Trial 70 finished with value: 7.699110507965088 and parameters: {'hidden_size': 128, 'lr': 0.0043543072859881125, 'batch_size': 64, 'weight_decay': 0.00045928558799919304, 'dropout': 0.2860046343725443, 'huber_delta': 1.5210514325596383}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 16:59:53,731] Trial 71 finished with value: 7.698221683502197 and parameters: {'hidden_size': 128, 'lr': 0.006779868870781799, 'batch_size': 64, 'weight_decay': 0.00037510268530483506, 'dropout': 0.2910643509945257, 'huber_delta': 1.5463109823445051}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:00:05,909] Trial 72 finished with value: 7.700564861297607 and parameters: {'hidden_size': 128, 'lr': 0.007288550474806587, 'batch_size': 64, 'weight_decay': 0.000589273068928856, 'dropout': 0.30831972917523065, 'huber_delta': 1.4659636397098095}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:00:17,197] Trial 73 finished with value: 7.694326877593994 and parameters: {'hidden_size': 128, 'lr': 0.007890546541769811, 'batch_size': 64, 'weight_decay': 0.0001762373382893526, 'dropout': 0.2971470929514637, 'huber_delta': 1.6511102483648417}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:00:37,955] Trial 74 finished with value: 7.694971084594727 and parameters: {'hidden_size': 128, 'lr': 0.006250714010165696, 'batch_size': 64, 'weight_decay': 0.0003014356602863873, 'dropout': 0.26213120171201476, 'huber_delta': 1.5702807369985956}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:00:52,805] Trial 75 finished with value: 7.694438934326172 and parameters: {'hidden_size': 128, 'lr': 0.004941070631997087, 'batch_size': 64, 'weight_decay': 0.0001893376320166228, 'dropout': 0.25749193464897474, 'huber_delta': 1.6477811796438093}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:01:09,981] Trial 76 finished with value: 7.69992208480835 and parameters: {'hidden_size': 128, 'lr': 0.004948492828078454, 'batch_size': 16, 'weight_decay': 0.00018942125650126527, 'dropout': 0.23271775019912627, 'huber_delta': 1.6613872610612197}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:01:26,173] Trial 77 finished with value: 7.6992034912109375 and parameters: {'hidden_size': 32, 'lr': 0.008350119028537911, 'batch_size': 64, 'weight_decay': 0.00029512324657299336, 'dropout': 0.26041571362331023, 'huber_delta': 1.5832468480875594}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:01:36,069] Trial 78 finished with value: 7.701509952545166 and parameters: {'hidden_size': 128, 'lr': 0.004118842008481045, 'batch_size': 64, 'weight_decay': 0.00011975090376725348, 'dropout': 0.243912056300413, 'huber_delta': 1.4944878173591347}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:01:46,495] Trial 79 finished with value: 7.700392246246338 and parameters: {'hidden_size': 128, 'lr': 0.005200753941165246, 'batch_size': 64, 'weight_decay': 0.00018042291476089313, 'dropout': 0.25803678734245866, 'huber_delta': 1.7185519917933019}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:01:59,541] Trial 80 finished with value: 7.69649076461792 and parameters: {'hidden_size': 128, 'lr': 0.003278317441435018, 'batch_size': 64, 'weight_decay': 0.0008178181219286908, 'dropout': 0.32459630989033206, 'huber_delta': 1.650548645692316}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:02:21,153] Trial 81 finished with value: 7.704080104827881 and parameters: {'hidden_size': 128, 'lr': 0.006235738286240191, 'batch_size': 64, 'weight_decay': 0.00032013379585223156, 'dropout': 0.2793429223843117, 'huber_delta': 1.5673864667536883}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:02:36,759] Trial 82 finished with value: 7.698570728302002 and parameters: {'hidden_size': 128, 'lr': 0.009013863782367485, 'batch_size': 64, 'weight_decay': 0.0002416317959138042, 'dropout': 0.26923249000512645, 'huber_delta': 1.62210135343651}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:02:53,568] Trial 83 finished with value: 7.696701526641846 and parameters: {'hidden_size': 128, 'lr': 0.005966642369907897, 'batch_size': 64, 'weight_decay': 0.0004228130645760342, 'dropout': 0.29602898161492763, 'huber_delta': 1.6896180035203536}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:03:06,700] Trial 84 finished with value: 7.699778079986572 and parameters: {'hidden_size': 128, 'lr': 0.00980590741055799, 'batch_size': 64, 'weight_decay': 0.00015183064812689703, 'dropout': 0.2817664769409476, 'huber_delta': 1.445256584052892}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:03:17,471] Trial 85 finished with value: 7.699451446533203 and parameters: {'hidden_size': 128, 'lr': 0.007985936475444525, 'batch_size': 64, 'weight_decay': 0.0006546762849196945, 'dropout': 0.26496722190514305, 'huber_delta': 1.8054644576478103}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:03:37,225] Trial 86 finished with value: 7.6966729164123535 and parameters: {'hidden_size': 128, 'lr': 0.004663578264875489, 'batch_size': 16, 'weight_decay': 0.0003107455043345511, 'dropout': 0.2513026038477725, 'huber_delta': 1.7395986761626419}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:03:53,079] Trial 87 finished with value: 7.705587387084961 and parameters: {'hidden_size': 32, 'lr': 0.006499831416470587, 'batch_size': 64, 'weight_decay': 0.00010654736296069047, 'dropout': 0.2748299661337101, 'huber_delta': 1.5632858125991762}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:04:06,131] Trial 88 finished with value: 7.699262619018555 and parameters: {'hidden_size': 128, 'lr': 0.0037199128507143762, 'batch_size': 64, 'weight_decay': 0.0002765226978217361, 'dropout': 0.23879798101883398, 'huber_delta': 1.6074662284641814}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:04:19,089] Trial 89 finished with value: 7.699743747711182 and parameters: {'hidden_size': 128, 'lr': 0.005418275382758085, 'batch_size': 64, 'weight_decay': 0.00020507136153973552, 'dropout': 0.3166480435318298, 'huber_delta': 1.6610471838217236}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:04:31,194] Trial 90 finished with value: 7.697134494781494 and parameters: {'hidden_size': 128, 'lr': 0.007905710648817196, 'batch_size': 64, 'weight_decay': 0.0009981389489385497, 'dropout': 0.2501581809103226, 'huber_delta': 1.5963004704905235}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:04:54,477] Trial 91 finished with value: 7.694711685180664 and parameters: {'hidden_size': 128, 'lr': 0.00700234979707077, 'batch_size': 64, 'weight_decay': 0.0005510141390288233, 'dropout': 0.28702910835688017, 'huber_delta': 1.5149377761565133}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:05:09,238] Trial 92 finished with value: 7.704771041870117 and parameters: {'hidden_size': 128, 'lr': 0.007245607341126563, 'batch_size': 64, 'weight_decay': 0.0003498458550613029, 'dropout': 0.3012116456815229, 'huber_delta': 1.3928915936650852}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:05:21,503] Trial 93 finished with value: 7.693212985992432 and parameters: {'hidden_size': 128, 'lr': 0.006253479943859556, 'batch_size': 64, 'weight_decay': 0.0005753657772894695, 'dropout': 0.47349403429547027, 'huber_delta': 1.49196675060007}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:05:36,789] Trial 94 finished with value: 7.7053141593933105 and parameters: {'hidden_size': 128, 'lr': 0.005707312371739904, 'batch_size': 64, 'weight_decay': 0.0005569541380473151, 'dropout': 0.4927714562702681, 'huber_delta': 1.4994400032129007}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:05:51,715] Trial 95 finished with value: 7.698047161102295 and parameters: {'hidden_size': 128, 'lr': 0.008906977791057959, 'batch_size': 64, 'weight_decay': 0.0007312146315900522, 'dropout': 0.4183876215696692, 'huber_delta': 1.5579365683265487}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:06:03,787] Trial 96 finished with value: 7.697174072265625 and parameters: {'hidden_size': 128, 'lr': 0.00793798563508072, 'batch_size': 64, 'weight_decay': 0.0008378265303809051, 'dropout': 0.231314162181065, 'huber_delta': 1.4289846903664007}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:06:26,781] Trial 97 finished with value: 7.697133541107178 and parameters: {'hidden_size': 128, 'lr': 0.004872086381012446, 'batch_size': 64, 'weight_decay': 0.00042548036519562146, 'dropout': 0.4724312653590949, 'huber_delta': 1.6400117585380112}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:06:46,417] Trial 98 finished with value: 7.700042724609375 and parameters: {'hidden_size': 128, 'lr': 0.006834997283058677, 'batch_size': 64, 'weight_decay': 0.0005910609419567625, 'dropout': 0.45834248192602944, 'huber_delta': 1.4837269296086508}. Best is trial 59 with value: 7.691688537597656.
# [I 2026-06-11 17:07:06,755] Trial 99 pruned.
# [HUBER - MTL Base] Best Avg Val Metric (minimize): 7.6917
#  Best Params: {'hidden_size': 128, 'lr': 0.008413145419011104, 'batch_size': 64, 'weight_decay': 0.0006289798091665713, 'dropout': 0.25746791334752883, 'huber_delta': 1.6282774654565855}

# %% [markdown]
# ## Improved MTL

# %%
print("Improved MTL (Comparing Losses)")
best_mtl_imp = {}
for l_type in ['l1', 'mse', 'huber']:
    print(f"\nEvaluating Improved with '{l_type}' Loss...")
    pruner = optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=15)
    study = optuna.create_study(direction="minimize", study_name=f"mtl_imp_{l_type}", pruner=pruner)
    study.optimize(get_hpo_objective(True, loss_type=l_type), n_trials=OPTUNA_TRIALS)
    best_mtl_imp[l_type] = study.best_trial.params
    print(f"[{l_type.upper()} - MTL Imp] Best Avg Val Metric (minimize): {study.best_value:.4f}")
    print(f" Best Params: {study.best_trial.params}")
# Out:
# [I 2026-06-11 17:07:06,769] A new study created in memory with name: mtl_imp_l1
# Improved MTL (Comparing Losses)
#
# Evaluating Improved with 'l1' Loss...
# [I 2026-06-11 17:07:31,316] Trial 0 finished with value: 7.701366901397705 and parameters: {'hidden_size': 32, 'lr': 0.0024139890672852677, 'batch_size': 32, 'weight_decay': 0.0002959696821965418, 'dropout': 0.23589902019987782}. Best is trial 0 with value: 7.701366901397705.
# [I 2026-06-11 17:08:01,832] Trial 1 finished with value: 7.706565856933594 and parameters: {'hidden_size': 128, 'lr': 0.001408269408333342, 'batch_size': 64, 'weight_decay': 0.0001304058786395262, 'dropout': 0.4491912577242482}. Best is trial 0 with value: 7.701366901397705.
# [I 2026-06-11 17:08:50,368] Trial 2 finished with value: 7.731206893920898 and parameters: {'hidden_size': 32, 'lr': 0.0013644073140781634, 'batch_size': 16, 'weight_decay': 9.506414932444012e-06, 'dropout': 0.38269605005049245}. Best is trial 0 with value: 7.701366901397705.
# [I 2026-06-11 17:09:29,391] Trial 3 finished with value: 7.723430633544922 and parameters: {'hidden_size': 64, 'lr': 0.0006384612671005587, 'batch_size': 32, 'weight_decay': 1.5050206821225044e-05, 'dropout': 0.296152156527146}. Best is trial 0 with value: 7.701366901397705.
# [I 2026-06-11 17:09:56,623] Trial 4 finished with value: 7.6978302001953125 and parameters: {'hidden_size': 128, 'lr': 0.008872728895082563, 'batch_size': 32, 'weight_decay': 1.155517921173016e-05, 'dropout': 0.48553447949876216}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:10:45,351] Trial 5 finished with value: 7.698362827301025 and parameters: {'hidden_size': 32, 'lr': 0.00039233359800952994, 'batch_size': 32, 'weight_decay': 2.4665361134273968e-06, 'dropout': 0.4870021020060283}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:12:28,223] Trial 6 finished with value: 7.710638523101807 and parameters: {'hidden_size': 32, 'lr': 0.0006401960426850081, 'batch_size': 32, 'weight_decay': 4.833084475572998e-05, 'dropout': 0.4024174152938238}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:13:15,176] Trial 7 finished with value: 7.700655460357666 and parameters: {'hidden_size': 128, 'lr': 0.00020987045383297532, 'batch_size': 64, 'weight_decay': 0.0004662032501533612, 'dropout': 0.4000798578257357}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:13:34,493] Trial 8 finished with value: 7.714454174041748 and parameters: {'hidden_size': 32, 'lr': 0.003942228222387403, 'batch_size': 64, 'weight_decay': 2.1738579401128513e-05, 'dropout': 0.3686266514060548}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:14:15,063] Trial 9 finished with value: 7.7280707359313965 and parameters: {'hidden_size': 64, 'lr': 0.00013672751487760334, 'batch_size': 32, 'weight_decay': 6.517844789705592e-05, 'dropout': 0.3223668133066383}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:14:48,508] Trial 10 finished with value: 7.699031829833984 and parameters: {'hidden_size': 128, 'lr': 0.009676596321721001, 'batch_size': 16, 'weight_decay': 3.4918169041485934e-06, 'dropout': 0.23340097377998137}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:15:18,715] Trial 11 finished with value: 7.698238372802734 and parameters: {'hidden_size': 128, 'lr': 0.009264732501833593, 'batch_size': 32, 'weight_decay': 1.9569794240005315e-06, 'dropout': 0.49495291190060914}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:15:34,235] Trial 12 finished with value: 7.708436489105225 and parameters: {'hidden_size': 128, 'lr': 0.009824793628022306, 'batch_size': 32, 'weight_decay': 1.4032803534524062e-06, 'dropout': 0.4915488193450912}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:16:00,378] Trial 13 finished with value: 7.699832916259766 and parameters: {'hidden_size': 128, 'lr': 0.005228354668754737, 'batch_size': 32, 'weight_decay': 5.376760887283014e-06, 'dropout': 0.45201600005409154}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:16:30,315] Trial 14 finished with value: 7.705631256103516 and parameters: {'hidden_size': 128, 'lr': 0.005674145177711953, 'batch_size': 32, 'weight_decay': 1.395097843872569e-06, 'dropout': 0.456824862025595}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:17:02,319] Trial 15 finished with value: 7.70382833480835 and parameters: {'hidden_size': 128, 'lr': 0.0036175635394046592, 'batch_size': 16, 'weight_decay': 6.6385906679770275e-06, 'dropout': 0.4995982395129915}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:17:35,393] Trial 16 finished with value: 7.699047088623047 and parameters: {'hidden_size': 128, 'lr': 0.009677382449543564, 'batch_size': 32, 'weight_decay': 2.9184355048223932e-05, 'dropout': 0.43020040869375914}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:17:59,674] Trial 17 finished with value: 7.708189010620117 and parameters: {'hidden_size': 64, 'lr': 0.002272762760461325, 'batch_size': 32, 'weight_decay': 1.1023298530120914e-06, 'dropout': 0.46904082951913795}. Best is trial 4 with value: 7.6978302001953125.
# [I 2026-06-11 17:18:22,212] Trial 18 finished with value: 7.692906856536865 and parameters: {'hidden_size': 128, 'lr': 0.006241657632490772, 'batch_size': 16, 'weight_decay': 0.0009721043978511005, 'dropout': 0.4246512433535299}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:18:43,058] Trial 19 finished with value: 7.698673725128174 and parameters: {'hidden_size': 128, 'lr': 0.0054943238820472085, 'batch_size': 16, 'weight_decay': 0.0008035045125320082, 'dropout': 0.34832154739163723}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:19:27,146] Trial 20 finished with value: 7.7036614418029785 and parameters: {'hidden_size': 64, 'lr': 0.0024170275935557345, 'batch_size': 16, 'weight_decay': 0.00013406031761607518, 'dropout': 0.4177385584946107}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:19:46,200] Trial 21 finished with value: 7.707509517669678 and parameters: {'hidden_size': 128, 'lr': 0.006482495180784798, 'batch_size': 16, 'weight_decay': 2.6409621375474704e-06, 'dropout': 0.43740915166979955}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:20:13,676] Trial 22 finished with value: 7.698781490325928 and parameters: {'hidden_size': 128, 'lr': 0.00704674630048417, 'batch_size': 16, 'weight_decay': 0.00015863551908919542, 'dropout': 0.4737007081886465}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:20:31,590] Trial 23 pruned.
# [I 2026-06-11 17:21:04,290] Trial 24 finished with value: 7.694972991943359 and parameters: {'hidden_size': 128, 'lr': 0.003682224189375454, 'batch_size': 32, 'weight_decay': 0.0008796943787305438, 'dropout': 0.47139260939401734}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:21:44,311] Trial 25 finished with value: 7.6974196434021 and parameters: {'hidden_size': 128, 'lr': 0.0015981726240102368, 'batch_size': 16, 'weight_decay': 0.0008542913988073054, 'dropout': 0.46785667545690063}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:22:19,787] Trial 26 finished with value: 7.700929164886475 and parameters: {'hidden_size': 128, 'lr': 0.0014021071945880539, 'batch_size': 16, 'weight_decay': 0.0009429013645746255, 'dropout': 0.4052245964865983}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:22:55,771] Trial 27 finished with value: 7.70728063583374 and parameters: {'hidden_size': 128, 'lr': 0.0010129161266318257, 'batch_size': 16, 'weight_decay': 0.00045968098790211923, 'dropout': 0.368552591850359}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:23:39,632] Trial 28 finished with value: 7.70461893081665 and parameters: {'hidden_size': 64, 'lr': 0.0019324372352329928, 'batch_size': 16, 'weight_decay': 0.00048578930666597314, 'dropout': 0.46209352032923146}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:24:15,043] Trial 29 finished with value: 7.6984405517578125 and parameters: {'hidden_size': 128, 'lr': 0.0028530115705267126, 'batch_size': 16, 'weight_decay': 0.00026295546981086474, 'dropout': 0.4404108222780077}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:24:37,929] Trial 30 pruned.
# [I 2026-06-11 17:25:18,517] Trial 31 finished with value: 7.698812961578369 and parameters: {'hidden_size': 128, 'lr': 0.00476763219775163, 'batch_size': 32, 'weight_decay': 0.0007006947116808018, 'dropout': 0.47275151827436096}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:25:47,253] Trial 32 finished with value: 7.707124710083008 and parameters: {'hidden_size': 128, 'lr': 0.007144765548687019, 'batch_size': 64, 'weight_decay': 0.0002026034443239807, 'dropout': 0.20989252718246515}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:26:08,942] Trial 33 pruned.
# [I 2026-06-11 17:26:34,990] Trial 34 finished with value: 7.6985602378845215 and parameters: {'hidden_size': 128, 'lr': 0.0029553752321476333, 'batch_size': 16, 'weight_decay': 0.0005508081274048359, 'dropout': 0.446937826215904}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:27:07,430] Trial 35 finished with value: 7.699941635131836 and parameters: {'hidden_size': 128, 'lr': 0.004464320756792648, 'batch_size': 32, 'weight_decay': 0.0009427645209297446, 'dropout': 0.4119528521729925}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:27:26,492] Trial 36 pruned.
# [I 2026-06-11 17:27:42,661] Trial 37 pruned.
# [I 2026-06-11 17:28:05,922] Trial 38 finished with value: 7.701986312866211 and parameters: {'hidden_size': 128, 'lr': 0.007393541877132856, 'batch_size': 16, 'weight_decay': 0.0006492464805998248, 'dropout': 0.4550046385003285}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:28:23,960] Trial 39 pruned.
# [I 2026-06-11 17:28:58,323] Trial 40 finished with value: 7.706994533538818 and parameters: {'hidden_size': 64, 'lr': 0.0005449447430025562, 'batch_size': 64, 'weight_decay': 2.4785756981872036e-05, 'dropout': 0.28431576454327745}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:29:16,137] Trial 41 finished with value: 7.700927734375 and parameters: {'hidden_size': 128, 'lr': 0.008154357655323519, 'batch_size': 32, 'weight_decay': 3.982816211179829e-05, 'dropout': 0.49291605647533976}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:29:38,362] Trial 42 finished with value: 7.695993900299072 and parameters: {'hidden_size': 128, 'lr': 0.0041700812407893155, 'batch_size': 32, 'weight_decay': 1.636736521177607e-05, 'dropout': 0.4820027784484379}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:30:08,951] Trial 43 finished with value: 7.700721740722656 and parameters: {'hidden_size': 128, 'lr': 0.004300437719110865, 'batch_size': 32, 'weight_decay': 1.4680025706898143e-05, 'dropout': 0.48196763054461156}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:30:28,901] Trial 44 finished with value: 7.704870223999023 and parameters: {'hidden_size': 128, 'lr': 0.0031005498395012946, 'batch_size': 32, 'weight_decay': 8.171099573452413e-06, 'dropout': 0.4628877054299534}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:30:46,868] Trial 45 finished with value: 7.701313018798828 and parameters: {'hidden_size': 128, 'lr': 0.002370354536419662, 'batch_size': 32, 'weight_decay': 1.8085948675170112e-05, 'dropout': 0.39117292769651935}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:31:05,556] Trial 46 pruned.
# [I 2026-06-11 17:31:35,992] Trial 47 finished with value: 7.707239627838135 and parameters: {'hidden_size': 32, 'lr': 0.0039026929875667295, 'batch_size': 32, 'weight_decay': 0.0009936759363147311, 'dropout': 0.4853913979515509}. Best is trial 18 with value: 7.692906856536865.
# [I 2026-06-11 17:31:53,379] Trial 48 finished with value: 7.6897501945495605 and parameters: {'hidden_size': 128, 'lr': 0.008348762109208775, 'batch_size': 16, 'weight_decay': 0.0003772961969983845, 'dropout': 0.49991817673879335}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:32:37,878] Trial 49 finished with value: 7.698436737060547 and parameters: {'hidden_size': 128, 'lr': 0.005690679024903338, 'batch_size': 16, 'weight_decay': 0.00040019462679485407, 'dropout': 0.49816288567251077}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:33:18,235] Trial 50 finished with value: 7.696570873260498 and parameters: {'hidden_size': 128, 'lr': 0.004673827445951261, 'batch_size': 16, 'weight_decay': 0.0006709369144903646, 'dropout': 0.46359942202307164}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:33:40,878] Trial 51 finished with value: 7.695026874542236 and parameters: {'hidden_size': 128, 'lr': 0.0048479995582414465, 'batch_size': 16, 'weight_decay': 0.0006342066782135947, 'dropout': 0.4596892954816508}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:34:16,075] Trial 52 finished with value: 7.697971820831299 and parameters: {'hidden_size': 128, 'lr': 0.00474758176390975, 'batch_size': 16, 'weight_decay': 0.0005810040476045042, 'dropout': 0.4527083375243199}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:34:37,006] Trial 53 finished with value: 7.700781345367432 and parameters: {'hidden_size': 128, 'lr': 0.0036065438690228457, 'batch_size': 16, 'weight_decay': 0.00036603780958376054, 'dropout': 0.4211025130883919}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:34:56,598] Trial 54 finished with value: 7.698888301849365 and parameters: {'hidden_size': 128, 'lr': 0.008261245537860845, 'batch_size': 16, 'weight_decay': 0.0006727697322367796, 'dropout': 0.4789444388063675}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:35:24,590] Trial 55 finished with value: 7.7009758949279785 and parameters: {'hidden_size': 64, 'lr': 0.005121319278556667, 'batch_size': 16, 'weight_decay': 0.00031603450655200805, 'dropout': 0.46276863408898966}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:35:46,429] Trial 56 finished with value: 7.70204496383667 and parameters: {'hidden_size': 128, 'lr': 0.006157941152721832, 'batch_size': 16, 'weight_decay': 0.000525225690823923, 'dropout': 0.43048463053984815}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:36:43,372] Trial 57 pruned.
# [I 2026-06-11 17:37:11,783] Trial 58 finished with value: 7.696495056152344 and parameters: {'hidden_size': 128, 'lr': 0.0028935184842715884, 'batch_size': 16, 'weight_decay': 0.0002555042496867447, 'dropout': 0.44307927387695956}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:37:31,791] Trial 59 finished with value: 7.69796895980835 and parameters: {'hidden_size': 128, 'lr': 0.0026493750136652346, 'batch_size': 16, 'weight_decay': 0.00025285666401461134, 'dropout': 0.44684197648333046}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:37:56,212] Trial 60 pruned.
# [I 2026-06-11 17:38:24,358] Trial 61 finished with value: 7.700462341308594 and parameters: {'hidden_size': 128, 'lr': 0.0033625508969151083, 'batch_size': 16, 'weight_decay': 0.00045016364040457687, 'dropout': 0.46673753807916574}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:38:55,709] Trial 62 finished with value: 7.696218967437744 and parameters: {'hidden_size': 128, 'lr': 0.004191206382443217, 'batch_size': 16, 'weight_decay': 0.00010237373927330744, 'dropout': 0.4368801233566821}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:39:31,408] Trial 63 finished with value: 7.698354244232178 and parameters: {'hidden_size': 128, 'lr': 0.004213383728790458, 'batch_size': 16, 'weight_decay': 0.00020364575646695312, 'dropout': 0.4077988115742455}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:40:06,959] Trial 64 finished with value: 7.704570770263672 and parameters: {'hidden_size': 128, 'lr': 0.0026839684256113184, 'batch_size': 16, 'weight_decay': 9.20811932256307e-05, 'dropout': 0.42336679512473635}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:40:42,255] Trial 65 finished with value: 7.702461242675781 and parameters: {'hidden_size': 64, 'lr': 0.0038379863465066127, 'batch_size': 16, 'weight_decay': 0.0003467495949775132, 'dropout': 0.39610581126038114}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:41:01,062] Trial 66 finished with value: 7.69805383682251 and parameters: {'hidden_size': 128, 'lr': 0.007103236922380092, 'batch_size': 64, 'weight_decay': 0.0002682451960401377, 'dropout': 0.4387381404765624}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:41:22,385] Trial 67 finished with value: 7.70569372177124 and parameters: {'hidden_size': 128, 'lr': 0.0055419563378282955, 'batch_size': 16, 'weight_decay': 0.00010540616216002456, 'dropout': 0.45470479683559056}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:41:46,722] Trial 68 pruned.
# [I 2026-06-11 17:42:08,842] Trial 69 finished with value: 7.6982293128967285 and parameters: {'hidden_size': 128, 'lr': 0.009514796997080077, 'batch_size': 16, 'weight_decay': 5.5347964451082816e-05, 'dropout': 0.4733373619033496}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:42:45,847] Trial 70 finished with value: 7.703184604644775 and parameters: {'hidden_size': 128, 'lr': 0.00325358303880207, 'batch_size': 16, 'weight_decay': 3.201448810606734e-05, 'dropout': 0.4279421491998643}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:43:19,398] Trial 71 finished with value: 7.699137210845947 and parameters: {'hidden_size': 128, 'lr': 0.005021135974797104, 'batch_size': 16, 'weight_decay': 0.0005370410713927629, 'dropout': 0.4599681115367829}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:43:50,813] Trial 72 finished with value: 7.695168972015381 and parameters: {'hidden_size': 128, 'lr': 0.0041592173373676275, 'batch_size': 16, 'weight_decay': 0.0007877355911958448, 'dropout': 0.41480199781565114}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:44:09,651] Trial 73 finished with value: 7.700059413909912 and parameters: {'hidden_size': 128, 'lr': 0.006453814996453557, 'batch_size': 16, 'weight_decay': 0.0008161353707051451, 'dropout': 0.41348630122086955}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:44:46,514] Trial 74 finished with value: 7.69036865234375 and parameters: {'hidden_size': 128, 'lr': 0.0040324455646106, 'batch_size': 16, 'weight_decay': 0.0004265628005127177, 'dropout': 0.436171181918765}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:45:27,941] Trial 75 finished with value: 7.6984543800354 and parameters: {'hidden_size': 128, 'lr': 0.003995347338561471, 'batch_size': 16, 'weight_decay': 0.00042171163495259947, 'dropout': 0.418195338176888}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:45:54,688] Trial 76 finished with value: 7.69978666305542 and parameters: {'hidden_size': 128, 'lr': 0.005582695617052409, 'batch_size': 32, 'weight_decay': 0.0005706953477128393, 'dropout': 0.4357551434196222}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:46:20,844] Trial 77 finished with value: 7.698962688446045 and parameters: {'hidden_size': 128, 'lr': 0.0034779917171313597, 'batch_size': 64, 'weight_decay': 0.0009418947938686283, 'dropout': 0.4800396826380775}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:47:00,831] Trial 78 finished with value: 7.703977108001709 and parameters: {'hidden_size': 64, 'lr': 0.008509459821386307, 'batch_size': 16, 'weight_decay': 0.00017352040758305626, 'dropout': 0.40397251459610534}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:47:32,950] Trial 79 finished with value: 7.7013936042785645 and parameters: {'hidden_size': 128, 'lr': 0.004549320788461892, 'batch_size': 32, 'weight_decay': 0.00046773160518501114, 'dropout': 0.36126929924528756}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:48:03,159] Trial 80 finished with value: 7.701198577880859 and parameters: {'hidden_size': 32, 'lr': 0.0066869677519454, 'batch_size': 16, 'weight_decay': 0.0007124411040733631, 'dropout': 0.4874677976431718}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:48:31,821] Trial 81 finished with value: 7.706930160522461 and parameters: {'hidden_size': 128, 'lr': 0.0028847554678947513, 'batch_size': 16, 'weight_decay': 0.00030087791825345186, 'dropout': 0.4496498833589355}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:49:02,331] Trial 82 finished with value: 7.705501556396484 and parameters: {'hidden_size': 128, 'lr': 0.002548496574587511, 'batch_size': 16, 'weight_decay': 0.0002227513958600791, 'dropout': 0.440982972839263}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:49:27,316] Trial 83 finished with value: 7.70059061050415 and parameters: {'hidden_size': 128, 'lr': 0.003939364751390514, 'batch_size': 16, 'weight_decay': 0.0003919775256928031, 'dropout': 0.429815894484612}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:50:04,988] Trial 84 finished with value: 7.698880672454834 and parameters: {'hidden_size': 128, 'lr': 0.0030743454990796444, 'batch_size': 16, 'weight_decay': 0.0005873095010706054, 'dropout': 0.46959234973659997}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:50:37,299] Trial 85 finished with value: 7.695522785186768 and parameters: {'hidden_size': 128, 'lr': 0.002203494618286979, 'batch_size': 32, 'weight_decay': 0.0007979493886626388, 'dropout': 0.41317791665930825}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:50:57,167] Trial 86 finished with value: 7.700016021728516 and parameters: {'hidden_size': 128, 'lr': 0.002292894239428609, 'batch_size': 32, 'weight_decay': 0.0008489551925897244, 'dropout': 0.3973409801722396}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:51:22,785] Trial 87 finished with value: 7.69751501083374 and parameters: {'hidden_size': 128, 'lr': 0.0019796132891566225, 'batch_size': 32, 'weight_decay': 0.0007310014173355287, 'dropout': 0.41308295875095896}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:51:44,273] Trial 88 finished with value: 7.701429843902588 and parameters: {'hidden_size': 128, 'lr': 0.005095699034796854, 'batch_size': 32, 'weight_decay': 0.0006380592184457386, 'dropout': 0.2692279260720945}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:52:03,133] Trial 89 finished with value: 7.694217205047607 and parameters: {'hidden_size': 128, 'lr': 0.005996999631517591, 'batch_size': 32, 'weight_decay': 0.0009716410775282007, 'dropout': 0.4550785236715035}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:52:21,301] Trial 90 finished with value: 7.69854211807251 and parameters: {'hidden_size': 128, 'lr': 0.0062676326889820775, 'batch_size': 32, 'weight_decay': 0.000999472716052381, 'dropout': 0.4915376332560234}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:52:59,547] Trial 91 finished with value: 7.701927185058594 and parameters: {'hidden_size': 128, 'lr': 0.0044042127129115686, 'batch_size': 32, 'weight_decay': 0.0008022448671070108, 'dropout': 0.4569500532029257}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:53:19,825] Trial 92 finished with value: 7.69934606552124 and parameters: {'hidden_size': 128, 'lr': 0.00576687072771432, 'batch_size': 32, 'weight_decay': 0.0005104696634536044, 'dropout': 0.4224460577208562}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:53:52,411] Trial 93 finished with value: 7.695688724517822 and parameters: {'hidden_size': 128, 'lr': 0.007292139228460727, 'batch_size': 32, 'weight_decay': 0.0006395390436408846, 'dropout': 0.43529639222486205}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:54:19,308] Trial 94 finished with value: 7.693291187286377 and parameters: {'hidden_size': 128, 'lr': 0.00882780862401945, 'batch_size': 32, 'weight_decay': 0.0009979003664375445, 'dropout': 0.47323169710016516}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:54:34,548] Trial 95 finished with value: 7.694400787353516 and parameters: {'hidden_size': 128, 'lr': 0.009040660926693521, 'batch_size': 32, 'weight_decay': 0.00061937204551797, 'dropout': 0.449519932317927}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:54:52,570] Trial 96 finished with value: 7.6994309425354 and parameters: {'hidden_size': 128, 'lr': 0.008890554427724039, 'batch_size': 32, 'weight_decay': 0.0008648707222721494, 'dropout': 0.4729645782048769}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:55:06,554] Trial 97 finished with value: 7.694765567779541 and parameters: {'hidden_size': 128, 'lr': 0.008192175830063883, 'batch_size': 32, 'weight_decay': 0.0004683777628209775, 'dropout': 0.4493180861058203}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:55:28,382] Trial 98 finished with value: 7.696636199951172 and parameters: {'hidden_size': 64, 'lr': 0.007924001382467337, 'batch_size': 32, 'weight_decay': 0.00043767180589632704, 'dropout': 0.4490277116076156}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:55:55,168] Trial 99 finished with value: 7.697700500488281 and parameters: {'hidden_size': 128, 'lr': 0.00987087130737519, 'batch_size': 32, 'weight_decay': 0.00034932768547231685, 'dropout': 0.45983977505420476}. Best is trial 48 with value: 7.6897501945495605.
# [I 2026-06-11 17:55:55,169] A new study created in memory with name: mtl_imp_mse
# [L1 - MTL Imp] Best Avg Val Metric (minimize): 7.6898
#  Best Params: {'hidden_size': 128, 'lr': 0.008348762109208775, 'batch_size': 16, 'weight_decay': 0.0003772961969983845, 'dropout': 0.49991817673879335}
#
# Evaluating Improved with 'mse' Loss...
# [I 2026-06-11 17:56:13,972] Trial 0 finished with value: 7.715034484863281 and parameters: {'hidden_size': 64, 'lr': 0.005657564844887007, 'batch_size': 32, 'weight_decay': 1.1956166142407548e-05, 'dropout': 0.2811120124638329}. Best is trial 0 with value: 7.715034484863281.
# [I 2026-06-11 17:56:31,635] Trial 1 finished with value: 7.710878849029541 and parameters: {'hidden_size': 128, 'lr': 0.0008395790355842682, 'batch_size': 64, 'weight_decay': 2.100861932496224e-05, 'dropout': 0.4027890867083891}. Best is trial 1 with value: 7.710878849029541.
# [I 2026-06-11 17:56:53,364] Trial 2 finished with value: 7.715019226074219 and parameters: {'hidden_size': 128, 'lr': 0.000675871678577033, 'batch_size': 32, 'weight_decay': 3.058188653991013e-05, 'dropout': 0.41100144469377}. Best is trial 1 with value: 7.710878849029541.
# [I 2026-06-11 17:57:20,669] Trial 3 finished with value: 7.725275039672852 and parameters: {'hidden_size': 128, 'lr': 0.0003477645110796511, 'batch_size': 32, 'weight_decay': 0.000773498437981121, 'dropout': 0.31097748012034515}. Best is trial 1 with value: 7.710878849029541.
# [I 2026-06-11 17:57:43,786] Trial 4 finished with value: 7.70343017578125 and parameters: {'hidden_size': 128, 'lr': 0.0014177619133566603, 'batch_size': 16, 'weight_decay': 0.0006469137285048024, 'dropout': 0.4304315711281208}. Best is trial 4 with value: 7.70343017578125.
# [I 2026-06-11 17:57:59,007] Trial 5 finished with value: 7.701974868774414 and parameters: {'hidden_size': 32, 'lr': 0.008281387656300066, 'batch_size': 64, 'weight_decay': 3.34511959417973e-05, 'dropout': 0.2549539022666259}. Best is trial 5 with value: 7.701974868774414.
# [I 2026-06-11 17:58:39,063] Trial 6 finished with value: 7.730262279510498 and parameters: {'hidden_size': 64, 'lr': 0.0011997951329199672, 'batch_size': 64, 'weight_decay': 7.99910093762153e-06, 'dropout': 0.4190096404393392}. Best is trial 5 with value: 7.701974868774414.
# [I 2026-06-11 17:59:06,639] Trial 7 finished with value: 7.70272970199585 and parameters: {'hidden_size': 64, 'lr': 0.009972987093178662, 'batch_size': 16, 'weight_decay': 1.1830597155653354e-06, 'dropout': 0.48652547979230476}. Best is trial 5 with value: 7.701974868774414.
# [I 2026-06-11 17:59:30,623] Trial 8 finished with value: 7.7009453773498535 and parameters: {'hidden_size': 64, 'lr': 0.008999867521358661, 'batch_size': 32, 'weight_decay': 6.980210700735744e-06, 'dropout': 0.43681745137669836}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 17:59:49,430] Trial 9 finished with value: 7.705281734466553 and parameters: {'hidden_size': 64, 'lr': 0.0037212756671217754, 'batch_size': 32, 'weight_decay': 4.1789992745584715e-05, 'dropout': 0.28740820305850834}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:00:08,399] Trial 10 pruned.
# [I 2026-06-11 18:00:23,724] Trial 11 pruned.
# [I 2026-06-11 18:00:36,976] Trial 12 finished with value: 7.710353374481201 and parameters: {'hidden_size': 32, 'lr': 0.008067443097848924, 'batch_size': 64, 'weight_decay': 9.414387784051315e-05, 'dropout': 0.3519627231697403}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:00:57,651] Trial 13 finished with value: 7.719509124755859 and parameters: {'hidden_size': 32, 'lr': 0.0027043321105946075, 'batch_size': 64, 'weight_decay': 4.6696667322052526e-06, 'dropout': 0.4968533324816211}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:01:20,726] Trial 14 finished with value: 7.704322814941406 and parameters: {'hidden_size': 64, 'lr': 0.005995695002897436, 'batch_size': 16, 'weight_decay': 8.027338261932431e-05, 'dropout': 0.34832816698218705}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:01:44,969] Trial 15 finished with value: 7.7184600830078125 and parameters: {'hidden_size': 32, 'lr': 0.002453478940389223, 'batch_size': 32, 'weight_decay': 2.1865730153809395e-06, 'dropout': 0.25513870342143974}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:02:06,981] Trial 16 finished with value: 7.702831745147705 and parameters: {'hidden_size': 32, 'lr': 0.009804153405686529, 'batch_size': 64, 'weight_decay': 1.1482496332905376e-05, 'dropout': 0.36824528043744176}. Best is trial 8 with value: 7.7009453773498535.
# [I 2026-06-11 18:02:38,002] Trial 17 finished with value: 7.699402332305908 and parameters: {'hidden_size': 64, 'lr': 0.005102205114643348, 'batch_size': 32, 'weight_decay': 0.00022394694421302243, 'dropout': 0.4603383832663422}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:03:02,137] Trial 18 finished with value: 7.705214023590088 and parameters: {'hidden_size': 64, 'lr': 0.004398195349862458, 'batch_size': 32, 'weight_decay': 0.00024656968024895084, 'dropout': 0.4634560292202285}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:03:20,959] Trial 19 finished with value: 7.705907821655273 and parameters: {'hidden_size': 64, 'lr': 0.002071109940213268, 'batch_size': 32, 'weight_decay': 0.00030928520290981625, 'dropout': 0.4390671776462303}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:03:44,312] Trial 20 finished with value: 7.7092461585998535 and parameters: {'hidden_size': 64, 'lr': 0.005376678554923361, 'batch_size': 32, 'weight_decay': 7.434412280396215e-05, 'dropout': 0.46233126870251423}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:03:58,089] Trial 21 finished with value: 7.69971227645874 and parameters: {'hidden_size': 64, 'lr': 0.006601561115320043, 'batch_size': 32, 'weight_decay': 2.0263957272095375e-05, 'dropout': 0.38454164345770614}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:04:28,629] Trial 22 finished with value: 7.708581447601318 and parameters: {'hidden_size': 64, 'lr': 0.0034212832396642427, 'batch_size': 32, 'weight_decay': 5.333882024627327e-06, 'dropout': 0.3885708131307543}. Best is trial 17 with value: 7.699402332305908.
# [I 2026-06-11 18:04:57,217] Trial 23 finished with value: 7.697536468505859 and parameters: {'hidden_size': 64, 'lr': 0.006013060606853909, 'batch_size': 32, 'weight_decay': 1.6689758094530025e-05, 'dropout': 0.4564334844240952}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:05:15,527] Trial 24 pruned.
# [I 2026-06-11 18:05:33,751] Trial 25 finished with value: 7.702572345733643 and parameters: {'hidden_size': 64, 'lr': 0.005755292928032415, 'batch_size': 32, 'weight_decay': 0.00035578888466353096, 'dropout': 0.3799447934052916}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:06:06,508] Trial 26 finished with value: 7.71274995803833 and parameters: {'hidden_size': 64, 'lr': 0.002705865106344895, 'batch_size': 16, 'weight_decay': 4.9866469707095084e-05, 'dropout': 0.45215156092780073}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:06:27,065] Trial 27 finished with value: 7.711099147796631 and parameters: {'hidden_size': 64, 'lr': 0.00632702519080295, 'batch_size': 32, 'weight_decay': 0.00015167928391126095, 'dropout': 0.3297322363691532}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:06:49,117] Trial 28 finished with value: 7.721053600311279 and parameters: {'hidden_size': 64, 'lr': 0.004357506613569515, 'batch_size': 32, 'weight_decay': 1.9710979331132817e-05, 'dropout': 0.48446481419798215}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:07:06,053] Trial 29 finished with value: 7.709617614746094 and parameters: {'hidden_size': 64, 'lr': 0.006792658184440127, 'batch_size': 32, 'weight_decay': 1.0354232125263841e-05, 'dropout': 0.40305443394314117}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:08:07,539] Trial 30 finished with value: 7.711540699005127 and parameters: {'hidden_size': 64, 'lr': 0.00010174237881768558, 'batch_size': 32, 'weight_decay': 3.311037992782181e-06, 'dropout': 0.4780906329118631}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:08:26,231] Trial 31 finished with value: 7.70109224319458 and parameters: {'hidden_size': 64, 'lr': 0.004982308194803659, 'batch_size': 32, 'weight_decay': 1.5020457686983443e-05, 'dropout': 0.44054516310611275}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:08:43,231] Trial 32 finished with value: 7.70507287979126 and parameters: {'hidden_size': 64, 'lr': 0.007677827181896222, 'batch_size': 32, 'weight_decay': 6.885444736126596e-06, 'dropout': 0.42600614312196894}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:09:01,940] Trial 33 finished with value: 7.7000603675842285 and parameters: {'hidden_size': 128, 'lr': 0.0033270895711902506, 'batch_size': 32, 'weight_decay': 1.547625411108791e-06, 'dropout': 0.3930998030345359}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:09:16,074] Trial 34 finished with value: 7.703012943267822 and parameters: {'hidden_size': 128, 'lr': 0.003579574959362407, 'batch_size': 32, 'weight_decay': 1.1198295716435609e-06, 'dropout': 0.3938362525759354}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:09:35,597] Trial 35 finished with value: 7.702262878417969 and parameters: {'hidden_size': 128, 'lr': 0.0009297247259642271, 'batch_size': 32, 'weight_decay': 1.7761576045968675e-06, 'dropout': 0.3688925569405854}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:10:01,267] Trial 36 finished with value: 7.703008651733398 and parameters: {'hidden_size': 128, 'lr': 0.00037731898359888796, 'batch_size': 16, 'weight_decay': 0.0009135487553517444, 'dropout': 0.41628039674456546}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:10:20,375] Trial 37 finished with value: 7.698612689971924 and parameters: {'hidden_size': 128, 'lr': 0.0018994907485114186, 'batch_size': 32, 'weight_decay': 0.0004932557661315217, 'dropout': 0.33481816070598486}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:10:36,361] Trial 38 finished with value: 7.725509166717529 and parameters: {'hidden_size': 128, 'lr': 0.0006081221661137698, 'batch_size': 32, 'weight_decay': 0.0004817161580390658, 'dropout': 0.31267345477160574}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:10:51,108] Trial 39 finished with value: 7.702632904052734 and parameters: {'hidden_size': 128, 'lr': 0.0017428748524373607, 'batch_size': 32, 'weight_decay': 0.00019295216787621416, 'dropout': 0.3348988887001654}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:11:18,318] Trial 40 finished with value: 7.720472812652588 and parameters: {'hidden_size': 128, 'lr': 0.0011633548810289591, 'batch_size': 16, 'weight_decay': 2.9268102594141568e-05, 'dropout': 0.3166731422686315}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:11:33,723] Trial 41 finished with value: 7.699498653411865 and parameters: {'hidden_size': 128, 'lr': 0.003028103139567101, 'batch_size': 32, 'weight_decay': 0.0006536219850389041, 'dropout': 0.4064310329072842}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:11:55,638] Trial 42 finished with value: 7.707971096038818 and parameters: {'hidden_size': 128, 'lr': 0.002630418812270678, 'batch_size': 32, 'weight_decay': 0.0005409460607736059, 'dropout': 0.2943831081837569}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:12:16,876] Trial 43 finished with value: 7.698112487792969 and parameters: {'hidden_size': 128, 'lr': 0.00469328196504798, 'batch_size': 32, 'weight_decay': 0.0007764430911853931, 'dropout': 0.40988807688818085}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:12:36,914] Trial 44 finished with value: 7.708885669708252 and parameters: {'hidden_size': 128, 'lr': 0.0019935157188396223, 'batch_size': 32, 'weight_decay': 0.0006848427978214797, 'dropout': 0.4086841051297031}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:13:04,078] Trial 45 finished with value: 7.699184894561768 and parameters: {'hidden_size': 128, 'lr': 0.004758450315522341, 'batch_size': 32, 'weight_decay': 0.0004433095506888079, 'dropout': 0.44719272373142605}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:13:20,043] Trial 46 finished with value: 7.703962802886963 and parameters: {'hidden_size': 128, 'lr': 0.004379138474506876, 'batch_size': 32, 'weight_decay': 0.000992503034400878, 'dropout': 0.4509536708989515}. Best is trial 23 with value: 7.697536468505859.
# [I 2026-06-11 18:13:34,705] Trial 47 finished with value: 7.69508695602417 and parameters: {'hidden_size': 128, 'lr': 0.004851554467820172, 'batch_size': 64, 'weight_decay': 0.00042778403757366565, 'dropout': 0.4713600697179938}. Best is trial 47 with value: 7.69508695602417.
# [I 2026-06-11 18:13:47,180] Trial 48 finished with value: 7.711158752441406 and parameters: {'hidden_size': 128, 'lr': 0.0013372474135129042, 'batch_size': 64, 'weight_decay': 0.00040529921329104837, 'dropout': 0.4995852196994789}. Best is trial 47 with value: 7.69508695602417.
# [I 2026-06-11 18:14:01,722] Trial 49 finished with value: 7.706876277923584 and parameters: {'hidden_size': 128, 'lr': 0.0021403895659078726, 'batch_size': 64, 'weight_decay': 0.00013669845843311846, 'dropout': 0.47712274014679085}. Best is trial 47 with value: 7.69508695602417.
# [I 2026-06-11 18:14:29,580] Trial 50 finished with value: 7.704492568969727 and parameters: {'hidden_size': 128, 'lr': 0.008193415926027953, 'batch_size': 64, 'weight_decay': 0.0002745977728115912, 'dropout': 0.42649133936560574}. Best is trial 47 with value: 7.69508695602417.
# [I 2026-06-11 18:14:44,330] Trial 51 finished with value: 7.699662685394287 and parameters: {'hidden_size': 128, 'lr': 0.004798944268144995, 'batch_size': 64, 'weight_decay': 0.0004777169486635486, 'dropout': 0.45407713252639315}. Best is trial 47 with value: 7.69508695602417.
# [I 2026-06-11 18:14:57,064] Trial 52 finished with value: 7.6935601234436035 and parameters: {'hidden_size': 128, 'lr': 0.0040012472564448405, 'batch_size': 64, 'weight_decay': 0.00019503085747588184, 'dropout': 0.2646681156510332}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:15:09,643] Trial 53 finished with value: 7.7004828453063965 and parameters: {'hidden_size': 128, 'lr': 0.0040858878059374494, 'batch_size': 64, 'weight_decay': 0.00010989661854281697, 'dropout': 0.29742711916648534}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:15:26,359] Trial 54 finished with value: 7.710775852203369 and parameters: {'hidden_size': 128, 'lr': 0.0071680471321170025, 'batch_size': 64, 'weight_decay': 0.00037736851662353556, 'dropout': 0.2806763057587336}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:15:40,942] Trial 55 finished with value: 7.722644805908203 and parameters: {'hidden_size': 128, 'lr': 0.0030860240868662275, 'batch_size': 64, 'weight_decay': 0.0007898283121482831, 'dropout': 0.21545081564206303}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:15:54,716] Trial 56 finished with value: 7.698886871337891 and parameters: {'hidden_size': 128, 'lr': 0.005788221195979108, 'batch_size': 64, 'weight_decay': 0.0005298698029639969, 'dropout': 0.23850125052661464}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:16:10,753] Trial 57 finished with value: 7.708517551422119 and parameters: {'hidden_size': 128, 'lr': 0.009022059954821972, 'batch_size': 64, 'weight_decay': 0.0002053184078169811, 'dropout': 0.24000469057697224}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:16:24,600] Trial 58 finished with value: 7.704904079437256 and parameters: {'hidden_size': 32, 'lr': 0.005674212858655687, 'batch_size': 64, 'weight_decay': 0.0005807308681784027, 'dropout': 0.2393419082018456}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:16:39,116] Trial 59 finished with value: 7.701023101806641 and parameters: {'hidden_size': 128, 'lr': 0.0037597405828324265, 'batch_size': 64, 'weight_decay': 5.256268934865807e-05, 'dropout': 0.27197340099085315}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:16:51,862] Trial 60 finished with value: 7.702415943145752 and parameters: {'hidden_size': 128, 'lr': 0.002250327290039678, 'batch_size': 64, 'weight_decay': 0.0002872184664348071, 'dropout': 0.23601981506077663}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:17:08,663] Trial 61 finished with value: 7.7001166343688965 and parameters: {'hidden_size': 128, 'lr': 0.0051595628271212885, 'batch_size': 64, 'weight_decay': 0.0004463955270317803, 'dropout': 0.2586066045398202}. Best is trial 52 with value: 7.6935601234436035.
# [I 2026-06-11 18:17:30,162] Trial 62 finished with value: 7.692965030670166 and parameters: {'hidden_size': 128, 'lr': 0.0061093242596911195, 'batch_size': 64, 'weight_decay': 0.0007857935995134359, 'dropout': 0.44380990269032716}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:17:42,751] Trial 63 finished with value: 7.7001051902771 and parameters: {'hidden_size': 128, 'lr': 0.006664948905559497, 'batch_size': 64, 'weight_decay': 0.000776962570249761, 'dropout': 0.470098427409401}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:17:56,555] Trial 64 finished with value: 7.6968536376953125 and parameters: {'hidden_size': 128, 'lr': 0.009944904805241754, 'batch_size': 64, 'weight_decay': 0.00032719870503908723, 'dropout': 0.26432280594309776}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:18:09,756] Trial 65 finished with value: 7.70119047164917 and parameters: {'hidden_size': 32, 'lr': 0.009336868030312386, 'batch_size': 64, 'weight_decay': 0.00033375078926342947, 'dropout': 0.26409576931661194}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:18:27,124] Trial 66 finished with value: 7.698161602020264 and parameters: {'hidden_size': 128, 'lr': 0.007618586352518641, 'batch_size': 64, 'weight_decay': 0.000794563365619953, 'dropout': 0.4331661216972651}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:18:47,754] Trial 67 finished with value: 7.698706150054932 and parameters: {'hidden_size': 128, 'lr': 0.007471757784987793, 'batch_size': 64, 'weight_decay': 0.0007777556911617079, 'dropout': 0.43487858213914726}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:19:03,971] Trial 68 finished with value: 7.6995768547058105 and parameters: {'hidden_size': 128, 'lr': 0.00825751576370569, 'batch_size': 64, 'weight_decay': 0.0009508730141820548, 'dropout': 0.48751374436047135}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:19:22,781] Trial 69 finished with value: 7.701831340789795 and parameters: {'hidden_size': 128, 'lr': 0.006290671938543188, 'batch_size': 64, 'weight_decay': 0.0006521860063324743, 'dropout': 0.4198700710644233}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:19:52,418] Trial 70 finished with value: 7.7051544189453125 and parameters: {'hidden_size': 32, 'lr': 0.003965793353404053, 'batch_size': 16, 'weight_decay': 0.0002554299718917804, 'dropout': 0.4447202162954119}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:20:07,669] Trial 71 finished with value: 7.699256420135498 and parameters: {'hidden_size': 128, 'lr': 0.00999179941764943, 'batch_size': 64, 'weight_decay': 0.0003457808122901133, 'dropout': 0.34479245711367174}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:20:24,454] Trial 72 finished with value: 7.699234485626221 and parameters: {'hidden_size': 128, 'lr': 0.007440398274851581, 'batch_size': 64, 'weight_decay': 0.0005671585707381235, 'dropout': 0.37025276134825885}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:20:44,848] Trial 73 finished with value: 7.703328609466553 and parameters: {'hidden_size': 128, 'lr': 0.006133300624989741, 'batch_size': 64, 'weight_decay': 0.000190747621684924, 'dropout': 0.45817418824850764}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:21:01,653] Trial 74 finished with value: 7.6973137855529785 and parameters: {'hidden_size': 128, 'lr': 0.005402433407021768, 'batch_size': 64, 'weight_decay': 0.000742876912944356, 'dropout': 0.4725498656802828}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:21:23,975] Trial 75 finished with value: 7.69766092300415 and parameters: {'hidden_size': 128, 'lr': 0.005407390390608974, 'batch_size': 64, 'weight_decay': 0.0007997616689558098, 'dropout': 0.47079766940056433}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:21:39,605] Trial 76 finished with value: 7.693078994750977 and parameters: {'hidden_size': 128, 'lr': 0.004577055555776335, 'batch_size': 64, 'weight_decay': 0.0006109917801149314, 'dropout': 0.47173986669326845}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:21:55,350] Trial 77 finished with value: 7.702004909515381 and parameters: {'hidden_size': 128, 'lr': 0.005150575780872135, 'batch_size': 64, 'weight_decay': 0.0006276855673277833, 'dropout': 0.4901717249967447}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:22:09,187] Trial 78 finished with value: 7.7023606300354 and parameters: {'hidden_size': 128, 'lr': 0.0030595304141968504, 'batch_size': 64, 'weight_decay': 0.00037794969449220407, 'dropout': 0.4719228770630227}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:22:26,588] Trial 79 finished with value: 7.698036193847656 and parameters: {'hidden_size': 128, 'lr': 0.004143570433633684, 'batch_size': 64, 'weight_decay': 0.0009940254383365894, 'dropout': 0.47734244546589877}. Best is trial 62 with value: 7.692965030670166.
# [I 2026-06-11 18:22:44,029] Trial 80 finished with value: 7.705636978149414 and parameters: {'hidden_size': 64, 'lr': 0.005594447067450837, 'batch_size': 64, 'weight_decay': 0.00030192694119687195, 'dropout': 0.4935974551594206}. Best is trial 62 with value: 7.692965030670166.
# ...
# [I 2026-06-11 18:51:06,378] Trial 46 pruned.
# [I 2026-06-11 18:51:33,334] Trial 47 finished with value: 7.69549560546875 and parameters: {'hidden_size': 128, 'lr': 0.0033780846662835244, 'batch_size': 32, 'weight_decay': 0.0005225211874648598, 'dropout': 0.39417091810007787, 'huber_delta': 1.7285298503137916}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:51:59,552] Trial 48 finished with value: 7.70392370223999 and parameters: {'hidden_size': 128, 'lr': 0.005031184109350901, 'batch_size': 64, 'weight_decay': 0.00037457475238799037, 'dropout': 0.432917935181059, 'huber_delta': 1.0511811188900022}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:52:24,744] Trial 49 pruned.
# [I 2026-06-11 18:52:44,125] Trial 50 finished with value: 7.703073978424072 and parameters: {'hidden_size': 32, 'lr': 0.0022389543013943067, 'batch_size': 32, 'weight_decay': 3.296438817139576e-06, 'dropout': 0.4156226000980695, 'huber_delta': 1.5886492166345558}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:53:02,919] Trial 51 pruned.
# [I 2026-06-11 18:53:18,864] Trial 52 finished with value: 7.6953511238098145 and parameters: {'hidden_size': 128, 'lr': 0.0034226860531441274, 'batch_size': 32, 'weight_decay': 0.00015999547399213313, 'dropout': 0.4673547688039587, 'huber_delta': 1.8902662342564849}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:53:51,831] Trial 53 finished with value: 7.697338104248047 and parameters: {'hidden_size': 128, 'lr': 0.006647926292617775, 'batch_size': 32, 'weight_decay': 0.000705362130975483, 'dropout': 0.4533642867557484, 'huber_delta': 1.657518186721586}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:54:23,412] Trial 54 finished with value: 7.696164608001709 and parameters: {'hidden_size': 128, 'lr': 0.009562306452849275, 'batch_size': 32, 'weight_decay': 0.00037371803675029247, 'dropout': 0.4403376337671898, 'huber_delta': 1.974853685678405}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:54:51,813] Trial 55 finished with value: 7.69147253036499 and parameters: {'hidden_size': 128, 'lr': 0.005388405539824047, 'batch_size': 16, 'weight_decay': 0.0002512608049621831, 'dropout': 0.46688596119842485, 'huber_delta': 1.8149137633055736}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:55:43,533] Trial 56 finished with value: 7.694102764129639 and parameters: {'hidden_size': 128, 'lr': 0.005524413377227651, 'batch_size': 16, 'weight_decay': 0.00045321081586670336, 'dropout': 0.38024669465676625, 'huber_delta': 1.8211480547380114}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:56:07,106] Trial 57 finished with value: 7.698266506195068 and parameters: {'hidden_size': 128, 'lr': 0.007997934644653055, 'batch_size': 16, 'weight_decay': 0.0006445555000129262, 'dropout': 0.4911461155160717, 'huber_delta': 1.7378604550428018}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:56:32,153] Trial 58 finished with value: 7.696821689605713 and parameters: {'hidden_size': 128, 'lr': 0.0053033886568828615, 'batch_size': 16, 'weight_decay': 0.0002967245320695164, 'dropout': 0.4474975456809309, 'huber_delta': 1.7876501935092124}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:56:55,048] Trial 59 finished with value: 7.700270175933838 and parameters: {'hidden_size': 128, 'lr': 0.0028627014660664715, 'batch_size': 16, 'weight_decay': 4.0972140838169164e-05, 'dropout': 0.46536822298474434, 'huber_delta': 1.9134278751613225}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:57:24,275] Trial 60 finished with value: 7.697017669677734 and parameters: {'hidden_size': 128, 'lr': 0.0016928486612386114, 'batch_size': 16, 'weight_decay': 0.0008647442394664075, 'dropout': 0.4331496205007704, 'huber_delta': 1.3822688939575294}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:57:52,172] Trial 61 finished with value: 7.693548202514648 and parameters: {'hidden_size': 128, 'lr': 0.004495526524648397, 'batch_size': 16, 'weight_decay': 0.0002118206301162444, 'dropout': 0.4744291055673244, 'huber_delta': 1.854880106021487}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:58:06,495] Trial 62 finished with value: 7.698631286621094 and parameters: {'hidden_size': 128, 'lr': 0.003645334328538189, 'batch_size': 64, 'weight_decay': 0.00015264392935686858, 'dropout': 0.4868817490675974, 'huber_delta': 1.9701147460403283}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:58:41,216] Trial 63 finished with value: 7.688539505004883 and parameters: {'hidden_size': 128, 'lr': 0.006853188072923898, 'batch_size': 16, 'weight_decay': 0.0002736559510319791, 'dropout': 0.46322633123183443, 'huber_delta': 1.802038637665249}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:59:07,325] Trial 64 finished with value: 7.6883978843688965 and parameters: {'hidden_size': 128, 'lr': 0.00859192584044823, 'batch_size': 16, 'weight_decay': 0.0005280615454838624, 'dropout': 0.49981396870229217, 'huber_delta': 1.8001446162625097}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 18:59:41,639] Trial 65 finished with value: 7.6972737312316895 and parameters: {'hidden_size': 128, 'lr': 0.008824217025010753, 'batch_size': 16, 'weight_decay': 0.0003370557912883974, 'dropout': 0.4971361713848356, 'huber_delta': 1.8084585928852328}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:00:00,561] Trial 66 finished with value: 7.704200267791748 and parameters: {'hidden_size': 64, 'lr': 0.006933172565619812, 'batch_size': 16, 'weight_decay': 0.00010145003581325278, 'dropout': 0.4583333232655533, 'huber_delta': 1.7580232253964168}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:00:29,398] Trial 67 finished with value: 7.693644046783447 and parameters: {'hidden_size': 128, 'lr': 0.008217156347082439, 'batch_size': 16, 'weight_decay': 0.0004886103175198842, 'dropout': 0.3134758491944204, 'huber_delta': 1.639999262879415}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:00:52,593] Trial 68 pruned.
# [I 2026-06-11 19:01:22,499] Trial 69 finished with value: 7.6979241371154785 and parameters: {'hidden_size': 128, 'lr': 0.002380241265999214, 'batch_size': 16, 'weight_decay': 0.00017555469006690793, 'dropout': 0.4259180642001288, 'huber_delta': 1.7296351737764264}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:01:51,016] Trial 70 finished with value: 7.695465087890625 and parameters: {'hidden_size': 128, 'lr': 0.005279441089407163, 'batch_size': 16, 'weight_decay': 0.00036760858932852165, 'dropout': 0.4836943895208246, 'huber_delta': 0.8835730376217846}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:02:21,751] Trial 71 finished with value: 7.690975189208984 and parameters: {'hidden_size': 128, 'lr': 0.00644629030834871, 'batch_size': 16, 'weight_decay': 0.0006017355859635356, 'dropout': 0.47142480908990236, 'huber_delta': 1.9073351858528849}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:02:59,439] Trial 72 finished with value: 7.694032192230225 and parameters: {'hidden_size': 128, 'lr': 0.006937053128317893, 'batch_size': 16, 'weight_decay': 0.00048131546046532235, 'dropout': 0.44724661959301465, 'huber_delta': 1.9201966998747064}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:04:01,047] Trial 73 finished with value: 7.691555023193359 and parameters: {'hidden_size': 128, 'lr': 0.005984857740451884, 'batch_size': 16, 'weight_decay': 0.000794553109690003, 'dropout': 0.47798161460739574, 'huber_delta': 1.9997699325946199}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:04:19,837] Trial 74 finished with value: 7.70105504989624 and parameters: {'hidden_size': 128, 'lr': 0.004589980197976785, 'batch_size': 16, 'weight_decay': 0.0003050847328012998, 'dropout': 0.45544089724306963, 'huber_delta': 1.7900241221507058}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:04:37,925] Trial 75 finished with value: 7.704214572906494 and parameters: {'hidden_size': 128, 'lr': 0.009096495659805364, 'batch_size': 16, 'weight_decay': 0.0006052559271640659, 'dropout': 0.4637583370747371, 'huber_delta': 0.8093367120919571}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:05:09,393] Trial 76 finished with value: 7.695593357086182 and parameters: {'hidden_size': 128, 'lr': 0.0037848981606884075, 'batch_size': 16, 'weight_decay': 0.00041877934150728543, 'dropout': 0.4911063415376649, 'huber_delta': 1.9053997375773937}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:05:45,451] Trial 77 finished with value: 7.70059061050415 and parameters: {'hidden_size': 128, 'lr': 0.007126947599107093, 'batch_size': 16, 'weight_decay': 0.00025244911138520506, 'dropout': 0.3359028454575132, 'huber_delta': 1.956235426654401}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:06:11,777] Trial 78 finished with value: 7.698660373687744 and parameters: {'hidden_size': 128, 'lr': 0.005996636385352551, 'batch_size': 16, 'weight_decay': 0.0001374887364693627, 'dropout': 0.3708748191580911, 'huber_delta': 1.6986548604572185}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:06:37,257] Trial 79 finished with value: 7.70297384262085 and parameters: {'hidden_size': 64, 'lr': 0.0031125057034026896, 'batch_size': 16, 'weight_decay': 0.00020197889824423448, 'dropout': 0.4725329201584629, 'huber_delta': 1.8283136748346709}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:06:57,597] Trial 80 finished with value: 7.69906759262085 and parameters: {'hidden_size': 128, 'lr': 0.008484628677454257, 'batch_size': 16, 'weight_decay': 0.0007009073953128535, 'dropout': 0.44048987222073643, 'huber_delta': 1.757866740069344}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:07:15,850] Trial 81 finished with value: 7.699605464935303 and parameters: {'hidden_size': 128, 'lr': 0.005919665640335942, 'batch_size': 16, 'weight_decay': 0.0008914483372817378, 'dropout': 0.4824768169125148, 'huber_delta': 1.9959822439688257}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:07:57,633] Trial 82 finished with value: 7.691919803619385 and parameters: {'hidden_size': 128, 'lr': 0.004939575747849759, 'batch_size': 16, 'weight_decay': 0.0007897839092632778, 'dropout': 0.47312267834616, 'huber_delta': 1.2938881675908036}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:08:31,435] Trial 83 finished with value: 7.696019649505615 and parameters: {'hidden_size': 128, 'lr': 0.006418045263953065, 'batch_size': 16, 'weight_decay': 0.0005382706623893581, 'dropout': 0.4785769104892944, 'huber_delta': 1.9525371983378288}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:08:55,622] Trial 84 finished with value: 7.692131519317627 and parameters: {'hidden_size': 128, 'lr': 0.004340273804248023, 'batch_size': 16, 'weight_decay': 0.00040067413226495307, 'dropout': 0.45849882819082916, 'huber_delta': 1.892918359322372}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:09:18,588] Trial 85 finished with value: 7.696586608886719 and parameters: {'hidden_size': 128, 'lr': 0.0055464490896845135, 'batch_size': 16, 'weight_decay': 0.00032392475314534883, 'dropout': 0.48998013186420114, 'huber_delta': 1.8628323362254144}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:09:33,117] Trial 86 pruned.
# [I 2026-06-11 19:09:58,973] Trial 87 finished with value: 7.704512119293213 and parameters: {'hidden_size': 128, 'lr': 0.0077228496574824074, 'batch_size': 16, 'weight_decay': 0.0007979761774765743, 'dropout': 0.46086356512997373, 'huber_delta': 1.9228369536830845}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:10:19,245] Trial 88 finished with value: 7.710491180419922 and parameters: {'hidden_size': 128, 'lr': 0.003781259759271851, 'batch_size': 16, 'weight_decay': 1.079101042192854e-05, 'dropout': 0.23963401025286546, 'huber_delta': 1.484397383583931}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:11:02,558] Trial 89 finished with value: 7.688180446624756 and parameters: {'hidden_size': 128, 'lr': 0.009727908176878602, 'batch_size': 16, 'weight_decay': 0.0006729316091688487, 'dropout': 0.44829347234194206, 'huber_delta': 1.8071133346706345}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:11:37,245] Trial 90 finished with value: 7.699148654937744 and parameters: {'hidden_size': 64, 'lr': 0.009997399263729584, 'batch_size': 16, 'weight_decay': 0.0006450822789874301, 'dropout': 0.4265716213534362, 'huber_delta': 1.8161253810371223}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:12:10,891] Trial 91 finished with value: 7.700170993804932 and parameters: {'hidden_size': 128, 'lr': 0.007342877015453114, 'batch_size': 16, 'weight_decay': 0.00042626589484356725, 'dropout': 0.41390709906351936, 'huber_delta': 1.7812425612825444}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:12:36,134] Trial 92 finished with value: 7.699277400970459 and parameters: {'hidden_size': 128, 'lr': 0.00639851250866463, 'batch_size': 16, 'weight_decay': 0.0009745157551006523, 'dropout': 0.4482711528830305, 'huber_delta': 1.8699492442524621}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:13:22,331] Trial 93 finished with value: 7.693822383880615 and parameters: {'hidden_size': 128, 'lr': 0.008596315672036723, 'batch_size': 16, 'weight_decay': 0.0006637260154307907, 'dropout': 0.3902415081277739, 'huber_delta': 1.0983598301486048}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:13:49,583] Trial 94 finished with value: 7.696521759033203 and parameters: {'hidden_size': 128, 'lr': 0.005068308292878238, 'batch_size': 16, 'weight_decay': 0.0005364851387589704, 'dropout': 0.4692548172926818, 'huber_delta': 1.8419256728374958}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:14:27,056] Trial 95 finished with value: 7.6891303062438965 and parameters: {'hidden_size': 128, 'lr': 0.005923484932659563, 'batch_size': 16, 'weight_decay': 0.00028915379314709233, 'dropout': 0.4399270062589309, 'huber_delta': 1.6629090616798745}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:14:50,481] Trial 96 finished with value: 7.697971343994141 and parameters: {'hidden_size': 128, 'lr': 0.0074576790123350705, 'batch_size': 16, 'weight_decay': 0.000344359799404711, 'dropout': 0.4404445553085888, 'huber_delta': 1.5992671963708507}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:15:23,753] Trial 97 finished with value: 7.689742565155029 and parameters: {'hidden_size': 128, 'lr': 0.009199257863424886, 'batch_size': 16, 'weight_decay': 0.00026367861614091237, 'dropout': 0.4664488019047809, 'huber_delta': 1.6581461546518212}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:15:48,414] Trial 98 finished with value: 7.7043137550354 and parameters: {'hidden_size': 128, 'lr': 0.009999682137291717, 'batch_size': 16, 'weight_decay': 0.00028088218398739296, 'dropout': 0.4530201035065835, 'huber_delta': 1.554012006283847}. Best is trial 26 with value: 7.685606002807617.
# [I 2026-06-11 19:16:05,982] Trial 99 finished with value: 7.69634485244751 and parameters: {'hidden_size': 128, 'lr': 0.009025755296139977, 'batch_size': 64, 'weight_decay': 0.00021477358879156785, 'dropout': 0.40806341808327606, 'huber_delta': 1.662946054129949}. Best is trial 26 with value: 7.685606002807617.
# [HUBER - MTL Imp] Best Avg Val Metric (minimize): 7.6856
#  Best Params: {'hidden_size': 128, 'lr': 0.006381792160258894, 'batch_size': 16, 'weight_decay': 0.0004979630805077204, 'dropout': 0.4768112640113703, 'huber_delta': 1.5200330683283365}

# %%
print("\n--- Baseline MTL Best Params ---")
for l_type, params in best_mtl_baselines.items():
    print(f"[Baseline - {l_type.upper()}] \n {params}\n")

print("\n--- Improved MTL Best Params ---")
for l_type, params in best_mtl_imp.items():
    print(f"[Improved - {l_type.upper()}] \n {params}\n")
# Out:
# --- Baseline MTL Best Params ---
# [Baseline - L1]
#  {'hidden_size': 64, 'lr': 0.007232524590277065, 'batch_size': 16, 'weight_decay': 0.0005087759150780066, 'dropout': 0.35589358244791597}
#
# [Baseline - MSE]
#  {'hidden_size': 64, 'lr': 0.006983818714746657, 'batch_size': 16, 'weight_decay': 5.675822110414546e-06, 'dropout': 0.3475448443627979}
#
# [Baseline - HUBER]
#  {'hidden_size': 128, 'lr': 0.008413145419011104, 'batch_size': 64, 'weight_decay': 0.0006289798091665713, 'dropout': 0.25746791334752883, 'huber_delta': 1.6282774654565855}
#
#
# --- Improved MTL Best Params ---
# [Improved - L1]
#  {'hidden_size': 128, 'lr': 0.008348762109208775, 'batch_size': 16, 'weight_decay': 0.0003772961969983845, 'dropout': 0.49991817673879335}
#
# [Improved - MSE]
#  {'hidden_size': 128, 'lr': 0.008528708437362812, 'batch_size': 64, 'weight_decay': 0.0008323034321305966, 'dropout': 0.4931784741813427}
#
# [Improved - HUBER]
#  {'hidden_size': 128, 'lr': 0.006381792160258894, 'batch_size': 16, 'weight_decay': 0.0004979630805077204, 'dropout': 0.4768112640113703, 'huber_delta': 1.5200330683283365}

# %%
def build_loaders_and_model(is_improved, params):
    dropout_val = params.get("dropout", 0.2)
    if is_improved:
        train_ds = ImprovedYoYDatasetMTL(mtl_train_data_imp, robust_scaler, selected_indices)
        val_ds = ImprovedYoYDatasetMTL(mtl_val_data_imp, robust_scaler, selected_indices)
        test_ds = ImprovedYoYDatasetMTL(mtl_test_data_imp, robust_scaler, selected_indices)
        collate = collate_fn_improved_mtl
        model = ImprovedShallowLSTM(len(selected_indices), params["hidden_size"], len(PREDICTION_TARGETS), dropout_val).to(DEVICE)
    else:
        train_ds = YoYSequenceDatasetMTL(mtl_train_data, max_seq_length, scaler)
        val_ds = YoYSequenceDatasetMTL(mtl_val_data, max_seq_length, scaler)
        test_ds = YoYSequenceDatasetMTL(mtl_test_data, max_seq_length, scaler)
        collate = None
        model = ShallowLSTMClassifier(len(feature_cols), params["hidden_size"], len(PREDICTION_TARGETS), dropout_val).to(DEVICE)

    if collate:
        train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True, collate_fn=collate)
        val_loader = DataLoader(val_ds, batch_size=params["batch_size"], shuffle=False, collate_fn=collate)
        test_loader = DataLoader(test_ds, batch_size=params["batch_size"], shuffle=False, collate_fn=collate)
    else:
        train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True)
        val_loader = DataLoader(val_ds, batch_size=params["batch_size"], shuffle=False)
        test_loader = DataLoader(test_ds, batch_size=params["batch_size"], shuffle=False)

    return model, train_loader, val_loader, test_loader


def evaluate_loader(model, loader, is_improved):
    model.eval()
    all_preds, all_targets, all_masks = [], [], []
    with torch.no_grad():
        for batch in loader:
            if is_improved:
                bx, by, bmask, lengths = batch
                logits = model(bx.to(DEVICE), lengths)
                all_masks.append(bmask.numpy())
            else:
                bx, by, bmask = batch
                logits = model(bx.to(DEVICE))
                all_masks.append(bmask.numpy())

            all_preds.append(logits.cpu().numpy())
            all_targets.append(by.numpy())

    if not all_preds:
        return None

    y_pred = np.vstack(all_preds)
    y_true = np.vstack(all_targets)

    if is_improved:
        y_pred = np.sign(y_pred) * np.expm1(np.abs(y_pred))
        y_true = np.sign(y_true) * np.expm1(np.abs(y_true))

    mask = np.vstack(all_masks)
    res = {}
    for i, t in enumerate(PREDICTION_TARGETS):
        m = mask[:, i]
        if m.sum() == 0:
            continue
        res[t] = np.mean(np.abs(y_pred[m, i] - y_true[m, i]))
    return res


def final_train_and_test(is_improved, params, loss_type='l1'):
    model, train_loader, val_loader, test_loader = build_loaders_and_model(
        is_improved, params
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=params["lr"], weight_decay=params["weight_decay"])
    huber_delta = params.get("huber_delta", 1.0)

    model, _ = train_and_eval(
        model, train_loader, val_loader, optimizer,
        is_improved=is_improved, loss_type=loss_type, huber_delta=huber_delta
    )

    return evaluate_loader(model, test_loader, is_improved=is_improved)

def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)

N_RUNS = 20
print(f"Computing Final Test Metrics using Test Sets across {N_RUNS} runs...")
final_results = []

def run_multiple_times(pipeline_name, is_improved, best_params_dict):
    for l_type, params in best_params_dict.items():
        print(f"Running {pipeline_name} with {l_type.upper()} loss...")
        target_results = {t: [] for t in PREDICTION_TARGETS}
        for run_idx in range(N_RUNS):
            set_seed(SEED + run_idx)
            res = final_train_and_test(is_improved, params, loss_type=l_type)
            for target, val in res.items():
                target_results[target].append(val)

        for target in PREDICTION_TARGETS:
            avg_mae = np.mean(target_results[target])
            std_mae = np.std(target_results[target])
            final_results.append({
                "Pipeline": pipeline_name,
                "Loss": l_type.upper(),
                "Target": target,
                "Test MAE (Mean)": avg_mae,
                "Deviation": std_mae
            })
# Out:
# Computing Final Test Metrics using Test Sets across 20 runs...

# %%
final_results = []
run_multiple_times("Baseline", False, best_mtl_baselines)
run_multiple_times("Improved", True, best_mtl_imp)

df_final = pd.DataFrame(final_results)

# Create a pivot table for easy comparison
pivot_df = df_final.pivot_table(
    index=["Target", "Loss"],
    columns=["Pipeline"],
    values=["Test MAE (Mean)", "Deviation"]
)
display(pivot_df)
# Out:
# Running Baseline with L1 loss...
# Running Baseline with MSE loss...
# Running Baseline with HUBER loss...
# Running Improved with L1 loss...
# Running Improved with MSE loss...
# Running Improved with HUBER loss...
#                  Deviation           Test MAE (Mean)
# Pipeline          Baseline  Improved        Baseline  Improved
# Target     Loss
# EBITDA     HUBER  0.038023  0.057954        1.543805  1.540742
#            L1     0.018964  0.011054        1.493970  1.495113
#            MSE    0.117408  0.028594        1.684377  1.564265
# Net_Income HUBER  0.043481  0.020795        1.564359  1.553485
#            L1     0.011268  0.022689        1.555192  1.558131
#            MSE    0.039119  0.010249        1.584323  1.558509
# ROA        HUBER  0.038295  0.019419        1.600802  1.579551
#            L1     0.016011  0.008418        1.586383  1.580006
#            MSE    0.077355  0.013362        1.649686  1.583897

# %% [markdown]
# ## Segmented Performance Analysis

# %%
def evaluate_group_pipeline(is_improved, best_params_dict):
    group_results = []

    for l_type, params in best_params_dict.items():
        # Store individual run MAEs here to compute standard deviation
        group_run_maes = {grp: {t: [] for t in PREDICTION_TARGETS} for grp in ticker_groups.keys()}

        for run_idx in range(N_RUNS):
            set_seed(SEED + run_idx)
            # Re-train model for this run
            model, train_loader, val_loader, _ = build_loaders_and_model(is_improved, params)
            optimizer = torch.optim.Adam(model.parameters(), lr=params["lr"], weight_decay=params["weight_decay"])
            huber_delta = params.get("huber_delta", 1.0)
            model, _ = train_and_eval(model, train_loader, val_loader, optimizer, is_improved=is_improved, loss_type=l_type, huber_delta=huber_delta)

            for group_name, tickers in ticker_groups.items():
                if is_improved:
                    group_df = mtl_test_data_imp[mtl_test_data_imp['company'].isin(tickers)]
                    if group_df.empty: continue
                    group_ds = ImprovedYoYDatasetMTL(group_df, robust_scaler, selected_indices)
                    collate = collate_fn_improved_mtl
                else:
                    group_df = mtl_test_data[mtl_test_data['company'].isin(tickers)]
                    if group_df.empty: continue
                    group_ds = YoYSequenceDatasetMTL(group_df, max_seq_length, scaler)
                    collate = None

                loader = DataLoader(group_ds, batch_size=params["batch_size"], shuffle=False, collate_fn=collate)
                metrics = evaluate_loader(model, loader, is_improved=is_improved)

                if metrics:
                    for target, val in metrics.items():
                        group_run_maes[group_name][target].append(val)

        # Compute mean and std
        for group_name in ticker_groups.keys():
            for target in PREDICTION_TARGETS:
                if len(group_run_maes[group_name][target]) > 0:
                    maes = group_run_maes[group_name][target]
                    group_results.append({
                        "Loss": l_type.upper(),
                        "Group": group_name,
                        "Target": target,
                        "MAE (Mean)": np.mean(maes),
                        "Deviation": np.std(maes)
                    })

    return group_results

print("Evaluating Improved MTL across losses and groups...")
imp_group_stats = evaluate_group_pipeline(True, best_mtl_imp)

print("\nEvaluating Baseline MTL across losses and groups...")
base_group_stats = evaluate_group_pipeline(False, best_mtl_baselines)

df_imp_group = pd.DataFrame(imp_group_stats)
df_base_group = pd.DataFrame(base_group_stats)

print("\n--- Grouped MAE: Improved MTL ---")
if not df_imp_group.empty:
    display(df_imp_group.pivot_table(index=['Target', 'Loss'], columns='Group', values=['MAE (Mean)', 'Deviation']))

print("\n--- Grouped MAE: Baseline MTL ---")
if not df_base_group.empty:
    display(df_base_group.pivot_table(index=['Target', 'Loss'], columns='Group', values=['MAE (Mean)', 'Deviation']))
# Out:
# Evaluating Improved MTL across losses and groups...
#
# Evaluating Baseline MTL across losses and groups...
#
# --- Grouped MAE: Improved MTL ---
#                  Deviation                     MAE (Mean)
# Group                  MIB   Mid-cap Small-cap        MIB   Mid-cap Small-cap
# Target     Loss
# EBITDA     HUBER  0.013345  0.012285  0.011936   1.882129  0.432301  2.077805
#            L1     0.007175  0.010151  0.011694   1.872868  0.423073  2.068846
#            MSE    0.016179  0.029560  0.056993   1.879454  0.456574  2.127214
# Net_Income HUBER  0.019447  0.015695  0.004571   0.727523  1.660671  1.794760
#            L1     0.018631  0.018250  0.014093   0.728950  1.658343  1.811956
#            MSE    0.020231  0.017087  0.003697   0.728444  1.674364  1.789339
# ROA        HUBER  0.022916  0.024162  0.004770   0.724385  1.634140  1.882975
#            L1     0.018667  0.024420  0.013050   0.722308  1.619287  1.893402
#            MSE    0.018359  0.019872  0.005220   0.722233  1.631258  1.877700
# --- Grouped MAE: Baseline MTL ---
#                  Deviation                     MAE (Mean)
# Group                  MIB   Mid-cap Small-cap        MIB   Mid-cap Small-cap
# Target     Loss
# EBITDA     HUBER  0.032670  0.048373  0.037989   1.897592  0.477673  2.114572
#            L1     0.018431  0.021678  0.020876   1.868880  0.431836  2.074885
#            MSE    0.089618  0.128185  0.095976   2.017731  0.637593  2.234647
# Net_Income HUBER  0.041453  0.044896  0.011992   0.733051  1.674605  1.806381
#            L1     0.022736  0.014829  0.010894   0.722157  1.649563  1.809530
#            MSE    0.070602  0.070106  0.020684   0.782812  1.724882  1.816690
# ROA        HUBER  0.046131  0.051967  0.015194   0.734569  1.644067  1.891570
#            L1     0.021650  0.019594  0.012843   0.719380  1.612774  1.892010
#            MSE    0.093082  0.097450  0.028914   0.814015  1.724964  1.910691

# %% [markdown]
# ### Directional Accuracy

# %%
def calculate_directional_accuracy(model, loader, is_improved):
    model.eval()
    all_preds, all_targets, all_masks = [], [], []
    with torch.no_grad():
        for batch in loader:
            if is_improved:
                bx, by, bmask, lengths = batch
                logits = model(bx.to(DEVICE), lengths)
                all_masks.append(bmask.numpy())
            else:
                bx, by, bmask = batch
                logits = model(bx.to(DEVICE))
                all_masks.append(bmask.numpy())
            all_preds.append(logits.cpu().numpy())
            all_targets.append(by.numpy())

    y_pred = np.vstack(all_preds)
    y_true = np.vstack(all_targets)
    mask = np.vstack(all_masks)

    accuracy_res = {}
    for i, t in enumerate(PREDICTION_TARGETS):
        m = mask[:, i]
        if m.sum() == 0: continue
        # Directional agreement: both positive or both negative
        correct_dir = (np.sign(y_pred[m, i]) == np.sign(y_true[m, i])).sum()
        accuracy_res[t] = correct_dir / m.sum()
    return accuracy_res

print("--- Directional Accuracy (Improved Pipeline) ---")
for l_type, params in best_mtl_imp.items():
    model_imp, _, _, test_loader_imp = build_loaders_and_model(True, params)
    dir_acc = calculate_directional_accuracy(model_imp, test_loader_imp, True)
    print(f"[{l_type.upper()}] Directional Accuracy:", dir_acc)
# Out:
# --- Directional Accuracy (Improved Pipeline) ---
# [L1] Directional Accuracy: {'EBITDA': np.float64(0.4315352697095436), 'Net_Income': np.float64(0.5318275154004107), 'ROA': np.float64(0.4948665297741273)}
# [MSE] Directional Accuracy: {'EBITDA': np.float64(0.6307053941908713), 'Net_Income': np.float64(0.4722792607802875), 'ROA': np.float64(0.5297741273100616)}
# [HUBER] Directional Accuracy: {'EBITDA': np.float64(0.37136929460580914), 'Net_Income': np.float64(0.5503080082135524), 'ROA': np.float64(0.5174537987679672)}

# %% [markdown]
# ### Specialized Models by Market Cap

# %%
def run_dedicated_pipeline(group_name, tickers, loss_type='l1'):
    print(f"--- Dedicated Pipeline: {group_name} ({loss_type.upper()}) ---")
    group_df = improved_data_df[improved_data_df['company'].isin(tickers)].copy()
    if group_df.empty:
        print(f"No data for {group_name}")
        return

    g_train, g_val, g_test = split_by_year(group_df, TRAIN_YEAR_CUTOFF, VALID_YEAR_CUTOFF)

    # Scoping scaler to group
    g_scaler = RobustScaler()
    g_train_windows = np.vstack([row[:, selected_indices] for row in g_train["window_data"]])
    g_scaler.fit(g_train_windows)

    g_mtl_train = extract_mtl_df(g_train)
    g_mtl_val = extract_mtl_df(g_val)
    g_mtl_test = extract_mtl_df(g_test)

    def group_objective(trial):
        hidden_size = trial.suggest_categorical("hidden_size", [32, 64, 128])
        lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
        batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
        weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
        dropout = trial.suggest_float("dropout", 0.1, 0.5)

        train_ds = ImprovedYoYDatasetMTL(g_mtl_train, g_scaler, selected_indices)
        val_ds = ImprovedYoYDatasetMTL(g_mtl_val, g_scaler, selected_indices)

        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate_fn_improved_mtl)
        val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn_improved_mtl)

        model = ImprovedShallowLSTM(len(selected_indices), hidden_size, len(PREDICTION_TARGETS), dropout).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

        _, best_metric = train_and_eval(model, train_loader, val_loader, optimizer, True, trial, loss_type=loss_type)
        return best_metric

    pruner = optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=15)
    study = optuna.create_study(direction="minimize", study_name=f"mtl_imp_{group_name}", pruner=pruner)
    study.optimize(group_objective, n_trials=OPTUNA_TRIALS)

    best_params = study.best_trial.params
    print(f"Best Params for {group_name}: {best_params}\n")

    # Final evaluation multiple runs
    target_results = {t: [] for t in PREDICTION_TARGETS}

    for run_idx in range(N_RUNS):
        set_seed(SEED + run_idx)
        train_ds = ImprovedYoYDatasetMTL(g_mtl_train, g_scaler, selected_indices)
        val_ds = ImprovedYoYDatasetMTL(g_mtl_val, g_scaler, selected_indices)
        test_ds = ImprovedYoYDatasetMTL(g_mtl_test, g_scaler, selected_indices)

        train_loader = DataLoader(train_ds, batch_size=best_params["batch_size"], shuffle=True, collate_fn=collate_fn_improved_mtl)
        val_loader = DataLoader(val_ds, batch_size=best_params["batch_size"], shuffle=False, collate_fn=collate_fn_improved_mtl)
        test_loader = DataLoader(test_ds, batch_size=best_params["batch_size"], shuffle=False, collate_fn=collate_fn_improved_mtl)

        dropout_val = best_params.get("dropout", 0.2)
        model = ImprovedShallowLSTM(len(selected_indices), best_params["hidden_size"], len(PREDICTION_TARGETS), dropout_val).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params["lr"], weight_decay=best_params["weight_decay"])

        model, _ = train_and_eval(model, train_loader, val_loader, optimizer, True, None, loss_type=loss_type)
        res = evaluate_loader(model, test_loader, True)

        if res:
            for target, val in res.items():
                target_results[target].append(val)

        group_stats = []

    # MAE per target
    for target in PREDICTION_TARGETS:
        avg_mae = np.mean(target_results[target])
        std_mae = np.std(target_results[target])

        group_stats.append({
            "Group": group_name,
            "Target": target,
            "Dedicated Test MAE": avg_mae,
            "Dedicated Deviation": std_mae
        })

    total_mae = np.mean([
        np.mean(target_results[target])
        for target in PREDICTION_TARGETS
    ])

    total_std = np.std([
        np.mean(target_results[target])
        for target in PREDICTION_TARGETS
    ])

    print(f"{group_name} - Total Test MAE: {total_mae:.4f} ± {total_std:.4f}")

    group_stats.append({
        "Group": group_name,
        "Target": "TOTAL",
        "Dedicated Test MAE": total_mae,
        "Dedicated Deviation": total_std
    })

    return group_stats

dedicated_all_stats = []
for group_name, tickers in ticker_groups.items():
    stats = run_dedicated_pipeline(group_name, tickers, loss_type='l1') # Defaulting to L1 as champion
    if stats:
        dedicated_all_stats.extend(stats)

df_dedicated = pd.DataFrame(dedicated_all_stats)
display(df_dedicated.pivot(index='Target', columns='Group', values='Dedicated Test MAE'))
# Out:
# --- Dedicated Pipeline: MIB (L1) ---
# [I 2026-06-09 13:36:37,825] A new study created in memory with name: mtl_imp_MIB
# [I 2026-06-09 13:37:01,540] Trial 0 finished with value: 3.2393970489501953 and parameters: {'hidden_size': 64, 'lr': 0.00033394693981808214, 'batch_size': 16, 'weight_decay': 5.520454939337981e-06, 'dropout': 0.1597438568222771}. Best is trial 0 with value: 3.2393970489501953.
# [I 2026-06-09 13:37:10,768] Trial 1 finished with value: 3.2112629413604736 and parameters: {'hidden_size': 32, 'lr': 0.0034624333747282606, 'batch_size': 32, 'weight_decay': 0.00069538361166545, 'dropout': 0.31359549926897357}. Best is trial 1 with value: 3.2112629413604736.
# [I 2026-06-09 13:37:15,528] Trial 2 finished with value: 3.2050540447235107 and parameters: {'hidden_size': 128, 'lr': 0.001090209309503447, 'batch_size': 16, 'weight_decay': 3.0235842334655288e-05, 'dropout': 0.11609442500888463}. Best is trial 2 with value: 3.2050540447235107.
# [I 2026-06-09 13:37:24,722] Trial 3 finished with value: 3.1962947845458984 and parameters: {'hidden_size': 128, 'lr': 0.006264294511119878, 'batch_size': 16, 'weight_decay': 0.0008915768999733689, 'dropout': 0.4490322895238731}. Best is trial 3 with value: 3.1962947845458984.
# [I 2026-06-09 13:37:28,065] Trial 4 finished with value: 3.197815179824829 and parameters: {'hidden_size': 128, 'lr': 0.006439269061195092, 'batch_size': 32, 'weight_decay': 3.6384048809089867e-06, 'dropout': 0.21401280937387127}. Best is trial 3 with value: 3.1962947845458984.
# [I 2026-06-09 13:37:38,087] Trial 5 finished with value: 3.2229373455047607 and parameters: {'hidden_size': 64, 'lr': 0.00022770087988650722, 'batch_size': 16, 'weight_decay': 0.00024068931286179077, 'dropout': 0.16404763950915008}. Best is trial 3 with value: 3.1962947845458984.
# [I 2026-06-09 13:37:43,043] Trial 6 finished with value: 3.2745721340179443 and parameters: {'hidden_size': 64, 'lr': 0.00018551916442122827, 'batch_size': 64, 'weight_decay': 1.3351491933552963e-05, 'dropout': 0.2860705952294449}. Best is trial 3 with value: 3.1962947845458984.
# [I 2026-06-09 13:37:50,532] Trial 7 finished with value: 3.190805196762085 and parameters: {'hidden_size': 32, 'lr': 0.001570410125682601, 'batch_size': 16, 'weight_decay': 6.566588551542508e-05, 'dropout': 0.4390545638910722}. Best is trial 7 with value: 3.190805196762085.
# [I 2026-06-09 13:37:59,215] Trial 8 finished with value: 3.1936137676239014 and parameters: {'hidden_size': 32, 'lr': 0.0007802928320540845, 'batch_size': 16, 'weight_decay': 0.000263134846939179, 'dropout': 0.23186392636881936}. Best is trial 7 with value: 3.190805196762085.
# [I 2026-06-09 13:38:09,684] Trial 9 finished with value: 3.18871808052063 and parameters: {'hidden_size': 32, 'lr': 0.0015548467889591102, 'batch_size': 64, 'weight_decay': 1.693608768944303e-06, 'dropout': 0.341091939716518}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:38:12,334] Trial 10 pruned.
# [I 2026-06-09 13:38:14,948] Trial 11 pruned.
# [I 2026-06-09 13:38:17,414] Trial 12 finished with value: 3.2009830474853516 and parameters: {'hidden_size': 32, 'lr': 0.0017515978215061527, 'batch_size': 64, 'weight_decay': 1.01044249285608e-06, 'dropout': 0.3925035880377129}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:38:20,666] Trial 13 pruned.
# [I 2026-06-09 13:38:23,972] Trial 14 pruned.
# [I 2026-06-09 13:38:29,388] Trial 15 finished with value: 3.1955254077911377 and parameters: {'hidden_size': 32, 'lr': 0.002902340078676707, 'batch_size': 16, 'weight_decay': 0.00012581244834178099, 'dropout': 0.46154414881515693}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:38:33,948] Trial 16 pruned.
# [I 2026-06-09 13:38:39,585] Trial 17 finished with value: 3.1944494247436523 and parameters: {'hidden_size': 32, 'lr': 0.004488346292165083, 'batch_size': 64, 'weight_decay': 4.16687159332207e-06, 'dropout': 0.35099399354958843}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:38:44,198] Trial 18 pruned.
# [I 2026-06-09 13:38:47,930] Trial 19 finished with value: 3.2038021087646484 and parameters: {'hidden_size': 128, 'lr': 0.009687402280972273, 'batch_size': 32, 'weight_decay': 2.172133660169819e-06, 'dropout': 0.4154368914793479}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:38:50,520] Trial 20 pruned.
# [I 2026-06-09 13:38:54,679] Trial 21 pruned.
# [I 2026-06-09 13:38:59,322] Trial 22 pruned.
# [I 2026-06-09 13:39:03,318] Trial 23 pruned.
# [I 2026-06-09 13:39:07,439] Trial 24 pruned.
# [I 2026-06-09 13:39:11,988] Trial 25 pruned.
# [I 2026-06-09 13:39:20,900] Trial 26 finished with value: 3.1924331188201904 and parameters: {'hidden_size': 32, 'lr': 0.002659341124996666, 'batch_size': 16, 'weight_decay': 0.0004226200960140802, 'dropout': 0.17390317862237237}. Best is trial 9 with value: 3.18871808052063.
# [I 2026-06-09 13:39:25,264] Trial 27 pruned.
# [I 2026-06-09 13:39:28,146] Trial 28 pruned.
# [I 2026-06-09 13:39:35,442] Trial 29 finished with value: 3.183743715286255 and parameters: {'hidden_size': 64, 'lr': 0.0047639846588888755, 'batch_size': 32, 'weight_decay': 0.0004627785003174142, 'dropout': 0.137398162298415}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:39:39,021] Trial 30 finished with value: 3.205381155014038 and parameters: {'hidden_size': 64, 'lr': 0.004641932158373863, 'batch_size': 32, 'weight_decay': 1.0844013463499635e-06, 'dropout': 0.4605578191736961}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:39:43,732] Trial 31 finished with value: 3.1931540966033936 and parameters: {'hidden_size': 64, 'lr': 0.004112181304521836, 'batch_size': 32, 'weight_decay': 0.0004708259262033211, 'dropout': 0.13788438173308887}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:39:48,813] Trial 32 finished with value: 3.1954917907714844 and parameters: {'hidden_size': 64, 'lr': 0.006246904273531176, 'batch_size': 32, 'weight_decay': 0.00018008144210477758, 'dropout': 0.18149801083168743}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:39:56,017] Trial 33 finished with value: 3.194345235824585 and parameters: {'hidden_size': 64, 'lr': 0.0015676622166320266, 'batch_size': 32, 'weight_decay': 0.000565005595904115, 'dropout': 0.13958128849152576}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:39:59,959] Trial 34 pruned.
# [I 2026-06-09 13:40:03,972] Trial 35 finished with value: 3.2098751068115234 and parameters: {'hidden_size': 128, 'lr': 0.009505368899600648, 'batch_size': 16, 'weight_decay': 0.00038217259129400477, 'dropout': 0.1178478854208743}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:12,936] Trial 36 finished with value: 3.195540189743042 and parameters: {'hidden_size': 64, 'lr': 0.002421015962689911, 'batch_size': 16, 'weight_decay': 0.0007583139802164452, 'dropout': 0.1843587921460571}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:18,729] Trial 37 finished with value: 3.1847169399261475 and parameters: {'hidden_size': 32, 'lr': 0.006413677184482696, 'batch_size': 32, 'weight_decay': 5.550706873568326e-06, 'dropout': 0.28207525116189525}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:22,973] Trial 38 finished with value: 3.200672149658203 and parameters: {'hidden_size': 128, 'lr': 0.00704272842886344, 'batch_size': 32, 'weight_decay': 2.417533107789274e-06, 'dropout': 0.29513259857594587}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:27,224] Trial 39 pruned.
# [I 2026-06-09 13:40:30,381] Trial 40 pruned.
# [I 2026-06-09 13:40:37,449] Trial 41 finished with value: 3.1962385177612305 and parameters: {'hidden_size': 32, 'lr': 0.0037837032242149, 'batch_size': 32, 'weight_decay': 0.0001781863347371173, 'dropout': 0.30250409534177186}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:40,960] Trial 42 finished with value: 3.2023284435272217 and parameters: {'hidden_size': 32, 'lr': 0.0056747247869546776, 'batch_size': 32, 'weight_decay': 1.4928620619414355e-06, 'dropout': 0.20445108090113473}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:40:43,560] Trial 43 pruned.
# [I 2026-06-09 13:40:48,372] Trial 44 pruned.
# [I 2026-06-09 13:40:51,187] Trial 45 pruned.
# [I 2026-06-09 13:40:55,391] Trial 46 pruned.
# [I 2026-06-09 13:40:58,671] Trial 47 pruned.
# [I 2026-06-09 13:41:01,939] Trial 48 pruned.
# [I 2026-06-09 13:41:05,566] Trial 49 finished with value: 3.25163197517395 and parameters: {'hidden_size': 64, 'lr': 0.00028146582782474463, 'batch_size': 16, 'weight_decay': 0.000662005309322505, 'dropout': 0.15993236012493528}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:41:09,421] Trial 50 pruned.
# [I 2026-06-09 13:41:13,922] Trial 51 pruned.
# [I 2026-06-09 13:41:17,382] Trial 52 pruned.
# [I 2026-06-09 13:41:20,982] Trial 53 finished with value: 3.1908397674560547 and parameters: {'hidden_size': 64, 'lr': 0.0025138109501879773, 'batch_size': 32, 'weight_decay': 0.0004705453497658635, 'dropout': 0.17487408094806872}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:41:24,352] Trial 54 finished with value: 3.2233970165252686 and parameters: {'hidden_size': 64, 'lr': 0.0026017017348937328, 'batch_size': 32, 'weight_decay': 0.00023399676339605662, 'dropout': 0.20709460342408714}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:41:27,461] Trial 55 pruned.
# [I 2026-06-09 13:41:31,650] Trial 56 pruned.
# [I 2026-06-09 13:41:34,659] Trial 57 finished with value: 3.2375175952911377 and parameters: {'hidden_size': 32, 'lr': 0.0031739189723683048, 'batch_size': 32, 'weight_decay': 2.7531362865840116e-05, 'dropout': 0.22206946037279998}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:41:37,704] Trial 58 pruned.
# [I 2026-06-09 13:41:42,030] Trial 59 pruned.
# [I 2026-06-09 13:41:45,442] Trial 60 pruned.
# [I 2026-06-09 13:41:49,765] Trial 61 finished with value: 3.1852920055389404 and parameters: {'hidden_size': 64, 'lr': 0.004208469038326672, 'batch_size': 32, 'weight_decay': 0.00047757283426622116, 'dropout': 0.14422467405780526}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:41:53,371] Trial 62 pruned.
# [I 2026-06-09 13:41:57,265] Trial 63 pruned.
# [I 2026-06-09 13:42:00,374] Trial 64 finished with value: 3.18798565864563 and parameters: {'hidden_size': 64, 'lr': 0.007670799415335552, 'batch_size': 32, 'weight_decay': 4.905571706084195e-06, 'dropout': 0.157346502317815}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:04,001] Trial 65 finished with value: 3.2069404125213623 and parameters: {'hidden_size': 64, 'lr': 0.007223363444417512, 'batch_size': 32, 'weight_decay': 4.4254283350771935e-06, 'dropout': 0.1567130374172093}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:07,308] Trial 66 pruned.
# [I 2026-06-09 13:42:11,589] Trial 67 finished with value: 3.188819169998169 and parameters: {'hidden_size': 64, 'lr': 0.005844795142730831, 'batch_size': 32, 'weight_decay': 2.7991333065010606e-06, 'dropout': 0.4171760439320697}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:15,980] Trial 68 finished with value: 3.202716827392578 and parameters: {'hidden_size': 64, 'lr': 0.005982850979875133, 'batch_size': 32, 'weight_decay': 2.28512260498207e-06, 'dropout': 0.4060998418239201}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:20,195] Trial 69 pruned.
# [I 2026-06-09 13:42:23,851] Trial 70 finished with value: 3.1962881088256836 and parameters: {'hidden_size': 64, 'lr': 0.008280896499924457, 'batch_size': 32, 'weight_decay': 1.480468632279785e-06, 'dropout': 0.4805325165356772}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:28,589] Trial 71 pruned.
# [I 2026-06-09 13:42:31,980] Trial 72 pruned.
# [I 2026-06-09 13:42:35,301] Trial 73 pruned.
# [I 2026-06-09 13:42:38,841] Trial 74 pruned.
# [I 2026-06-09 13:42:43,403] Trial 75 pruned.
# [I 2026-06-09 13:42:46,107] Trial 76 pruned.
# [I 2026-06-09 13:42:50,080] Trial 77 pruned.
# [I 2026-06-09 13:42:56,711] Trial 78 finished with value: 3.1985957622528076 and parameters: {'hidden_size': 64, 'lr': 0.007987668443083963, 'batch_size': 32, 'weight_decay': 2.0007227112067197e-06, 'dropout': 0.16739586009915622}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:42:59,390] Trial 79 pruned.
# [I 2026-06-09 13:43:03,604] Trial 80 finished with value: 3.2007713317871094 and parameters: {'hidden_size': 128, 'lr': 0.0054568965994601605, 'batch_size': 32, 'weight_decay': 0.0003095491786120959, 'dropout': 0.4377747940394562}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:43:09,113] Trial 81 finished with value: 3.191218137741089 and parameters: {'hidden_size': 32, 'lr': 0.002477888957424047, 'batch_size': 16, 'weight_decay': 0.0005026960615975634, 'dropout': 0.19471960322723053}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:43:18,125] Trial 82 finished with value: 3.187701463699341 and parameters: {'hidden_size': 32, 'lr': 0.0032903978116036476, 'batch_size': 16, 'weight_decay': 0.000528870138135143, 'dropout': 0.18814674353646182}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:43:22,860] Trial 83 finished with value: 3.194366693496704 and parameters: {'hidden_size': 32, 'lr': 0.003130743264692832, 'batch_size': 16, 'weight_decay': 6.502921527829966e-06, 'dropout': 0.18304140672383426}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:43:27,005] Trial 84 pruned.
# [I 2026-06-09 13:43:30,895] Trial 85 pruned.
# [I 2026-06-09 13:43:35,981] Trial 86 pruned.
# [I 2026-06-09 13:43:38,786] Trial 87 pruned.
# [I 2026-06-09 13:43:42,407] Trial 88 finished with value: 3.2329654693603516 and parameters: {'hidden_size': 32, 'lr': 0.004739095501309697, 'batch_size': 32, 'weight_decay': 0.00028941589069195417, 'dropout': 0.1774410521498451}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:43:45,945] Trial 89 pruned.
# [I 2026-06-09 13:43:51,036] Trial 90 pruned.
# [I 2026-06-09 13:43:55,928] Trial 91 pruned.
# [I 2026-06-09 13:44:00,836] Trial 92 finished with value: 3.195021390914917 and parameters: {'hidden_size': 32, 'lr': 0.0024268416106403468, 'batch_size': 16, 'weight_decay': 0.0005445488725765073, 'dropout': 0.1681501571313733}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:44:08,118] Trial 93 finished with value: 3.195801019668579 and parameters: {'hidden_size': 32, 'lr': 0.001614727591776754, 'batch_size': 16, 'weight_decay': 0.0009967198101921188, 'dropout': 0.20246155238616953}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:44:13,062] Trial 94 pruned.
# [I 2026-06-09 13:44:19,716] Trial 95 finished with value: 3.1859776973724365 and parameters: {'hidden_size': 32, 'lr': 0.002884869206884815, 'batch_size': 16, 'weight_decay': 0.0005066899052191753, 'dropout': 0.11257742281788267}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:44:23,118] Trial 96 pruned.
# [I 2026-06-09 13:44:30,127] Trial 97 finished with value: 3.193338394165039 and parameters: {'hidden_size': 64, 'lr': 0.002918926091292312, 'batch_size': 64, 'weight_decay': 0.000713772504355047, 'dropout': 0.11351459916392187}. Best is trial 29 with value: 3.183743715286255.
# [I 2026-06-09 13:44:34,928] Trial 98 pruned.
# [I 2026-06-09 13:44:38,459] Trial 99 pruned.
# Best Params for MIB: {'hidden_size': 64, 'lr': 0.0047639846588888755, 'batch_size': 32, 'weight_decay': 0.0004627785003174142, 'dropout': 0.137398162298415}
#
# MIB - Total Test MAE: 1.1194 ± 0.5330
# --- Dedicated Pipeline: Mid-cap (L1) ---
# [I 2026-06-09 13:46:15,458] A new study created in memory with name: mtl_imp_Mid-cap
# [I 2026-06-09 13:46:20,249] Trial 0 finished with value: 1.3854198455810547 and parameters: {'hidden_size': 64, 'lr': 0.0007760041563306649, 'batch_size': 32, 'weight_decay': 0.00032688538898296537, 'dropout': 0.11462011092617184}. Best is trial 0 with value: 1.3854198455810547.
# [I 2026-06-09 13:46:25,663] Trial 1 finished with value: 1.3796652555465698 and parameters: {'hidden_size': 32, 'lr': 0.0023475976550181347, 'batch_size': 64, 'weight_decay': 0.0008037673215877992, 'dropout': 0.10280236130787435}. Best is trial 1 with value: 1.3796652555465698.
# [I 2026-06-09 13:46:29,413] Trial 2 finished with value: 1.405164361000061 and parameters: {'hidden_size': 64, 'lr': 0.0005172517117526508, 'batch_size': 32, 'weight_decay': 5.21249595830484e-05, 'dropout': 0.10665703567990432}. Best is trial 1 with value: 1.3796652555465698.
# [I 2026-06-09 13:46:34,169] Trial 3 finished with value: 1.3795342445373535 and parameters: {'hidden_size': 64, 'lr': 0.0037119330433934487, 'batch_size': 32, 'weight_decay': 6.598982603840384e-06, 'dropout': 0.20723175899906898}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:46:40,782] Trial 4 finished with value: 1.381734848022461 and parameters: {'hidden_size': 32, 'lr': 0.0002231080484554408, 'batch_size': 16, 'weight_decay': 1.1064956143385574e-05, 'dropout': 0.14429989922984054}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:46:47,823] Trial 5 finished with value: 1.4099291563034058 and parameters: {'hidden_size': 32, 'lr': 0.0019769456819851076, 'batch_size': 16, 'weight_decay': 7.022868595609067e-05, 'dropout': 0.1657429998053072}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:46:53,933] Trial 6 finished with value: 1.4076083898544312 and parameters: {'hidden_size': 128, 'lr': 0.0013040505968153792, 'batch_size': 16, 'weight_decay': 0.00024409017700172575, 'dropout': 0.41423395888360526}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:47:02,584] Trial 7 finished with value: 1.3827710151672363 and parameters: {'hidden_size': 32, 'lr': 0.0031970794859084452, 'batch_size': 32, 'weight_decay': 0.000675602546781786, 'dropout': 0.3664306170891124}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:47:17,555] Trial 8 finished with value: 1.4049960374832153 and parameters: {'hidden_size': 64, 'lr': 0.00016269884652988855, 'batch_size': 16, 'weight_decay': 3.7084926338205987e-06, 'dropout': 0.25186267546412894}. Best is trial 3 with value: 1.3795342445373535.
# [I 2026-06-09 13:47:25,189] Trial 9 finished with value: 1.3786158561706543 and parameters: {'hidden_size': 32, 'lr': 0.00554754268455156, 'batch_size': 16, 'weight_decay': 3.910142854513963e-05, 'dropout': 0.2503566875806422}. Best is trial 9 with value: 1.3786158561706543.
# [I 2026-06-09 13:47:30,117] Trial 10 finished with value: 1.3837518692016602 and parameters: {'hidden_size': 128, 'lr': 0.0099636460351796, 'batch_size': 64, 'weight_decay': 1.149269201967523e-06, 'dropout': 0.4919146118354183}. Best is trial 9 with value: 1.3786158561706543.
# [I 2026-06-09 13:47:34,995] Trial 11 finished with value: 1.392459750175476 and parameters: {'hidden_size': 64, 'lr': 0.008724507815147243, 'batch_size': 32, 'weight_decay': 1.3438768770820905e-05, 'dropout': 0.24086235958020807}. Best is trial 9 with value: 1.3786158561706543.
# [I 2026-06-09 13:47:42,344] Trial 12 finished with value: 1.3965858221054077 and parameters: {'hidden_size': 32, 'lr': 0.004812108589851203, 'batch_size': 16, 'weight_decay': 2.3251431225767593e-05, 'dropout': 0.24922006804145594}. Best is trial 9 with value: 1.3786158561706543.
# [I 2026-06-09 13:47:47,030] Trial 13 finished with value: 1.3845361471176147 and parameters: {'hidden_size': 64, 'lr': 0.0046356988721208935, 'batch_size': 32, 'weight_decay': 3.142286563496263e-06, 'dropout': 0.3234669694963784}. Best is trial 9 with value: 1.3786158561706543.
# [I 2026-06-09 13:47:51,706] Trial 14 finished with value: 1.3760648965835571 and parameters: {'hidden_size': 128, 'lr': 0.004771932737555349, 'batch_size': 64, 'weight_decay': 6.199299352360339e-05, 'dropout': 0.19808728371509407}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:47:56,464] Trial 15 finished with value: 1.3808064460754395 and parameters: {'hidden_size': 128, 'lr': 0.006533642000658437, 'batch_size': 64, 'weight_decay': 9.469218971003695e-05, 'dropout': 0.2984279079473505}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:47:59,750] Trial 16 finished with value: 1.3903498649597168 and parameters: {'hidden_size': 128, 'lr': 0.001476547359545534, 'batch_size': 64, 'weight_decay': 3.554901238991103e-05, 'dropout': 0.18901887932547595}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:48:04,599] Trial 17 finished with value: 1.3819656372070312 and parameters: {'hidden_size': 128, 'lr': 0.005792363759787663, 'batch_size': 64, 'weight_decay': 0.00017010493682109652, 'dropout': 0.29273916708002934}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:48:09,431] Trial 18 pruned.
# [I 2026-06-09 13:48:18,484] Trial 19 finished with value: 1.3910619020462036 and parameters: {'hidden_size': 128, 'lr': 0.0026975668151823637, 'batch_size': 16, 'weight_decay': 2.511958389976215e-05, 'dropout': 0.3578849290625342}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:48:23,445] Trial 20 pruned.
# [I 2026-06-09 13:48:28,801] Trial 21 finished with value: 1.3994988203048706 and parameters: {'hidden_size': 64, 'lr': 0.0036870699213526225, 'batch_size': 32, 'weight_decay': 1.1723963331270868e-05, 'dropout': 0.203006246222529}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:48:34,352] Trial 22 finished with value: 1.3835798501968384 and parameters: {'hidden_size': 64, 'lr': 0.007086056183660322, 'batch_size': 16, 'weight_decay': 5.104814094538304e-06, 'dropout': 0.2747796355547908}. Best is trial 14 with value: 1.3760648965835571.
# [I 2026-06-09 13:48:38,334] Trial 23 finished with value: 1.3755091428756714 and parameters: {'hidden_size': 32, 'lr': 0.00392218282600513, 'batch_size': 32, 'weight_decay': 1.2289000030390197e-06, 'dropout': 0.21878637401830048}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:48:43,462] Trial 24 finished with value: 1.3940852880477905 and parameters: {'hidden_size': 32, 'lr': 0.0016544003035334554, 'batch_size': 64, 'weight_decay': 1.080787071893955e-06, 'dropout': 0.22399718625447956}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:48:47,816] Trial 25 finished with value: 1.4312041997909546 and parameters: {'hidden_size': 32, 'lr': 0.004518434247915782, 'batch_size': 32, 'weight_decay': 2.1777617870926393e-06, 'dropout': 0.18079075628591046}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:48:54,103] Trial 26 finished with value: 1.4382715225219727 and parameters: {'hidden_size': 32, 'lr': 0.002696695732382966, 'batch_size': 16, 'weight_decay': 1.9413129078942466e-05, 'dropout': 0.2686412910478345}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:48:58,855] Trial 27 finished with value: 1.3837767839431763 and parameters: {'hidden_size': 32, 'lr': 0.007286854211641528, 'batch_size': 64, 'weight_decay': 0.00037779942850726093, 'dropout': 0.326975184029044}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:04,035] Trial 28 pruned.
# [I 2026-06-09 13:49:13,791] Trial 29 finished with value: 1.3983079195022583 and parameters: {'hidden_size': 128, 'lr': 0.0011010374007000678, 'batch_size': 16, 'weight_decay': 0.00045189998536865664, 'dropout': 0.13149384312808637}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:19,288] Trial 30 pruned.
# [I 2026-06-09 13:49:25,370] Trial 31 finished with value: 1.394234538078308 and parameters: {'hidden_size': 64, 'lr': 0.003676103399274197, 'batch_size': 32, 'weight_decay': 6.076120075349756e-06, 'dropout': 0.19768515100699918}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:30,635] Trial 32 finished with value: 1.391013741493225 and parameters: {'hidden_size': 64, 'lr': 0.003545155438935267, 'batch_size': 32, 'weight_decay': 7.576065361798276e-06, 'dropout': 0.1769643594851658}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:38,178] Trial 33 finished with value: 1.3922048807144165 and parameters: {'hidden_size': 32, 'lr': 0.001991273235623587, 'batch_size': 32, 'weight_decay': 1.7270526810482584e-06, 'dropout': 0.20972712620083342}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:44,063] Trial 34 finished with value: 1.4049530029296875 and parameters: {'hidden_size': 64, 'lr': 0.004132898061627463, 'batch_size': 32, 'weight_decay': 3.2485195452499764e-05, 'dropout': 0.12037722867949051}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:49:51,330] Trial 35 pruned.
# [I 2026-06-09 13:49:58,065] Trial 36 finished with value: 1.4118375778198242 and parameters: {'hidden_size': 128, 'lr': 0.0005684665134999183, 'batch_size': 16, 'weight_decay': 8.347529398345116e-06, 'dropout': 0.16047342832413014}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:50:02,520] Trial 37 finished with value: 1.389910340309143 and parameters: {'hidden_size': 32, 'lr': 0.007709955956126164, 'batch_size': 64, 'weight_decay': 5.8642434402137395e-05, 'dropout': 0.22905834384124904}. Best is trial 23 with value: 1.3755091428756714.
# [I 2026-06-09 13:50:07,442] Trial 38 finished with value: 1.3733106851577759 and parameters: {'hidden_size': 64, 'lr': 0.005426748767587874, 'batch_size': 32, 'weight_decay': 3.6520300079748134e-06, 'dropout': 0.2908379909201838}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:12,352] Trial 39 finished with value: 1.3901114463806152 and parameters: {'hidden_size': 64, 'lr': 0.005591115511462178, 'batch_size': 32, 'weight_decay': 1.4745277513941973e-06, 'dropout': 0.30158532055967024}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:20,879] Trial 40 finished with value: 1.3814282417297363 and parameters: {'hidden_size': 128, 'lr': 0.008709222087212885, 'batch_size': 16, 'weight_decay': 2.8238168578614906e-06, 'dropout': 0.4003945526865071}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:25,160] Trial 41 finished with value: 1.3849372863769531 and parameters: {'hidden_size': 64, 'lr': 0.003100720955921292, 'batch_size': 32, 'weight_decay': 3.5343658701514466e-06, 'dropout': 0.26862549609412834}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:29,796] Trial 42 finished with value: 1.3980202674865723 and parameters: {'hidden_size': 64, 'lr': 0.005275248504549227, 'batch_size': 32, 'weight_decay': 4.475621506105417e-06, 'dropout': 0.24264332394991614}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:36,132] Trial 43 finished with value: 1.3924245834350586 and parameters: {'hidden_size': 64, 'lr': 0.002075890721704845, 'batch_size': 32, 'weight_decay': 8.242560843224457e-06, 'dropout': 0.2802856121074673}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:41,139] Trial 44 finished with value: 1.394809603691101 and parameters: {'hidden_size': 64, 'lr': 0.00401574901325978, 'batch_size': 32, 'weight_decay': 1.461754965318998e-06, 'dropout': 0.20624599382723133}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:49,079] Trial 45 pruned.
# [I 2026-06-09 13:50:54,603] Trial 46 finished with value: 1.3911371231079102 and parameters: {'hidden_size': 64, 'lr': 0.008654530337517792, 'batch_size': 16, 'weight_decay': 0.00020715274440729739, 'dropout': 0.32382450084117054}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:50:59,584] Trial 47 finished with value: 1.4025825262069702 and parameters: {'hidden_size': 128, 'lr': 0.00012684986379629743, 'batch_size': 64, 'weight_decay': 2.4948403077614644e-06, 'dropout': 0.3087291083379994}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:05,154] Trial 48 finished with value: 1.3968461751937866 and parameters: {'hidden_size': 32, 'lr': 0.004798116969816668, 'batch_size': 32, 'weight_decay': 0.00012390094028248222, 'dropout': 0.24840000864824183}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:08,614] Trial 49 finished with value: 1.4124013185501099 and parameters: {'hidden_size': 64, 'lr': 0.0024865348293448674, 'batch_size': 64, 'weight_decay': 4.6585843806514436e-05, 'dropout': 0.10081249745245091}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:15,433] Trial 50 finished with value: 1.3854535818099976 and parameters: {'hidden_size': 128, 'lr': 0.009773663320347344, 'batch_size': 16, 'weight_decay': 2.8063278138424654e-05, 'dropout': 0.19213435993513234}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:19,457] Trial 51 pruned.
# [I 2026-06-09 13:51:25,090] Trial 52 finished with value: 1.4019979238510132 and parameters: {'hidden_size': 32, 'lr': 0.0034552454541221934, 'batch_size': 64, 'weight_decay': 0.0006368399201791893, 'dropout': 0.1695316674103235}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:30,643] Trial 53 pruned.
# [I 2026-06-09 13:51:38,527] Trial 54 finished with value: 1.392317771911621 and parameters: {'hidden_size': 32, 'lr': 0.0013739466750399406, 'batch_size': 64, 'weight_decay': 1.5127907795094277e-05, 'dropout': 0.14433524166724965}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:43,852] Trial 55 pruned.
# [I 2026-06-09 13:51:51,002] Trial 56 finished with value: 1.3965559005737305 and parameters: {'hidden_size': 128, 'lr': 0.003011461660225073, 'batch_size': 16, 'weight_decay': 1.0859980000942757e-05, 'dropout': 0.29190711252058166}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:55,537] Trial 57 finished with value: 1.3939834833145142 and parameters: {'hidden_size': 64, 'lr': 0.004360920365824854, 'batch_size': 32, 'weight_decay': 1.0606623990462911e-06, 'dropout': 0.21919386300960136}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:51:59,419] Trial 58 finished with value: 1.4038915634155273 and parameters: {'hidden_size': 32, 'lr': 0.002427972893917988, 'batch_size': 64, 'weight_decay': 3.955707751452033e-06, 'dropout': 0.11744047286884456}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:04,425] Trial 59 pruned.
# [I 2026-06-09 13:52:09,730] Trial 60 finished with value: 1.382267951965332 and parameters: {'hidden_size': 128, 'lr': 0.003266553807109758, 'batch_size': 16, 'weight_decay': 0.00030670455931727623, 'dropout': 0.18394211864142784}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:14,339] Trial 61 finished with value: 1.3891457319259644 and parameters: {'hidden_size': 128, 'lr': 0.0069797523457303485, 'batch_size': 64, 'weight_decay': 8.337297890853298e-05, 'dropout': 0.28972527676921994}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:18,683] Trial 62 finished with value: 1.3903154134750366 and parameters: {'hidden_size': 128, 'lr': 0.006350878304598395, 'batch_size': 64, 'weight_decay': 0.00014120603951155766, 'dropout': 0.28061846072706875}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:23,516] Trial 63 pruned.
# [I 2026-06-09 13:52:29,322] Trial 64 finished with value: 1.3933073282241821 and parameters: {'hidden_size': 128, 'lr': 0.0038391841080096865, 'batch_size': 64, 'weight_decay': 3.852460086344642e-05, 'dropout': 0.31538878095086564}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:33,368] Trial 65 finished with value: 1.389743685722351 and parameters: {'hidden_size': 64, 'lr': 0.004465858695255656, 'batch_size': 64, 'weight_decay': 2.165540166167142e-05, 'dropout': 0.21305061083808918}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:38,639] Trial 66 finished with value: 1.4109951257705688 and parameters: {'hidden_size': 32, 'lr': 0.007658733100902504, 'batch_size': 32, 'weight_decay': 0.0004927080744458387, 'dropout': 0.14933975304825237}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:43,377] Trial 67 finished with value: 1.4091216325759888 and parameters: {'hidden_size': 128, 'lr': 0.005996779175497821, 'batch_size': 64, 'weight_decay': 0.00011513884135397783, 'dropout': 0.2616275933293209}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:48,435] Trial 68 finished with value: 1.3967968225479126 and parameters: {'hidden_size': 32, 'lr': 0.005299971966605349, 'batch_size': 32, 'weight_decay': 0.000964514360556039, 'dropout': 0.4496787181361269}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:52:55,025] Trial 69 pruned.
# [I 2026-06-09 13:53:00,271] Trial 70 finished with value: 1.3901928663253784 and parameters: {'hidden_size': 128, 'lr': 0.004055286722828324, 'batch_size': 32, 'weight_decay': 1.1439274966072238e-05, 'dropout': 0.22732712774451871}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:05,791] Trial 71 finished with value: 1.383662223815918 and parameters: {'hidden_size': 128, 'lr': 0.007855967096290994, 'batch_size': 16, 'weight_decay': 6.408639290534308e-06, 'dropout': 0.38882365225764415}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:15,016] Trial 72 finished with value: 1.385828971862793 and parameters: {'hidden_size': 128, 'lr': 0.008168216758512066, 'batch_size': 16, 'weight_decay': 2.759219140673193e-06, 'dropout': 0.34018234394836283}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:23,264] Trial 73 finished with value: 1.3757370710372925 and parameters: {'hidden_size': 128, 'lr': 0.009873793677354447, 'batch_size': 16, 'weight_decay': 3.104379439741139e-06, 'dropout': 0.4527520099882422}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:33,120] Trial 74 finished with value: 1.3837013244628906 and parameters: {'hidden_size': 128, 'lr': 0.0063999580839775435, 'batch_size': 16, 'weight_decay': 2.1799753427232764e-06, 'dropout': 0.4254288049994142}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:38,464] Trial 75 finished with value: 1.3905609846115112 and parameters: {'hidden_size': 128, 'lr': 0.00972945453248978, 'batch_size': 16, 'weight_decay': 3.3078878963352936e-06, 'dropout': 0.13221290758274362}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:43,011] Trial 76 finished with value: 1.4034045934677124 and parameters: {'hidden_size': 64, 'lr': 0.0047189375528314285, 'batch_size': 32, 'weight_decay': 1.4382429435596318e-06, 'dropout': 0.19675279411899982}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:50,085] Trial 77 finished with value: 1.3998533487319946 and parameters: {'hidden_size': 32, 'lr': 0.0028153564011985438, 'batch_size': 16, 'weight_decay': 4.471410236545315e-06, 'dropout': 0.1756290852554188}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:53:56,096] Trial 78 finished with value: 1.3954310417175293 and parameters: {'hidden_size': 64, 'lr': 0.005486799511349797, 'batch_size': 64, 'weight_decay': 4.0853695706267474e-05, 'dropout': 0.4625086286702244}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:01,269] Trial 79 finished with value: 1.388288140296936 and parameters: {'hidden_size': 128, 'lr': 0.003447593689188663, 'batch_size': 32, 'weight_decay': 0.00016540166167382125, 'dropout': 0.24588647799443328}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:05,972] Trial 80 finished with value: 1.378318428993225 and parameters: {'hidden_size': 32, 'lr': 0.007044850431881941, 'batch_size': 64, 'weight_decay': 3.045136570032521e-05, 'dropout': 0.3023656783768205}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:10,362] Trial 81 finished with value: 1.3985610008239746 and parameters: {'hidden_size': 32, 'lr': 0.007138650112033935, 'batch_size': 64, 'weight_decay': 3.079033589693399e-05, 'dropout': 0.27250140562334135}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:14,866] Trial 82 finished with value: 1.3801418542861938 and parameters: {'hidden_size': 32, 'lr': 0.009947615430783657, 'batch_size': 64, 'weight_decay': 5.0165259216179945e-05, 'dropout': 0.30021627474661355}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:19,815] Trial 83 finished with value: 1.3892706632614136 and parameters: {'hidden_size': 32, 'lr': 0.009948282502451474, 'batch_size': 64, 'weight_decay': 5.227876676999263e-05, 'dropout': 0.30080523723767244}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:25,410] Trial 84 finished with value: 1.3908076286315918 and parameters: {'hidden_size': 32, 'lr': 0.008590900663379981, 'batch_size': 64, 'weight_decay': 1.8726541959607177e-05, 'dropout': 0.3300852620230367}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:30,711] Trial 85 finished with value: 1.3995846509933472 and parameters: {'hidden_size': 32, 'lr': 0.002207732494210405, 'batch_size': 64, 'weight_decay': 1.0087825473481492e-05, 'dropout': 0.2048436228541868}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:34,934] Trial 86 finished with value: 1.3898357152938843 and parameters: {'hidden_size': 32, 'lr': 0.005875546429324927, 'batch_size': 64, 'weight_decay': 2.6311099343287393e-05, 'dropout': 0.3119257691200836}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:40,469] Trial 87 pruned.
# [I 2026-06-09 13:54:45,564] Trial 88 finished with value: 1.389478087425232 and parameters: {'hidden_size': 32, 'lr': 0.009022323283371412, 'batch_size': 16, 'weight_decay': 6.841090206956076e-05, 'dropout': 0.2816705344381305}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:54,020] Trial 89 finished with value: 1.384386658668518 and parameters: {'hidden_size': 32, 'lr': 0.005065126218324603, 'batch_size': 64, 'weight_decay': 1.2492676250597247e-06, 'dropout': 0.22102452981488183}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:54:59,003] Trial 90 finished with value: 1.3978241682052612 and parameters: {'hidden_size': 32, 'lr': 0.003766010572455418, 'batch_size': 32, 'weight_decay': 6.6241035538044995e-06, 'dropout': 0.25390417082647143}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:02,175] Trial 91 finished with value: 1.3842287063598633 and parameters: {'hidden_size': 64, 'lr': 0.007982965766513705, 'batch_size': 64, 'weight_decay': 5.092924370882566e-05, 'dropout': 0.3023524697035416}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:06,474] Trial 92 finished with value: 1.4049960374832153 and parameters: {'hidden_size': 32, 'lr': 0.00433397540581714, 'batch_size': 64, 'weight_decay': 0.0001046103523839917, 'dropout': 0.26668463342218424}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:10,108] Trial 93 finished with value: 1.3912945985794067 and parameters: {'hidden_size': 32, 'lr': 0.006635957406845725, 'batch_size': 64, 'weight_decay': 3.491533496590213e-05, 'dropout': 0.16321232026229307}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:15,871] Trial 94 finished with value: 1.391919493675232 and parameters: {'hidden_size': 128, 'lr': 0.005776142902878527, 'batch_size': 64, 'weight_decay': 4.1619640465752565e-05, 'dropout': 0.34059912779886325}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:23,283] Trial 95 finished with value: 1.3954219818115234 and parameters: {'hidden_size': 64, 'lr': 0.004947471317743078, 'batch_size': 64, 'weight_decay': 7.488360699900983e-05, 'dropout': 0.28946355422310327}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:28,960] Trial 96 finished with value: 1.3845959901809692 and parameters: {'hidden_size': 32, 'lr': 0.007334751793356375, 'batch_size': 16, 'weight_decay': 4.044249764099265e-06, 'dropout': 0.18962697889828256}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:34,037] Trial 97 finished with value: 1.3872135877609253 and parameters: {'hidden_size': 128, 'lr': 0.009149772461339006, 'batch_size': 32, 'weight_decay': 1.4507299442948985e-05, 'dropout': 0.2329762269656198}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:38,241] Trial 98 finished with value: 1.3879972696304321 and parameters: {'hidden_size': 32, 'lr': 0.0025512555328606693, 'batch_size': 64, 'weight_decay': 5.243627798121809e-06, 'dropout': 0.31997133500236297}. Best is trial 38 with value: 1.3733106851577759.
# [I 2026-06-09 13:55:44,796] Trial 99 finished with value: 1.3800382614135742 and parameters: {'hidden_size': 64, 'lr': 0.0031245360871157138, 'batch_size': 32, 'weight_decay': 6.117589257537541e-05, 'dropout': 0.29821147122366215}. Best is trial 38 with value: 1.3733106851577759.
# Best Params for Mid-cap: {'hidden_size': 64, 'lr': 0.005426748767587874, 'batch_size': 32, 'weight_decay': 3.6520300079748134e-06, 'dropout': 0.2908379909201838}
#
# Mid-cap - Total Test MAE: 1.2394 ± 0.5697
# --- Dedicated Pipeline: Small-cap (L1) ---
# [I 2026-06-09 13:57:30,157] A new study created in memory with name: mtl_imp_Small-cap
# [I 2026-06-09 13:57:42,166] Trial 0 finished with value: 13.257041931152344 and parameters: {'hidden_size': 64, 'lr': 0.005848022240010461, 'batch_size': 16, 'weight_decay': 3.736112590892339e-06, 'dropout': 0.3433044313153144}. Best is trial 0 with value: 13.257041931152344.
# [I 2026-06-09 13:57:53,661] Trial 1 finished with value: 13.288570404052734 and parameters: {'hidden_size': 32, 'lr': 0.0015539476187347461, 'batch_size': 16, 'weight_decay': 4.5568320096635844e-05, 'dropout': 0.2718966340549591}. Best is trial 0 with value: 13.257041931152344.
# [I 2026-06-09 13:58:07,763] Trial 2 finished with value: 13.258105278015137 and parameters: {'hidden_size': 32, 'lr': 0.00419146898779243, 'batch_size': 16, 'weight_decay': 2.272519836209071e-06, 'dropout': 0.1319286950823879}. Best is trial 0 with value: 13.257041931152344.
# [I 2026-06-09 13:58:32,269] Trial 3 finished with value: 13.247562408447266 and parameters: {'hidden_size': 32, 'lr': 0.0003982073272685544, 'batch_size': 64, 'weight_decay': 6.707613819888943e-05, 'dropout': 0.18858105345548154}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 13:58:45,696] Trial 4 finished with value: 13.254721641540527 and parameters: {'hidden_size': 128, 'lr': 0.00988483104444834, 'batch_size': 64, 'weight_decay': 4.276877923361183e-06, 'dropout': 0.2314781902606678}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 13:59:04,917] Trial 5 finished with value: 13.276092529296875 and parameters: {'hidden_size': 32, 'lr': 0.0008328677294596044, 'batch_size': 64, 'weight_decay': 1.2556604412949375e-05, 'dropout': 0.3540063457349205}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 13:59:45,197] Trial 6 finished with value: 13.273951530456543 and parameters: {'hidden_size': 32, 'lr': 0.00042496458675079986, 'batch_size': 16, 'weight_decay': 0.00020502732949143868, 'dropout': 0.4992077187361267}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 14:00:00,651] Trial 7 finished with value: 13.317721366882324 and parameters: {'hidden_size': 64, 'lr': 0.00041137598823505066, 'batch_size': 16, 'weight_decay': 1.34064100513637e-06, 'dropout': 0.10318130955831868}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 14:00:09,016] Trial 8 finished with value: 13.255854606628418 and parameters: {'hidden_size': 128, 'lr': 0.002682600897115114, 'batch_size': 32, 'weight_decay': 0.0007664665838731778, 'dropout': 0.22520323306966974}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 14:00:25,036] Trial 9 finished with value: 13.259769439697266 and parameters: {'hidden_size': 128, 'lr': 0.005780424537518324, 'batch_size': 16, 'weight_decay': 5.098167689766668e-06, 'dropout': 0.45648767121172407}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 14:00:32,678] Trial 10 pruned.
# [I 2026-06-09 14:00:53,689] Trial 11 pruned.
# [I 2026-06-09 14:01:01,692] Trial 12 finished with value: 13.2564115524292 and parameters: {'hidden_size': 128, 'lr': 0.009473927248609319, 'batch_size': 64, 'weight_decay': 0.00014511584573984878, 'dropout': 0.19081721153318632}. Best is trial 3 with value: 13.247562408447266.
# [I 2026-06-09 14:01:11,678] Trial 13 finished with value: 13.242308616638184 and parameters: {'hidden_size': 128, 'lr': 0.0012166808363442572, 'batch_size': 64, 'weight_decay': 9.439937279767432e-06, 'dropout': 0.2700727008349456}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:01:24,148] Trial 14 finished with value: 13.268844604492188 and parameters: {'hidden_size': 64, 'lr': 0.0008707432844517858, 'batch_size': 32, 'weight_decay': 0.00014383809844561567, 'dropout': 0.2927129344707238}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:01:31,694] Trial 15 pruned.
# [I 2026-06-09 14:01:39,948] Trial 16 finished with value: 13.258286476135254 and parameters: {'hidden_size': 128, 'lr': 0.0017899168428139474, 'batch_size': 64, 'weight_decay': 0.0006364384348835527, 'dropout': 0.2975162127201281}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:01:47,886] Trial 17 pruned.
# [I 2026-06-09 14:01:56,965] Trial 18 pruned.
# [I 2026-06-09 14:02:14,629] Trial 19 finished with value: 13.264132499694824 and parameters: {'hidden_size': 64, 'lr': 0.0006133394516030766, 'batch_size': 64, 'weight_decay': 8.606510896920639e-05, 'dropout': 0.3991400851756949}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:02:22,694] Trial 20 pruned.
# [I 2026-06-09 14:02:32,640] Trial 21 finished with value: 13.251757621765137 and parameters: {'hidden_size': 128, 'lr': 0.0026666237013172984, 'batch_size': 64, 'weight_decay': 5.381906504020547e-06, 'dropout': 0.2357944178709294}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:02:42,010] Trial 22 finished with value: 13.247169494628906 and parameters: {'hidden_size': 128, 'lr': 0.0029110599396308333, 'batch_size': 64, 'weight_decay': 1.8419949769951825e-05, 'dropout': 0.3132951988390351}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:02:50,947] Trial 23 finished with value: 13.2731351852417 and parameters: {'hidden_size': 128, 'lr': 0.001605833412504775, 'batch_size': 64, 'weight_decay': 2.3065679624450593e-05, 'dropout': 0.32433409560993626}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:03:00,063] Trial 24 finished with value: 13.24681568145752 and parameters: {'hidden_size': 128, 'lr': 0.0026692626346093854, 'batch_size': 64, 'weight_decay': 2.5507353584763968e-05, 'dropout': 0.27662854492313305}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:03:07,966] Trial 25 finished with value: 13.265652656555176 and parameters: {'hidden_size': 128, 'lr': 0.003027303915509756, 'batch_size': 32, 'weight_decay': 2.3256712918277105e-05, 'dropout': 0.30794226246123035}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:03:16,255] Trial 26 finished with value: 13.265155792236328 and parameters: {'hidden_size': 128, 'lr': 0.0011969357306511757, 'batch_size': 64, 'weight_decay': 1.0199618097268783e-05, 'dropout': 0.2675101776545153}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:03:26,746] Trial 27 finished with value: 13.24504566192627 and parameters: {'hidden_size': 128, 'lr': 0.0022021920705207676, 'batch_size': 64, 'weight_decay': 7.385610860902233e-06, 'dropout': 0.38042843213263955}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:03:36,221] Trial 28 finished with value: 13.272242546081543 and parameters: {'hidden_size': 128, 'lr': 0.0019163275200069366, 'batch_size': 64, 'weight_decay': 1.021512263506679e-06, 'dropout': 0.4194283103320916}. Best is trial 13 with value: 13.242308616638184.
# ...
# [I 2026-06-09 14:04:48,566] Trial 35 finished with value: 13.256970405578613 and parameters: {'hidden_size': 128, 'lr': 0.002138110145782755, 'batch_size': 16, 'weight_decay': 1.858761230529781e-05, 'dropout': 0.26528943045191394}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:01,011] Trial 36 finished with value: 13.248576164245605 and parameters: {'hidden_size': 128, 'lr': 0.004599191445347665, 'batch_size': 64, 'weight_decay': 3.108715696551369e-06, 'dropout': 0.37953523700096226}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:10,480] Trial 37 finished with value: 13.255204200744629 and parameters: {'hidden_size': 128, 'lr': 0.0011996502882037192, 'batch_size': 64, 'weight_decay': 1.4776204583812379e-05, 'dropout': 0.31152144768568335}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:23,351] Trial 38 finished with value: 13.258102416992188 and parameters: {'hidden_size': 64, 'lr': 0.0015280500499315107, 'batch_size': 16, 'weight_decay': 3.207224113930978e-05, 'dropout': 0.24930483271931675}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:34,368] Trial 39 finished with value: 13.248454093933105 and parameters: {'hidden_size': 128, 'lr': 0.0006849038555483053, 'batch_size': 64, 'weight_decay': 7.515081914438448e-06, 'dropout': 0.34198262009597175}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:50,149] Trial 40 finished with value: 13.2551851272583 and parameters: {'hidden_size': 128, 'lr': 0.002727710747658073, 'batch_size': 64, 'weight_decay': 7.765552459746664e-05, 'dropout': 0.4905713267844018}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:05:57,689] Trial 41 pruned.
# [I 2026-06-09 14:06:09,476] Trial 42 finished with value: 13.2674560546875 and parameters: {'hidden_size': 32, 'lr': 0.003341138085111124, 'batch_size': 64, 'weight_decay': 3.5471566586819453e-05, 'dropout': 0.15984047902346477}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:06:33,595] Trial 43 finished with value: 13.25915813446045 and parameters: {'hidden_size': 32, 'lr': 0.0022807526470096213, 'batch_size': 16, 'weight_decay': 9.578373410530174e-05, 'dropout': 0.28536053219134405}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:06:41,440] Trial 44 pruned.
# [I 2026-06-09 14:06:53,381] Trial 45 finished with value: 13.25671100616455 and parameters: {'hidden_size': 32, 'lr': 0.005360750531250819, 'batch_size': 64, 'weight_decay': 9.136191926287453e-06, 'dropout': 0.10737841336665524}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:07:00,966] Trial 46 pruned.
# [I 2026-06-09 14:07:15,885] Trial 47 pruned.
# [I 2026-06-09 14:07:29,048] Trial 48 finished with value: 13.25389575958252 and parameters: {'hidden_size': 128, 'lr': 0.0006388591091754195, 'batch_size': 64, 'weight_decay': 5.5294206122402576e-05, 'dropout': 0.19579775215740952}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:07:40,882] Trial 49 pruned.
# [I 2026-06-09 14:07:48,718] Trial 50 pruned.
# [I 2026-06-09 14:08:00,634] Trial 51 finished with value: 13.259127616882324 and parameters: {'hidden_size': 128, 'lr': 0.0006761694058423096, 'batch_size': 64, 'weight_decay': 5.641280610559321e-06, 'dropout': 0.3410978727797767}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:08:08,911] Trial 52 pruned.
# [I 2026-06-09 14:08:20,118] Trial 53 finished with value: 13.261691093444824 and parameters: {'hidden_size': 128, 'lr': 0.0006880532641391178, 'batch_size': 64, 'weight_decay': 2.0461553279000113e-06, 'dropout': 0.3939712775465668}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:08:28,147] Trial 54 pruned.
# [I 2026-06-09 14:08:41,900] Trial 55 finished with value: 13.269185066223145 and parameters: {'hidden_size': 128, 'lr': 0.0005200339769852606, 'batch_size': 64, 'weight_decay': 6.69677879847138e-06, 'dropout': 0.2682841576895981}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:08:56,330] Trial 56 finished with value: 13.25204086303711 and parameters: {'hidden_size': 128, 'lr': 0.0007695789613516218, 'batch_size': 64, 'weight_decay': 0.0002091546053117374, 'dropout': 0.36440004998907605}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:09:07,804] Trial 57 finished with value: 13.267571449279785 and parameters: {'hidden_size': 128, 'lr': 0.0017369754368159818, 'batch_size': 32, 'weight_decay': 4.695722441139721e-05, 'dropout': 0.3208359883071296}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:09:36,060] Trial 58 finished with value: 13.257189750671387 and parameters: {'hidden_size': 64, 'lr': 0.00038542745420134313, 'batch_size': 64, 'weight_decay': 3.5660576764679843e-06, 'dropout': 0.23245581551270458}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:09:44,550] Trial 59 pruned.
# [I 2026-06-09 14:09:52,422] Trial 60 finished with value: 13.265965461730957 and parameters: {'hidden_size': 128, 'lr': 0.0012565038427037004, 'batch_size': 64, 'weight_decay': 2.6989825445120776e-05, 'dropout': 0.3398865701499956}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:09:59,101] Trial 61 finished with value: 13.261894226074219 and parameters: {'hidden_size': 128, 'lr': 0.0036088953172187005, 'batch_size': 64, 'weight_decay': 7.03250602108362e-06, 'dropout': 0.27299851405364745}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:10:07,366] Trial 62 finished with value: 13.269347190856934 and parameters: {'hidden_size': 128, 'lr': 0.004016321779447687, 'batch_size': 64, 'weight_decay': 8.742372225445433e-06, 'dropout': 0.2798442363627579}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:10:17,349] Trial 63 finished with value: 13.242924690246582 and parameters: {'hidden_size': 128, 'lr': 0.002926050718449894, 'batch_size': 64, 'weight_decay': 1.261532718481105e-05, 'dropout': 0.30044340231175726}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:10:28,447] Trial 64 finished with value: 13.25560474395752 and parameters: {'hidden_size': 128, 'lr': 0.002682954336766329, 'batch_size': 64, 'weight_decay': 1.3498950786875323e-05, 'dropout': 0.30010907292190936}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:10:36,291] Trial 65 finished with value: 13.261836051940918 and parameters: {'hidden_size': 128, 'lr': 0.0014769281225824314, 'batch_size': 64, 'weight_decay': 2.013360927711532e-05, 'dropout': 0.3142587507845175}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:10:49,463] Trial 66 finished with value: 13.247676849365234 and parameters: {'hidden_size': 128, 'lr': 0.0021906876441379563, 'batch_size': 64, 'weight_decay': 1.1575904851578903e-05, 'dropout': 0.38226677164595596}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:11:04,348] Trial 67 finished with value: 13.256179809570312 and parameters: {'hidden_size': 32, 'lr': 0.0021203378152299312, 'batch_size': 32, 'weight_decay': 1.1957893476723846e-05, 'dropout': 0.47030730386955216}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:11:12,142] Trial 68 finished with value: 13.250140190124512 and parameters: {'hidden_size': 128, 'lr': 0.0030889292736118595, 'batch_size': 64, 'weight_decay': 1.4457003665263321e-05, 'dropout': 0.4168548014443888}. Best is trial 13 with value: 13.242308616638184.
# [I 2026-06-09 14:11:29,511] Trial 69 finished with value: 13.241581916809082 and parameters: {'hidden_size': 128, 'lr': 0.0024073927504210404, 'batch_size': 16, 'weight_decay': 2.879599343783324e-05, 'dropout': 0.3793695200631374}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:11:45,243] Trial 70 finished with value: 13.261321067810059 and parameters: {'hidden_size': 128, 'lr': 0.0018970019022250468, 'batch_size': 16, 'weight_decay': 2.9831760068385556e-05, 'dropout': 0.18428727193991934}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:12:02,620] Trial 71 finished with value: 13.253369331359863 and parameters: {'hidden_size': 128, 'lr': 0.0024456640847128237, 'batch_size': 16, 'weight_decay': 2.095984889264985e-05, 'dropout': 0.3849580511625327}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:12:14,661] Trial 72 finished with value: 13.258837699890137 and parameters: {'hidden_size': 128, 'lr': 0.0030071576394992135, 'batch_size': 16, 'weight_decay': 1.6349243341900513e-05, 'dropout': 0.4079313941006018}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:12:26,690] Trial 73 finished with value: 13.25584888458252 and parameters: {'hidden_size': 128, 'lr': 0.004456750600038748, 'batch_size': 16, 'weight_decay': 4.2891538082835944e-05, 'dropout': 0.3612861480138245}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:12:43,948] Trial 74 finished with value: 13.258399963378906 and parameters: {'hidden_size': 128, 'lr': 0.0020087104427859875, 'batch_size': 16, 'weight_decay': 5.639684240716969e-06, 'dropout': 0.43629979124869034}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:12:56,566] Trial 75 finished with value: 13.256260871887207 and parameters: {'hidden_size': 64, 'lr': 0.0025093260129229475, 'batch_size': 64, 'weight_decay': 1.0086126915401528e-05, 'dropout': 0.3734573624272637}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:13:03,845] Trial 76 finished with value: 13.253681182861328 and parameters: {'hidden_size': 128, 'lr': 0.0017229381319371474, 'batch_size': 64, 'weight_decay': 3.551843989926884e-05, 'dropout': 0.24481762773081467}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:13:13,384] Trial 77 finished with value: 13.250236511230469 and parameters: {'hidden_size': 128, 'lr': 0.0030201369399005997, 'batch_size': 64, 'weight_decay': 6.738762556662751e-05, 'dropout': 0.22395471575599382}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:13:28,201] Trial 78 finished with value: 13.264213562011719 and parameters: {'hidden_size': 32, 'lr': 0.0013862947346608072, 'batch_size': 64, 'weight_decay': 2.293637595612556e-05, 'dropout': 0.3504127776985583}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:13:45,439] Trial 79 finished with value: 13.259174346923828 and parameters: {'hidden_size': 128, 'lr': 0.002276638735184678, 'batch_size': 16, 'weight_decay': 1.6677992398411088e-05, 'dropout': 0.2614914586605461}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:13:57,046] Trial 80 finished with value: 13.260687828063965 and parameters: {'hidden_size': 128, 'lr': 0.0011029821572214901, 'batch_size': 64, 'weight_decay': 1.139205334168415e-05, 'dropout': 0.38612358593224544}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:05,801] Trial 81 pruned.
# [I 2026-06-09 14:14:15,967] Trial 82 finished with value: 13.246368408203125 and parameters: {'hidden_size': 128, 'lr': 0.0038705613263831868, 'batch_size': 64, 'weight_decay': 5.8176590798954795e-06, 'dropout': 0.2923940717635365}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:24,269] Trial 83 finished with value: 13.251116752624512 and parameters: {'hidden_size': 128, 'lr': 0.005031973748820616, 'batch_size': 64, 'weight_decay': 6.395206803080344e-06, 'dropout': 0.20313971894092725}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:31,432] Trial 84 finished with value: 13.245652198791504 and parameters: {'hidden_size': 128, 'lr': 0.004265665261633069, 'batch_size': 64, 'weight_decay': 2.690874035520368e-06, 'dropout': 0.32941915396048677}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:38,674] Trial 85 finished with value: 13.257311820983887 and parameters: {'hidden_size': 128, 'lr': 0.004116846857173562, 'batch_size': 64, 'weight_decay': 2.889120753928595e-06, 'dropout': 0.3311900680694369}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:50,733] Trial 86 finished with value: 13.245356559753418 and parameters: {'hidden_size': 32, 'lr': 0.006160310396774562, 'batch_size': 32, 'weight_decay': 2.2966264049081915e-06, 'dropout': 0.29694478210491143}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:14:58,850] Trial 87 finished with value: 13.271827697753906 and parameters: {'hidden_size': 32, 'lr': 0.007006564065589, 'batch_size': 32, 'weight_decay': 1.585657489164467e-06, 'dropout': 0.29083282612190947}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:15:12,336] Trial 88 finished with value: 13.254944801330566 and parameters: {'hidden_size': 128, 'lr': 0.0059397060202053195, 'batch_size': 32, 'weight_decay': 2.248149677521997e-06, 'dropout': 0.25924641507775137}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:15:20,544] Trial 89 finished with value: 13.253024101257324 and parameters: {'hidden_size': 128, 'lr': 0.0034459925657265187, 'batch_size': 32, 'weight_decay': 1.4388650837683698e-06, 'dropout': 0.31777159590971793}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:15:31,729] Trial 90 finished with value: 13.252777099609375 and parameters: {'hidden_size': 64, 'lr': 0.0044859704603911555, 'batch_size': 32, 'weight_decay': 4.091177840376444e-06, 'dropout': 0.30462749978802345}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:15:43,228] Trial 91 finished with value: 13.245201110839844 and parameters: {'hidden_size': 32, 'lr': 0.008878440803511422, 'batch_size': 32, 'weight_decay': 1.771531554980505e-06, 'dropout': 0.29828571598099296}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:00,037] Trial 92 finished with value: 13.254677772521973 and parameters: {'hidden_size': 32, 'lr': 0.006496235592256242, 'batch_size': 32, 'weight_decay': 1.0495685671686643e-06, 'dropout': 0.2828453718702003}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:08,217] Trial 93 finished with value: 13.268043518066406 and parameters: {'hidden_size': 32, 'lr': 0.008612622936289673, 'batch_size': 32, 'weight_decay': 2.7003902184753484e-06, 'dropout': 0.29652124137406705}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:16,907] Trial 94 finished with value: 13.308808326721191 and parameters: {'hidden_size': 32, 'lr': 0.0054586496120451996, 'batch_size': 32, 'weight_decay': 1.7191272598988147e-06, 'dropout': 0.33222677409564183}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:33,172] Trial 95 finished with value: 13.2495756149292 and parameters: {'hidden_size': 32, 'lr': 0.00919747940619162, 'batch_size': 32, 'weight_decay': 3.3096411913906974e-06, 'dropout': 0.30873393591733983}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:42,464] Trial 96 finished with value: 13.241687774658203 and parameters: {'hidden_size': 32, 'lr': 0.007756934154158615, 'batch_size': 32, 'weight_decay': 2.5233622393567417e-06, 'dropout': 0.2754736102398079}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:50,479] Trial 97 finished with value: 13.254776000976562 and parameters: {'hidden_size': 32, 'lr': 0.007456539811967861, 'batch_size': 32, 'weight_decay': 1.2449153697500336e-06, 'dropout': 0.27558663000930955}. Best is trial 69 with value: 13.241581916809082.
# [I 2026-06-09 14:16:59,792] Trial 98 pruned.
# [I 2026-06-09 14:17:09,123] Trial 99 pruned.
# Best Params for Small-cap: {'hidden_size': 128, 'lr': 0.0024073927504210404, 'batch_size': 16, 'weight_decay': 2.879599343783324e-05, 'dropout': 0.3793695200631374}
#
# Small-cap - Total Test MAE: 1.9426 ± 0.1155
# Group            MIB   Mid-cap  Small-cap
# Target
# EBITDA      1.872972  0.434066   2.098847
# Net_Income  0.724902  1.663558   1.823405
# ROA         0.760404  1.620463   1.905453
# TOTAL       1.119426  1.239362   1.942568

# %%
# ============================================================
# TRAIN FINAL DEDICATED MODEL FOR EACH MARKET-CAP GROUP
# ============================================================

GROUP_PARAMS = {
    "MIB": {
        "hidden_size": 64,
        "lr": 0.0047639846588888755,
        "batch_size": 32,
        "weight_decay": 0.0004627785003174142,
        "dropout": 0.137398162298415
    },
    "Mid-cap": {
        "hidden_size": 64,
        "lr": 0.005426748767587874,
        "batch_size": 32,
        "weight_decay": 3.6520300079748134e-06,
        "dropout": 0.2908379909201838
    },
    "Small-cap": {
        "hidden_size": 128,
        "lr": 0.0024073927504210404,
        "batch_size": 16,
        "weight_decay": 2.879599343783324e-05,
        "dropout": 0.3793695200631374
    }
}

results = []

for group_name, tickers in ticker_groups.items():

    print("\n" + "=" * 60)
    print(group_name)
    print("=" * 60)

    params = GROUP_PARAMS[group_name]

    set_seed(42)

    group_df = improved_data_df[
        improved_data_df["company"].isin(tickers)
    ].copy()

    g_train, g_val, g_test = split_by_year(
        group_df,
        TRAIN_YEAR_CUTOFF,
        VALID_YEAR_CUTOFF
    )

    scaler = RobustScaler()

    train_windows = np.vstack([
        row[:, selected_indices]
        for row in g_train["window_data"]
    ])

    scaler.fit(train_windows)

    train_ds = ImprovedYoYDatasetMTL(
        extract_mtl_df(g_train),
        scaler,
        selected_indices
    )

    val_ds = ImprovedYoYDatasetMTL(
        extract_mtl_df(g_val),
        scaler,
        selected_indices
    )

    test_ds = ImprovedYoYDatasetMTL(
        extract_mtl_df(g_test),
        scaler,
        selected_indices
    )

    train_loader = DataLoader(
        train_ds,
        batch_size=params["batch_size"],
        shuffle=True,
        collate_fn=collate_fn_improved_mtl
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=params["batch_size"],
        shuffle=False,
        collate_fn=collate_fn_improved_mtl
    )

    test_loader = DataLoader(
        test_ds,
        batch_size=params["batch_size"],
        shuffle=False,
        collate_fn=collate_fn_improved_mtl
    )

    model = ImprovedShallowLSTM(
        input_size=len(selected_indices),
        hidden_size=params["hidden_size"],
        num_targets=len(PREDICTION_TARGETS),
        dropout=params["dropout"]
    ).to(DEVICE)

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=params["lr"],
        weight_decay=params["weight_decay"]
    )

    model, _ = train_and_eval(
        model,
        train_loader,
        val_loader,
        optimizer,
        True,
        None,
        loss_type='l1'
    )

    print("\nTEST RESULTS")
    mae, rmse = evaluate_real_metrics(
        model,
        test_loader,
        DEVICE
    )

    n_samples = len(test_ds)

    results.append({
        "Group": group_name,
        "MAE": mae,
        "RMSE": rmse,
        "N": n_samples
    })

df_results = pd.DataFrame(results)

print("\n")
print("=" * 60)
print("FINAL RESULTS")
print("=" * 60)

print(df_results)

weighted_mae = (
    (df_results["MAE"] * df_results["N"]).sum()
    / df_results["N"].sum()
)

weighted_rmse = (
    (df_results["RMSE"] * df_results["N"]).sum()
    / df_results["N"].sum()
)

print("\nWeighted MAE:")
print(weighted_mae)

print("\nWeighted RMSE:")
print(weighted_rmse)
# Out:
# ============================================================
# MIB
# ============================================================
#
# TEST RESULTS
# Test MAE  (Real Scale): 1.1349
# Test RMSE (Real Scale): 8.2930
#
# ============================================================
# Mid-cap
# ============================================================
#
# TEST RESULTS
# Test MAE  (Real Scale): 1.2548
# Test RMSE (Real Scale): 8.7773
#
# ============================================================
# Small-cap
# ============================================================
#
# TEST RESULTS
# Test MAE  (Real Scale): 1.9577
# Test RMSE (Real Scale): 8.6113
#
#
# ============================================================
# FINAL RESULTS
# ============================================================
#        Group       MAE      RMSE    N
# 0        MIB  1.134931  8.293011   87
# 1    Mid-cap  1.254799  8.777294  156
# 2  Small-cap  1.957686  8.611273  241
#
# Weighted MAE:
# 1.5832434488722116
#
# Weighted RMSE:
# 8.607575554493046

# %% [markdown]
# # Two Layers

# %%
def objective_two_layers(trial):

    hidden_size = trial.suggest_categorical(
        "hidden_size",
        [32, 64, 128, 256]
    )

    dropout = trial.suggest_float(
        "dropout",
        0.1,
        0.5
    )

    lr = trial.suggest_float(
        "lr",
        1e-4,
        1e-2,
        log=True
    )

    weight_decay = trial.suggest_float(
        "weight_decay",
        1e-6,
        1e-3,
        log=True
    )

    batch_size = trial.suggest_categorical(
        "batch_size",
        [16, 32, 64]
    )

    # FIX: use the symlog transformed data (mtl_train_data_imp) instead of baseline
    train_ds = ImprovedYoYDatasetMTL(
        mtl_train_data_imp,
        robust_scaler,
        selected_indices
    )

    # FIX: use the symlog transformed data (mtl_val_data_imp) instead of baseline
    val_ds = ImprovedYoYDatasetMTL(
        mtl_val_data_imp,
        robust_scaler,
        selected_indices
    )

    train_loader = DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collate_fn_improved_mtl
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=batch_size,
        shuffle=False,
        collate_fn=collate_fn_improved_mtl
    )

    model = TwoLayersLSTM(
        input_size=len(selected_indices),
        hidden_size=hidden_size,
        num_targets=len(PREDICTION_TARGETS),
        dropout=dropout
    ).to(DEVICE)

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=weight_decay
    )

    _, best_metric = train_and_eval(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        optimizer=optimizer,
        is_improved=True,  # Correctly aligns with the updated _imp datasets
        trial=trial,
        loss_type='l1'
    )

    return best_metric

# %%
pruner = optuna.pruners.MedianPruner(
    n_startup_trials=10,
    n_warmup_steps=15
)

study = optuna.create_study(
    direction="minimize",
    study_name="two_layer_lstm",
    pruner=pruner
)

study.optimize(
    objective_two_layers,
    n_trials=100
)
# Out:
# [I 2026-06-11 22:24:16,241] A new study created in memory with name: two_layer_lstm
# [I 2026-06-11 22:24:50,053] Trial 0 finished with value: 7.724623203277588 and parameters: {'hidden_size': 128, 'dropout': 0.14691214989478396, 'lr': 0.00032024034260419817, 'weight_decay': 3.218262125518156e-05, 'batch_size': 32}. Best is trial 0 with value: 7.724623203277588.
# [I 2026-06-11 22:25:18,977] Trial 1 finished with value: 7.720845699310303 and parameters: {'hidden_size': 128, 'dropout': 0.2558427957440973, 'lr': 0.00010680887330958243, 'weight_decay': 3.90947526573401e-05, 'batch_size': 64}. Best is trial 1 with value: 7.720845699310303.
# [I 2026-06-11 22:25:52,892] Trial 2 finished with value: 7.6981587409973145 and parameters: {'hidden_size': 64, 'dropout': 0.1539068872509223, 'lr': 0.0034307115486327646, 'weight_decay': 2.5843706910896993e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:26:29,464] Trial 3 finished with value: 7.705106258392334 and parameters: {'hidden_size': 256, 'dropout': 0.20743838012260524, 'lr': 0.0004672001807498966, 'weight_decay': 2.1696142158977444e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:27:19,048] Trial 4 finished with value: 7.715505599975586 and parameters: {'hidden_size': 32, 'dropout': 0.24773793505814223, 'lr': 0.00042676541616724965, 'weight_decay': 0.00032394259000330015, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:27:37,141] Trial 5 finished with value: 7.710048675537109 and parameters: {'hidden_size': 64, 'dropout': 0.2119327999041818, 'lr': 0.009697236982694089, 'weight_decay': 6.538739202739029e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:27:58,482] Trial 6 finished with value: 7.738523006439209 and parameters: {'hidden_size': 32, 'dropout': 0.39812590550854343, 'lr': 0.0008943044345769521, 'weight_decay': 4.4362050741995495e-06, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:28:46,559] Trial 7 finished with value: 7.704579830169678 and parameters: {'hidden_size': 64, 'dropout': 0.1513266008626788, 'lr': 0.00010399771357332292, 'weight_decay': 0.0002149009978151829, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:29:46,220] Trial 8 finished with value: 7.7099480628967285 and parameters: {'hidden_size': 32, 'dropout': 0.19800895252225398, 'lr': 0.0027277951204429567, 'weight_decay': 0.00044236240859465043, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:30:27,129] Trial 9 finished with value: 7.704514980316162 and parameters: {'hidden_size': 64, 'dropout': 0.28601712831419307, 'lr': 0.0023716025088391787, 'weight_decay': 0.00069239586556653, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:31:15,289] Trial 10 finished with value: 7.715224742889404 and parameters: {'hidden_size': 256, 'dropout': 0.4581147740698651, 'lr': 0.003959688288708021, 'weight_decay': 1.1723825595467165e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:31:52,939] Trial 11 finished with value: 7.713142395019531 and parameters: {'hidden_size': 64, 'dropout': 0.32688219374383126, 'lr': 0.002238770592737676, 'weight_decay': 7.797993982986367e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:33:00,778] Trial 12 finished with value: 7.7082600593566895 and parameters: {'hidden_size': 64, 'dropout': 0.11056792315755859, 'lr': 0.0015150474175131981, 'weight_decay': 0.0009236074722187688, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:33:41,147] Trial 13 finished with value: 7.71212911605835 and parameters: {'hidden_size': 64, 'dropout': 0.33375275398048576, 'lr': 0.006426517370326779, 'weight_decay': 0.00011041090106892649, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:34:26,401] Trial 14 finished with value: 7.7033820152282715 and parameters: {'hidden_size': 64, 'dropout': 0.3515313022113764, 'lr': 0.001124356658133748, 'weight_decay': 7.547143474310141e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:35:08,974] Trial 15 finished with value: 7.708219051361084 and parameters: {'hidden_size': 64, 'dropout': 0.4904225888847472, 'lr': 0.0010166157536377995, 'weight_decay': 1.0895573148532073e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:36:08,269] Trial 16 finished with value: 7.69915771484375 and parameters: {'hidden_size': 64, 'dropout': 0.3973092657297117, 'lr': 0.004645255835169649, 'weight_decay': 2.0578554382209064e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:36:24,183] Trial 17 finished with value: 7.71052360534668 and parameters: {'hidden_size': 128, 'dropout': 0.4171481520029893, 'lr': 0.005101879893235935, 'weight_decay': 1.0864435187233708e-06, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:37:00,885] Trial 18 pruned.
# [I 2026-06-11 22:37:58,707] Trial 19 finished with value: 7.714130878448486 and parameters: {'hidden_size': 64, 'dropout': 0.29950894788677634, 'lr': 0.0037079289926735767, 'weight_decay': 1.4892006878859843e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:38:17,569] Trial 20 finished with value: 7.707138538360596 and parameters: {'hidden_size': 64, 'dropout': 0.4977293603334968, 'lr': 0.006041870226670521, 'weight_decay': 2.394402520995735e-06, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:39:13,076] Trial 21 finished with value: 7.712218761444092 and parameters: {'hidden_size': 64, 'dropout': 0.34970819938496284, 'lr': 0.0012033456536578368, 'weight_decay': 6.453769857278233e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:39:49,680] Trial 22 finished with value: 7.701847076416016 and parameters: {'hidden_size': 64, 'dropout': 0.3720666942671491, 'lr': 0.0017806831137301877, 'weight_decay': 1.9932413709677366e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:40:37,051] Trial 23 finished with value: 7.703235626220703 and parameters: {'hidden_size': 64, 'dropout': 0.4383979865012849, 'lr': 0.0018709983083687702, 'weight_decay': 1.7720160907983676e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:41:05,161] Trial 24 finished with value: 7.709737777709961 and parameters: {'hidden_size': 64, 'dropout': 0.3843700721442157, 'lr': 0.003144033579311243, 'weight_decay': 3.8716510236017005e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:41:38,630] Trial 25 pruned.
# [I 2026-06-11 22:42:07,807] Trial 26 finished with value: 7.700402736663818 and parameters: {'hidden_size': 128, 'dropout': 0.10564441603817998, 'lr': 0.00449304077803845, 'weight_decay': 0.00014211977291262576, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:43:13,536] Trial 27 finished with value: 7.707973003387451 and parameters: {'hidden_size': 128, 'dropout': 0.10176851092292395, 'lr': 0.004510862497062739, 'weight_decay': 0.0001566765765817928, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:43:31,189] Trial 28 finished with value: 7.7032623291015625 and parameters: {'hidden_size': 128, 'dropout': 0.15430893043328278, 'lr': 0.00740319804599976, 'weight_decay': 7.566548277604198e-05, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:44:06,697] Trial 29 pruned.
# [I 2026-06-11 22:44:44,526] Trial 30 finished with value: 7.703145980834961 and parameters: {'hidden_size': 128, 'dropout': 0.12388193030357353, 'lr': 0.002994544655092373, 'weight_decay': 5.80702788522448e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:45:25,117] Trial 31 finished with value: 7.70759391784668 and parameters: {'hidden_size': 128, 'dropout': 0.1373337917889385, 'lr': 0.0016903439626122442, 'weight_decay': 1.902755522810001e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:46:36,799] Trial 32 finished with value: 7.706837177276611 and parameters: {'hidden_size': 32, 'dropout': 0.2373133682453545, 'lr': 0.004908441551506219, 'weight_decay': 2.1895851522242546e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:47:20,403] Trial 33 finished with value: 7.7141571044921875 and parameters: {'hidden_size': 256, 'dropout': 0.1739378235256397, 'lr': 0.0034176676696169024, 'weight_decay': 4.873276658630513e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:48:21,540] Trial 34 finished with value: 7.70739221572876 and parameters: {'hidden_size': 128, 'dropout': 0.2890853630433349, 'lr': 0.0023516672944235073, 'weight_decay': 2.8561299202131675e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:48:44,201] Trial 35 pruned.
# [I 2026-06-11 22:49:02,286] Trial 36 pruned.
# [I 2026-06-11 22:49:47,578] Trial 37 finished with value: 7.7051100730896 and parameters: {'hidden_size': 256, 'dropout': 0.2219273908172506, 'lr': 0.000654741394974083, 'weight_decay': 0.00021472371591318615, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:50:25,376] Trial 38 finished with value: 7.714969635009766 and parameters: {'hidden_size': 64, 'dropout': 0.25906445535772704, 'lr': 0.0003077118570247925, 'weight_decay': 8.702706870448209e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:51:20,079] Trial 39 finished with value: 7.703369140625 and parameters: {'hidden_size': 128, 'dropout': 0.18624064004651678, 'lr': 0.005045683256703849, 'weight_decay': 0.0003895275742719732, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:51:53,514] Trial 40 pruned.
# [I 2026-06-11 22:52:18,912] Trial 41 finished with value: 7.7150115966796875 and parameters: {'hidden_size': 128, 'dropout': 0.11658829304323606, 'lr': 0.00286722481540814, 'weight_decay': 4.59475194729744e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:52:52,011] Trial 42 finished with value: 7.704113006591797 and parameters: {'hidden_size': 128, 'dropout': 0.15774096684735442, 'lr': 0.0020004153802388636, 'weight_decay': 0.00018178189790618273, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:53:40,201] Trial 43 finished with value: 7.7055840492248535 and parameters: {'hidden_size': 128, 'dropout': 0.12375634659892952, 'lr': 0.004040465764819519, 'weight_decay': 0.0001282022446240082, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:54:15,630] Trial 44 finished with value: 7.709596633911133 and parameters: {'hidden_size': 128, 'dropout': 0.10391120366224502, 'lr': 0.0032757652618860124, 'weight_decay': 6.193995505580026e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:54:51,568] Trial 45 finished with value: 7.703238010406494 and parameters: {'hidden_size': 64, 'dropout': 0.1474683919124527, 'lr': 0.005543520496988, 'weight_decay': 2.490206487064404e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:55:15,061] Trial 46 pruned.
# [I 2026-06-11 22:56:05,310] Trial 47 finished with value: 7.7081427574157715 and parameters: {'hidden_size': 128, 'dropout': 0.30990018674704795, 'lr': 0.004047490958814846, 'weight_decay': 0.0002804718734333515, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:56:33,539] Trial 48 finished with value: 7.709110260009766 and parameters: {'hidden_size': 64, 'dropout': 0.1631686822229907, 'lr': 0.002075644082578762, 'weight_decay': 0.00010546271008410797, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:57:10,199] Trial 49 pruned.
# [I 2026-06-11 22:58:08,430] Trial 50 finished with value: 7.704014301300049 and parameters: {'hidden_size': 64, 'dropout': 0.4773775278677943, 'lr': 0.007438904127738362, 'weight_decay': 0.0005583884103831075, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:58:49,161] Trial 51 finished with value: 7.711303234100342 and parameters: {'hidden_size': 64, 'dropout': 0.42744612789842745, 'lr': 0.001854502087826316, 'weight_decay': 1.6055010344815546e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 22:59:43,353] Trial 52 finished with value: 7.711429595947266 and parameters: {'hidden_size': 64, 'dropout': 0.4361255328136777, 'lr': 0.0027707477899690004, 'weight_decay': 2.145820121164621e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:00:17,293] Trial 53 pruned.
# [I 2026-06-11 23:00:57,405] Trial 54 finished with value: 7.712049961090088 and parameters: {'hidden_size': 64, 'dropout': 0.44745299242921543, 'lr': 0.0007854452364799696, 'weight_decay': 1.0602070516836597e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:01:35,093] Trial 55 finished with value: 7.701712131500244 and parameters: {'hidden_size': 64, 'dropout': 0.38207416883640327, 'lr': 0.0017702058129854482, 'weight_decay': 3.738077366660929e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:02:37,594] Trial 56 finished with value: 7.7085723876953125 and parameters: {'hidden_size': 64, 'dropout': 0.3674090396488862, 'lr': 0.0012787606419306405, 'weight_decay': 8.827345289476899e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:03:42,911] Trial 57 finished with value: 7.708314418792725 and parameters: {'hidden_size': 32, 'dropout': 0.4026717976293757, 'lr': 0.004110212956912614, 'weight_decay': 3.1119765637863848e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:04:06,373] Trial 58 finished with value: 7.713359832763672 and parameters: {'hidden_size': 64, 'dropout': 0.32733052060076695, 'lr': 0.006490162789971375, 'weight_decay': 1.8153270242856952e-05, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:04:45,890] Trial 59 finished with value: 7.710256099700928 and parameters: {'hidden_size': 128, 'dropout': 0.3798366080586593, 'lr': 0.0010217836575822823, 'weight_decay': 1.3165788972262302e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:05:05,933] Trial 60 finished with value: 7.701661586761475 and parameters: {'hidden_size': 64, 'dropout': 0.34213077819053117, 'lr': 0.0016406003373394863, 'weight_decay': 3.681763567518472e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:05:27,445] Trial 61 finished with value: 7.714653015136719 and parameters: {'hidden_size': 64, 'dropout': 0.3606314453364538, 'lr': 0.001654336360209102, 'weight_decay': 6.307770256393467e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:05:49,906] Trial 62 finished with value: 7.718576908111572 and parameters: {'hidden_size': 64, 'dropout': 0.13785707033486047, 'lr': 0.002986965104197313, 'weight_decay': 4.276996118502287e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:06:28,113] Trial 63 finished with value: 7.70867919921875 and parameters: {'hidden_size': 64, 'dropout': 0.39233359349076685, 'lr': 0.0017366658729511, 'weight_decay': 2.4203146896304705e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:07:15,838] Trial 64 finished with value: 7.708408355712891 and parameters: {'hidden_size': 64, 'dropout': 0.3483319451053159, 'lr': 0.0034915969464179354, 'weight_decay': 3.159275713223434e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:07:53,428] Trial 65 finished with value: 7.708887100219727 and parameters: {'hidden_size': 64, 'dropout': 0.3404452162534304, 'lr': 0.0021865166182941384, 'weight_decay': 3.7025443216040207e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:08:15,489] Trial 66 finished with value: 7.716735363006592 and parameters: {'hidden_size': 256, 'dropout': 0.4098325520342984, 'lr': 0.004452863990310104, 'weight_decay': 9.761433530051371e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:08:54,417] Trial 67 finished with value: 7.70936918258667 and parameters: {'hidden_size': 128, 'dropout': 0.47056795929583817, 'lr': 0.0013152596090653262, 'weight_decay': 1.2681826646615882e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:09:44,893] Trial 68 finished with value: 7.706780910491943 and parameters: {'hidden_size': 64, 'dropout': 0.12176950334269454, 'lr': 0.0010823639248810184, 'weight_decay': 5.6658889657890865e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:10:26,537] Trial 69 finished with value: 7.709269046783447 and parameters: {'hidden_size': 64, 'dropout': 0.3172740440884719, 'lr': 0.0008754799792154987, 'weight_decay': 1.9065194938523101e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:10:45,784] Trial 70 finished with value: 7.712047576904297 and parameters: {'hidden_size': 128, 'dropout': 0.3796557968163785, 'lr': 0.0027109257440921337, 'weight_decay': 2.6597355068253294e-06, 'batch_size': 64}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:11:25,709] Trial 71 finished with value: 7.714341640472412 and parameters: {'hidden_size': 64, 'dropout': 0.1003585418274995, 'lr': 0.0015093914004870401, 'weight_decay': 1.688977148882598e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:11:55,168] Trial 72 finished with value: 7.70407247543335 and parameters: {'hidden_size': 64, 'dropout': 0.13781105746090516, 'lr': 0.0019232918970196777, 'weight_decay': 1.3330578646258238e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:12:31,024] Trial 73 finished with value: 7.713499546051025 and parameters: {'hidden_size': 64, 'dropout': 0.39908668166341876, 'lr': 0.0022771860643042846, 'weight_decay': 3.699570784525557e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:13:01,498] Trial 74 finished with value: 7.718801021575928 and parameters: {'hidden_size': 32, 'dropout': 0.44634863770131666, 'lr': 0.003562793132317587, 'weight_decay': 2.0170321886323798e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:13:28,981] Trial 75 finished with value: 7.70526647567749 and parameters: {'hidden_size': 64, 'dropout': 0.425291562163544, 'lr': 0.0056506115387928236, 'weight_decay': 4.1201641400124e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:14:24,548] Trial 76 finished with value: 7.708035945892334 and parameters: {'hidden_size': 64, 'dropout': 0.36913738521782125, 'lr': 0.0031167555630187103, 'weight_decay': 0.00013353912281559156, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:14:56,456] Trial 77 finished with value: 7.702063083648682 and parameters: {'hidden_size': 128, 'dropout': 0.43799411024351537, 'lr': 0.0016116142184874646, 'weight_decay': 8.268579031682103e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:15:26,320] Trial 78 finished with value: 7.704854488372803 and parameters: {'hidden_size': 128, 'dropout': 0.21803703463902363, 'lr': 0.0012061319010343524, 'weight_decay': 9.699464186491595e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:15:48,840] Trial 79 pruned.
# [I 2026-06-11 23:16:22,290] Trial 80 pruned.
# [I 2026-06-11 23:17:48,533] Trial 81 finished with value: 7.705861568450928 and parameters: {'hidden_size': 128, 'dropout': 0.49077166056970306, 'lr': 0.00213295063888759, 'weight_decay': 0.00015030877251694918, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:18:46,182] Trial 82 finished with value: 7.707942962646484 and parameters: {'hidden_size': 128, 'dropout': 0.42082211099350114, 'lr': 0.0019043983890045654, 'weight_decay': 5.0135858409378566e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:19:11,783] Trial 83 finished with value: 7.734156131744385 and parameters: {'hidden_size': 256, 'dropout': 0.43431851429858176, 'lr': 0.00464704697770107, 'weight_decay': 7.5067477646436515e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:19:44,771] Trial 84 pruned.
# [I 2026-06-11 23:20:37,618] Trial 85 finished with value: 7.709676265716553 and parameters: {'hidden_size': 128, 'dropout': 0.41025574915222807, 'lr': 0.0025598908485294333, 'weight_decay': 2.6086577198373333e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:21:29,415] Trial 86 finished with value: 7.7114996910095215 and parameters: {'hidden_size': 64, 'dropout': 0.4363565584842664, 'lr': 0.0013729468675046587, 'weight_decay': 3.566683593789068e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:21:52,355] Trial 87 pruned.
# [I 2026-06-11 23:22:09,172] Trial 88 pruned.
# [I 2026-06-11 23:22:51,337] Trial 89 finished with value: 7.710974216461182 and parameters: {'hidden_size': 128, 'dropout': 0.27507452237625346, 'lr': 0.0033714070250277345, 'weight_decay': 0.0001759203579852864, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:23:55,403] Trial 90 finished with value: 7.706190586090088 and parameters: {'hidden_size': 64, 'dropout': 0.37947353044600385, 'lr': 0.003903620828514015, 'weight_decay': 0.00012097585995393553, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:24:22,796] Trial 91 finished with value: 7.709219455718994 and parameters: {'hidden_size': 64, 'dropout': 0.14569928836377216, 'lr': 0.005654209360406106, 'weight_decay': 2.582542540560491e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:24:42,542] Trial 92 finished with value: 7.712355136871338 and parameters: {'hidden_size': 64, 'dropout': 0.11568918862395412, 'lr': 0.0069386789424355465, 'weight_decay': 1.7062518079067684e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:25:01,040] Trial 93 finished with value: 7.710954189300537 and parameters: {'hidden_size': 64, 'dropout': 0.18712829549427323, 'lr': 0.005201678870787442, 'weight_decay': 4.37228066283588e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:25:22,771] Trial 94 finished with value: 7.714399814605713 and parameters: {'hidden_size': 64, 'dropout': 0.14582471203926203, 'lr': 0.004537027623339773, 'weight_decay': 2.3222150789967005e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:25:54,617] Trial 95 finished with value: 7.707396030426025 and parameters: {'hidden_size': 64, 'dropout': 0.2424336628431947, 'lr': 0.0029091193817036357, 'weight_decay': 1.773943528942313e-06, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:26:27,506] Trial 96 finished with value: 7.705421447753906 and parameters: {'hidden_size': 64, 'dropout': 0.3564831237928608, 'lr': 0.008455463338618902, 'weight_decay': 6.346910556905026e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:27:14,582] Trial 97 finished with value: 7.71044921875 and parameters: {'hidden_size': 128, 'dropout': 0.1565093802661833, 'lr': 0.0009340210481814322, 'weight_decay': 2.345889864282003e-06, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:27:57,826] Trial 98 finished with value: 7.711215972900391 and parameters: {'hidden_size': 64, 'dropout': 0.3435133886296163, 'lr': 0.0011374691998683449, 'weight_decay': 5.4750114572359076e-05, 'batch_size': 16}. Best is trial 2 with value: 7.6981587409973145.
# [I 2026-06-11 23:28:20,717] Trial 99 finished with value: 7.7103729248046875 and parameters: {'hidden_size': 64, 'dropout': 0.1279865833060707, 'lr': 0.005476554768575807, 'weight_decay': 7.862963814259483e-05, 'batch_size': 32}. Best is trial 2 with value: 7.6981587409973145.

# %%
best_config = {
    'hidden_size': 64,
    'dropout': 0.1539068872509223,
    'lr': 0.0034307115486327646,
    'weight_decay': 2.5843706910896993e-05,
    'batch_size': 16
}

# 2. Define the window sizes you want to test
window_sizes_to_test = [7, 14, 21, 30, 60]

# Dictionary to store the final metrics for comparison
experiment_results = {}

for w_size in window_sizes_to_test:
    print(f"\n{'='*50}")
    print(f"Starting training with window_size: {w_size}")
    print(f"{'='*50}")

    # 3. Initialize datasets with the current window size
    train_dataset = ImprovedYoYDatasetMTL(
        mtl_train_data_imp,
        robust_scaler,
        selected_indices,
        window_size=w_size
    )

    val_dataset = ImprovedYoYDatasetMTL(
        mtl_val_data_imp,
        robust_scaler,
        selected_indices,
        window_size=w_size
    )

    # 4. Create DataLoaders using the fixed batch size
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=best_config['batch_size'],
        shuffle=True,
        collate_fn=collate_fn_improved_mtl
    )

    val_dataloader = DataLoader(
        val_dataset,
        batch_size=best_config['batch_size'],
        shuffle=False,
        collate_fn=collate_fn_improved_mtl
    )

    # 5. Initialize the TwoLayersLSTM model
    lstm_model = TwoLayersLSTM(
        input_size=len(selected_indices),
        hidden_size=best_config['hidden_size'],
        num_targets=len(PREDICTION_TARGETS),
        dropout=best_config['dropout']
    ).to(DEVICE)

    # 6. Initialize the optimizer
    optimizer = torch.optim.Adam(
        lstm_model.parameters(),
        lr=best_config['lr'],
        weight_decay=best_config['weight_decay']
    )

    # 7. Train and evaluate
    # Important: pass trial=None since we are no longer using Optuna for pruning
    _, best_val_metric = train_and_eval(
        model=lstm_model,
        train_loader=train_dataloader,
        val_loader=val_dataloader,
        optimizer=optimizer,
        is_improved=True,
        loss_type='l1',
        trial=None
    )

    # 8. Save the result
    experiment_results[w_size] = best_val_metric
    print(f"--> Completed window_size {w_size} | Best Val Loss: {best_val_metric:.4f}")

# 9. Print the final summary of all window sizes
print("\n" + "="*50)
print("FINAL RESULTS SUMMARY")
print("="*50)
for w_size, metric in experiment_results.items():
    print(f"Window Size: {w_size:2d} | Best Validation L1 Loss: {metric:.4f}")
# Out:
# ==================================================
# Starting training with window_size: 7
# ==================================================
# --> Completed window_size 7 | Best Val Loss: 7.7119
#
# ==================================================
# Starting training with window_size: 14
# ==================================================
# --> Completed window_size 14 | Best Val Loss: 7.7062
#
# ==================================================
# Starting training with window_size: 21
# ==================================================
# --> Completed window_size 21 | Best Val Loss: 7.7051
#
# ==================================================
# Starting training with window_size: 30
# ==================================================
# --> Completed window_size 30 | Best Val Loss: 7.7012
#
# ==================================================
# Starting training with window_size: 60
# ==================================================
# --> Completed window_size 60 | Best Val Loss: 7.7072
#
# ==================================================
# FINAL RESULTS SUMMARY
# ==================================================
# Window Size:  7 | Best Validation L1 Loss: 7.7119
# Window Size: 14 | Best Validation L1 Loss: 7.7062
# Window Size: 21 | Best Validation L1 Loss: 7.7051
# Window Size: 30 | Best Validation L1 Loss: 7.7012
# Window Size: 60 | Best Validation L1 Loss: 7.7072

# %%
import optuna
import torch
from torch.utils.data import DataLoader

def objective_upgraded(trial):
    # 1. Define hyperparameters to tune for the new architecture
    hidden_size = trial.suggest_categorical(
        "hidden_size",
        [32, 64, 128, 256]
    )

    dropout = trial.suggest_float(
        "dropout",
        0.1,
        0.5
    )

    lr = trial.suggest_float(
        "lr",
        1e-4,
        1e-2,
        log=True
    )

    weight_decay = trial.suggest_float(
        "weight_decay",
        1e-6,
        1e-3,
        log=True
    )

    batch_size = trial.suggest_categorical(
        "batch_size",
        [16, 32, 64]
    )

    # 2. Set the optimal window size found during the ablation study
    fixed_window_size = 30

    # 3. Initialize datasets using the transformed data (_imp)
    train_dataset = ImprovedYoYDatasetMTL(
        mtl_train_data_imp,
        robust_scaler,
        selected_indices,
        window_size=fixed_window_size
    )

    val_dataset = ImprovedYoYDatasetMTL(
        mtl_val_data_imp,
        robust_scaler,
        selected_indices,
        window_size=fixed_window_size
    )

    # 4. Create DataLoaders
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collate_fn_improved_mtl
    )

    val_dataloader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        collate_fn=collate_fn_improved_mtl
    )

    # 5. Initialize the upgraded BiLSTM model
    model = UpgradedTwoLayersLSTM(
        input_size=len(selected_indices),
        hidden_size=hidden_size,
        num_targets=len(PREDICTION_TARGETS),
        dropout=dropout
    ).to(DEVICE)

    # 6. Initialize the optimizer
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=weight_decay
    )

    # 7. Train and evaluate, passing the trial object for pruning
    _, best_val_metric = train_and_eval(
        model=model,
        train_loader=train_dataloader,
        val_loader=val_dataloader,
        optimizer=optimizer,
        is_improved=True,
        loss_type='l1',
        trial=trial
    )

    return best_val_metric

# 8. Create and run the Optuna study
if __name__ == "__main__":
    study = optuna.create_study(
        direction="minimize",
        study_name="Upgraded_BiLSTM_Optimization"
    )

    # You can adjust n_trials based on the available time and compute resources
    study.optimize(objective_upgraded, n_trials=100)

    print("\n" + "="*50)
    print("OPTUNA STUDY COMPLETED")
    print("="*50)
    print(f"Best Validation Loss: {study.best_value:.4f}")
    print("Best Hyperparameters:")
    for key, value in study.best_params.items():
        print(f"  {key}: {value}")
# Out:
# [I 2026-06-12 00:51:19,373] A new study created in memory with name: Upgraded_BiLSTM_Optimization
# [I 2026-06-12 00:51:45,669] Trial 0 finished with value: 7.734804153442383 and parameters: {'hidden_size': 32, 'dropout': 0.2447338841658706, 'lr': 0.0009028734202600334, 'weight_decay': 2.5938817623815756e-06, 'batch_size': 16}. Best is trial 0 with value: 7.734804153442383.
# [I 2026-06-12 00:52:28,391] Trial 1 finished with value: 7.7083916664123535 and parameters: {'hidden_size': 64, 'dropout': 0.38023986160156975, 'lr': 0.0024723194872839365, 'weight_decay': 7.348794126445753e-05, 'batch_size': 32}. Best is trial 1 with value: 7.7083916664123535.
# [I 2026-06-12 00:52:41,508] Trial 2 finished with value: 7.745471954345703 and parameters: {'hidden_size': 128, 'dropout': 0.3765217778130161, 'lr': 0.004537401000836832, 'weight_decay': 6.989491990591736e-05, 'batch_size': 32}. Best is trial 1 with value: 7.7083916664123535.
# [I 2026-06-12 00:53:08,084] Trial 3 finished with value: 7.704807758331299 and parameters: {'hidden_size': 64, 'dropout': 0.368795602574165, 'lr': 0.0028411549770207076, 'weight_decay': 8.322216245075205e-05, 'batch_size': 64}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:53:27,619] Trial 4 finished with value: 7.745858669281006 and parameters: {'hidden_size': 256, 'dropout': 0.4273515764693254, 'lr': 0.003440260762524587, 'weight_decay': 5.371545331732443e-06, 'batch_size': 16}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:53:41,619] Trial 5 finished with value: 7.730350971221924 and parameters: {'hidden_size': 128, 'dropout': 0.19571059315397885, 'lr': 0.00020159792608110837, 'weight_decay': 9.981908088048799e-06, 'batch_size': 32}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:54:09,267] Trial 6 pruned.
# [I 2026-06-12 00:54:10,130] Trial 7 pruned.
# [I 2026-06-12 00:54:30,416] Trial 8 finished with value: 7.707250118255615 and parameters: {'hidden_size': 64, 'dropout': 0.32128762836618574, 'lr': 0.0024893756931290032, 'weight_decay': 8.832027517863074e-06, 'batch_size': 64}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:54:31,359] Trial 9 pruned.
# [I 2026-06-12 00:54:32,192] Trial 10 pruned.
# [I 2026-06-12 00:54:44,050] Trial 11 finished with value: 7.722946643829346 and parameters: {'hidden_size': 64, 'dropout': 0.3023864584386753, 'lr': 0.0013108566436079525, 'weight_decay': 0.0004001897165805957, 'batch_size': 64}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:54:59,036] Trial 12 pruned.
# [I 2026-06-12 00:54:59,838] Trial 13 pruned.
# [I 2026-06-12 00:55:00,635] Trial 14 pruned.
# [I 2026-06-12 00:55:13,864] Trial 15 pruned.
# [I 2026-06-12 00:55:41,457] Trial 16 finished with value: 7.707163333892822 and parameters: {'hidden_size': 32, 'dropout': 0.28350947649921754, 'lr': 0.0021959753315643833, 'weight_decay': 1.184109738764871e-05, 'batch_size': 64}. Best is trial 3 with value: 7.704807758331299.
# [I 2026-06-12 00:55:42,289] Trial 17 pruned.
# [I 2026-06-12 00:55:47,004] Trial 18 pruned.
# [I 2026-06-12 00:56:13,522] Trial 19 finished with value: 7.701961517333984 and parameters: {'hidden_size': 32, 'dropout': 0.18675628889002252, 'lr': 0.0017115793242785025, 'weight_decay': 0.0002962671402905773, 'batch_size': 16}. Best is trial 19 with value: 7.701961517333984.
# [I 2026-06-12 00:56:14,954] Trial 20 pruned.
# [I 2026-06-12 00:56:16,234] Trial 21 pruned.
# [I 2026-06-12 00:56:17,631] Trial 22 pruned.
# [I 2026-06-12 00:56:31,656] Trial 23 pruned.
# [I 2026-06-12 00:56:47,204] Trial 24 pruned.
# [I 2026-06-12 00:56:51,434] Trial 25 pruned.
# [I 2026-06-12 00:56:52,234] Trial 26 pruned.
# [I 2026-06-12 00:56:53,824] Trial 27 pruned.
# [I 2026-06-12 00:57:22,890] Trial 28 finished with value: 7.707120895385742 and parameters: {'hidden_size': 128, 'dropout': 0.11320425766897521, 'lr': 0.002036229557850004, 'weight_decay': 3.583198161310762e-05, 'batch_size': 32}. Best is trial 19 with value: 7.701961517333984.
# [I 2026-06-12 00:57:37,361] Trial 29 finished with value: 7.713016033172607 and parameters: {'hidden_size': 128, 'dropout': 0.10596140406605307, 'lr': 0.0012914734760100216, 'weight_decay': 4.670227414827369e-05, 'batch_size': 32}. Best is trial 19 with value: 7.701961517333984.
# [I 2026-06-12 00:57:38,887] Trial 30 pruned.
# [I 2026-06-12 00:57:40,033] Trial 31 pruned.
# [I 2026-06-12 00:57:41,111] Trial 32 pruned.
# [I 2026-06-12 00:58:10,637] Trial 33 finished with value: 7.708178997039795 and parameters: {'hidden_size': 128, 'dropout': 0.1300733364207442, 'lr': 0.00152007256191393, 'weight_decay': 4.7326531652595165e-05, 'batch_size': 16}. Best is trial 19 with value: 7.701961517333984.
# [I 2026-06-12 00:58:11,714] Trial 34 pruned.
# [I 2026-06-12 00:58:12,707] Trial 35 pruned.
# [I 2026-06-12 00:58:37,126] Trial 36 pruned.
# [I 2026-06-12 00:58:54,447] Trial 37 finished with value: 7.713053226470947 and parameters: {'hidden_size': 128, 'dropout': 0.10353997148230625, 'lr': 0.0007839679191130316, 'weight_decay': 0.00011810318800670639, 'batch_size': 32}. Best is trial 19 with value: 7.701961517333984.
# [I 2026-06-12 00:58:55,844] Trial 38 pruned.
# [I 2026-06-12 00:58:56,668] Trial 39 pruned.
# [I 2026-06-12 00:58:57,493] Trial 40 pruned.
# [I 2026-06-12 00:58:58,294] Trial 41 pruned.
# [I 2026-06-12 00:58:59,885] Trial 42 pruned.
# [I 2026-06-12 00:59:00,714] Trial 43 pruned.
# [I 2026-06-12 00:59:01,545] Trial 44 pruned.
# [I 2026-06-12 00:59:02,353] Trial 45 pruned.
# [I 2026-06-12 00:59:03,178] Trial 46 pruned.
# [I 2026-06-12 00:59:04,257] Trial 47 pruned.
# [I 2026-06-12 00:59:32,745] Trial 48 finished with value: 7.700216770172119 and parameters: {'hidden_size': 256, 'dropout': 0.1866786560425094, 'lr': 0.0001022364193508964, 'weight_decay': 7.628913251523041e-05, 'batch_size': 64}. Best is trial 48 with value: 7.700216770172119.
# [I 2026-06-12 00:59:34,090] Trial 49 pruned.
# [I 2026-06-12 00:59:34,958] Trial 50 pruned.
# [I 2026-06-12 00:59:51,418] Trial 51 pruned.
# [I 2026-06-12 00:59:52,321] Trial 52 pruned.
# [I 2026-06-12 00:59:53,127] Trial 53 pruned.
# [I 2026-06-12 00:59:53,939] Trial 54 pruned.
# [I 2026-06-12 00:59:54,978] Trial 55 pruned.
# [I 2026-06-12 01:00:27,015] Trial 56 finished with value: 7.700719356536865 and parameters: {'hidden_size': 256, 'dropout': 0.19541385532840447, 'lr': 0.00032536229009831895, 'weight_decay': 0.0001670777571756515, 'batch_size': 16}. Best is trial 48 with value: 7.700216770172119.
# [I 2026-06-12 01:00:35,581] Trial 57 pruned.
# [I 2026-06-12 01:00:52,762] Trial 58 finished with value: 7.715207576751709 and parameters: {'hidden_size': 256, 'dropout': 0.2523134220798459, 'lr': 0.00015423034738866375, 'weight_decay': 0.0002537849953839056, 'batch_size': 16}. Best is trial 48 with value: 7.700216770172119.
# [I 2026-06-12 01:00:54,136] Trial 59 pruned.
# [I 2026-06-12 01:00:55,495] Trial 60 pruned.
# [I 2026-06-12 01:00:56,732] Trial 61 pruned.
# [I 2026-06-12 01:00:59,853] Trial 62 pruned.
# [I 2026-06-12 01:01:00,927] Trial 63 pruned.
# [I 2026-06-12 01:01:01,764] Trial 64 pruned.
# [I 2026-06-12 01:01:03,018] Trial 65 pruned.
# [I 2026-06-12 01:01:28,476] Trial 66 finished with value: 7.698819637298584 and parameters: {'hidden_size': 64, 'dropout': 0.3162961795036872, 'lr': 0.0035905918291395294, 'weight_decay': 4.1353125421884645e-05, 'batch_size': 64}. Best is trial 66 with value: 7.698819637298584.
# [I 2026-06-12 01:01:29,458] Trial 67 pruned.
# [I 2026-06-12 01:01:30,723] Trial 68 pruned.
# [I 2026-06-12 01:01:31,569] Trial 69 pruned.
# [I 2026-06-12 01:01:32,514] Trial 70 pruned.
# [I 2026-06-12 01:01:43,737] Trial 71 pruned.
# [I 2026-06-12 01:01:44,628] Trial 72 pruned.
# [I 2026-06-12 01:01:45,453] Trial 73 pruned.
# [I 2026-06-12 01:01:47,079] Trial 74 pruned.
# [I 2026-06-12 01:01:48,429] Trial 75 pruned.
# [I 2026-06-12 01:01:50,116] Trial 76 pruned.
# [I 2026-06-12 01:02:04,826] Trial 77 finished with value: 7.700212001800537 and parameters: {'hidden_size': 128, 'dropout': 0.21126678169312846, 'lr': 0.0011276057158268063, 'weight_decay': 4.10054589499882e-06, 'batch_size': 64}. Best is trial 66 with value: 7.698819637298584.
# [I 2026-06-12 01:02:07,325] Trial 78 pruned.
# [I 2026-06-12 01:02:08,164] Trial 79 pruned.
# [I 2026-06-12 01:02:09,160] Trial 80 pruned.
# [I 2026-06-12 01:02:10,015] Trial 81 pruned.
# [I 2026-06-12 01:02:10,870] Trial 82 pruned.
# [I 2026-06-12 01:02:11,687] Trial 83 pruned.
# [I 2026-06-12 01:02:12,607] Trial 84 pruned.
# [I 2026-06-12 01:02:13,814] Trial 85 pruned.
# [I 2026-06-12 01:02:15,452] Trial 86 pruned.
# [I 2026-06-12 01:02:17,092] Trial 87 pruned.
# [I 2026-06-12 01:02:17,930] Trial 88 pruned.
# [I 2026-06-12 01:02:19,002] Trial 89 pruned.
# [I 2026-06-12 01:03:07,745] Trial 90 finished with value: 7.703485012054443 and parameters: {'hidden_size': 64, 'dropout': 0.13477025737655757, 'lr': 0.0025176575673054335, 'weight_decay': 8.373197585081785e-05, 'batch_size': 16}. Best is trial 66 with value: 7.698819637298584.
# [I 2026-06-12 01:03:08,994] Trial 91 pruned.
# [I 2026-06-12 01:03:10,282] Trial 92 pruned.
# [I 2026-06-12 01:03:11,526] Trial 93 pruned.
# [I 2026-06-12 01:03:12,776] Trial 94 pruned.
# [I 2026-06-12 01:03:14,016] Trial 95 pruned.
# [I 2026-06-12 01:03:21,124] Trial 96 pruned.
# [I 2026-06-12 01:03:22,488] Trial 97 pruned.
# [I 2026-06-12 01:03:23,312] Trial 98 pruned.
# [I 2026-06-12 01:03:26,224] Trial 99 pruned.
# ==================================================
# OPTUNA STUDY COMPLETED
# ==================================================
# Best Validation Loss: 7.6988
# Best Hyperparameters:
#   hidden_size: 64
#   dropout: 0.3162961795036872
#   lr: 0.0035905918291395294
#   weight_decay: 4.1353125421884645e-05
#   batch_size: 64
